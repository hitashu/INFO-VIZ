# %%
import pandas as pd
import numpy as np
import plotly.graph_objects as go

# %%
# !pip install pmdarima
# Out:
# Collecting pmdarima
#   Downloading pmdarima-1.8.3-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (1.4 MB)
#      |████████████████████████████████| 1.4 MB 5.1 MB/s
# Requirement already satisfied: numpy>=1.19.3 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.19.5)
# Requirement already satisfied: pandas>=0.19 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.1.5)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (0.22.2.post1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.0.1)
# Requirement already satisfied: Cython!=0.29.18,>=0.29 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (0.29.24)
# Collecting statsmodels!=0.12.0,>=0.11
#   Downloading statsmodels-0.13.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.8 MB)
#      |████████████████████████████████| 9.8 MB 15.4 MB/s
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.4.1)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.24.3)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (57.4.0)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19->pmdarima) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19->pmdarima) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.19->pmdarima) (1.15.0)
# Requirement already satisfied: patsy>=0.5.2 in /usr/local/lib/python3.7/dist-packages (from statsmodels!=0.12.0,>=0.11->pmdarima) (0.5.2)
# Installing collected packages: statsmodels, pmdarima
#   Attempting uninstall: statsmodels
#     Found existing installation: statsmodels 0.10.2
#     Uninstalling statsmodels-0.10.2:
#       Successfully uninstalled statsmodels-0.10.2
# Successfully installed pmdarima-1.8.3 statsmodels-0.13.0

# %%
import numpy as np
import pandas as pd
from math import sqrt
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf 
from statsmodels.tsa.seasonal import seasonal_decompose 
from statsmodels.tsa.stattools import adfuller              
from sklearn.metrics import mean_squared_error
from statsmodels.tools.eval_measures import rmse
import warnings
import matplotlib.pyplot as plt
warnings.filterwarnings("ignore")
import statsmodels.api as sm
from statsmodels.tsa.seasonal import seasonal_decompose
import statsmodels.tsa.ar_model
import pmdarima as pm
from statsmodels.tsa.arima.model import ARIMA

# %% [markdown]
# # Load Data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
calendar = pd.read_csv('/content/drive/MyDrive/INFO-VIZ/calendar.csv')
sales= pd.read_csv('/content/drive/MyDrive/INFO-VIZ/sales_train_evaluation.csv')
sell_prices = pd.read_csv('/content/drive/MyDrive/INFO-VIZ/sell_prices.csv')

# %%
print("The shape of sales data:",sales.shape)
print("The shape of sell_prices data:",sell_prices.shape)
print("The shape of calender data:",calendar.shape)
# Out:
# The shape of sales data: (30490, 1947)
# The shape of sell_prices data: (6841121, 4)
# The shape of calender data: (1969, 14)

# %%
calendar.tail()
# Out:
#             date  wm_yr_wk    weekday  ...  snap_CA  snap_TX  snap_WI
# 1964  2016-06-15     11620  Wednesday  ...        0        1        1
# 1965  2016-06-16     11620   Thursday  ...        0        0        0
# 1966  2016-06-17     11620     Friday  ...        0        0        0
# 1967  2016-06-18     11621   Saturday  ...        0        0        0
# 1968  2016-06-19     11621     Sunday  ...        0        0        0
#
# [5 rows x 14 columns]

# %%
sales.head()
# Out:
#                               id        item_id  ... d_1940 d_1941
# 0  HOBBIES_1_001_CA_1_evaluation  HOBBIES_1_001  ...      0      1
# 1  HOBBIES_1_002_CA_1_evaluation  HOBBIES_1_002  ...      0      0
# 2  HOBBIES_1_003_CA_1_evaluation  HOBBIES_1_003  ...      0      1
# 3  HOBBIES_1_004_CA_1_evaluation  HOBBIES_1_004  ...      2      6
# 4  HOBBIES_1_005_CA_1_evaluation  HOBBIES_1_005  ...      1      0
#
# [5 rows x 1947 columns]

# %%
sell_prices.head()
# Out:
#   store_id        item_id  wm_yr_wk  sell_price
# 0     CA_1  HOBBIES_1_001     11325        9.58
# 1     CA_1  HOBBIES_1_001     11326        9.58
# 2     CA_1  HOBBIES_1_001     11327        8.26
# 3     CA_1  HOBBIES_1_001     11328        8.26
# 4     CA_1  HOBBIES_1_001     11329        8.26

# %% [markdown]
# # Data Prep Phase

# %% [markdown]
# ## Perform Downcasting to reduce the amount of storage used by the datframes

# %%
# UPDATE 10/29 SS

def checkMemUsage(df):
  """
  Helper function to check memory usage

  Input: A dataframe

  Output: Memory usage

  """
  mem_usage = df.memory_usage().sum()
  return np.round(np.round(mem_usage/(1024*1024),1))

# %%
# Memory Usage Before Downcasting

print("Initial Memoery Usage: Sales {} , Calendar {} , sell_prices {}".format(checkMemUsage(sales), checkMemUsage(calendar), checkMemUsage(sell_prices)))
# Out:
# Initial Memoery Usage: Sales 453.0 , Calendar 0.0 , sell_prices 209.0

# %%
# UPDATE 10/29 SS

def performDowncast(df):

  """
  Function tpo apply downcasting 
  
  Input: A dataframe 

  Output: Dataframe with reduced memory usage
  
  
  """
  cols = df.dtypes.index.tolist()
  types = df.dtypes.values.tolist()

  for idx,dtype in enumerate(types):

      if 'int' in str(dtype):  # Downcasting for Int type variables
          if df[cols[idx]].min() > np.iinfo(np.int8).min and df[cols[idx]].max() < np.iinfo(np.int8).max:
              df[cols[idx]] = df[cols[idx]].astype(np.int8) # Downsize to int8
          elif df[cols[idx]].min() > np.iinfo(np.int16).min and df[cols[idx]].max() < np.iinfo(np.int16).max:
              df[cols[idx]] = df[cols[idx]].astype(np.int16) # Downsize to int16
          elif df[cols[idx]].min() > np.iinfo(np.int32).min and df[cols[idx]].max() < np.iinfo(np.int32).max:
              df[cols[idx]] = df[cols[idx]].astype(np.int32) # Downsize to int32
          else:
              df[cols[idx]] = df[cols[idx]].astype(np.int64) # Downsize as int64

      elif 'float' in str(dtype): # Downcasting for Float type variables
          if df[cols[idx]].min() > np.finfo(np.float16).min and df[cols[idx]].max() < np.finfo(np.float16).max:
              df[cols[idx]] = df[cols[idx]].astype(np.float16) # Downsize to float16
          elif df[cols[idx]].min() > np.finfo(np.float32).min and df[cols[idx]].max() < np.finfo(np.float32).max:
              df[cols[idx]] = df[cols[idx]].astype(np.float32) # Downsize to float32
          else:
              df[cols[idx]] = df[cols[idx]].astype(np.float64) # Downsize to float64

      elif dtype == np.object: # By default strings are treated as objects
          if cols[idx] == 'date':
              df[cols[idx]] = pd.to_datetime(df[cols[idx]], format='%Y-%m-%d')
          # else:
          #     df[cols[idx]] = df[cols[idx]].astype('category')

  return df

# %%
sales = performDowncast(sales)
calendar = performDowncast(calendar)
sell_prices = performDowncast(sell_prices)

print("Memory Usage after Downcasting: Sales {} , Calendar {} , sell_prices {}".format(checkMemUsage(sales), checkMemUsage(calendar), checkMemUsage(sell_prices)))
# Out:
# Memory Usage after Downcasting: Sales 96.0 , Calendar 0.0 , sell_prices 130.0

# %%
sales.head() # QC check to verify the original data is not changed
# Out:
#                               id        item_id  ... d_1940 d_1941
# 0  HOBBIES_1_001_CA_1_evaluation  HOBBIES_1_001  ...      0      1
# 1  HOBBIES_1_002_CA_1_evaluation  HOBBIES_1_002  ...      0      0
# 2  HOBBIES_1_003_CA_1_evaluation  HOBBIES_1_003  ...      0      1
# 3  HOBBIES_1_004_CA_1_evaluation  HOBBIES_1_004  ...      2      6
# 4  HOBBIES_1_005_CA_1_evaluation  HOBBIES_1_005  ...      1      0
#
# [5 rows x 1947 columns]

# %%
calendar.head() # QC check to verify the original data is not changed
# Out:
#         date  wm_yr_wk    weekday  wday  ...  event_type_2  snap_CA snap_TX snap_WI
# 0 2011-01-29     11101   Saturday     1  ...           NaN        0       0       0
# 1 2011-01-30     11101     Sunday     2  ...           NaN        0       0       0
# 2 2011-01-31     11101     Monday     3  ...           NaN        0       0       0
# 3 2011-02-01     11101    Tuesday     4  ...           NaN        1       1       0
# 4 2011-02-02     11101  Wednesday     5  ...           NaN        1       0       1
#
# [5 rows x 14 columns]

# %%
sell_prices.head() # QC check to verify the original data is not changed
# Out:
#   store_id        item_id  wm_yr_wk  sell_price
# 0     CA_1  HOBBIES_1_001     11325    9.578125
# 1     CA_1  HOBBIES_1_001     11326    9.578125
# 2     CA_1  HOBBIES_1_001     11327    8.257812
# 3     CA_1  HOBBIES_1_001     11328    8.257812
# 4     CA_1  HOBBIES_1_001     11329    8.257812

# %% [markdown]
# ## Perform Groupby across sales data to identify best selection

# %%
sales_item = sales.groupby('item_id').sum()
sales_item.head()
# Out:
#              d_1  d_2  d_3  d_4  d_5  ...  d_1937  d_1938  d_1939  d_1940  d_1941
# item_id                               ...
# FOODS_1_001    6    6    4    6    7  ...     7.0     5.0     7.0       5     9.0
# FOODS_1_002    4    5    7    4    3  ...     5.0     0.0     6.0       6     4.0
# FOODS_1_003   14    8    3    6    3  ...     7.0     7.0    10.0       6     5.0
# FOODS_1_004    0    0    0    0    0  ...    62.0    71.0    75.0      83    93.0
# FOODS_1_005   34   32   13   20   10  ...    25.0    19.0    25.0      17    19.0
#
# [5 rows x 1941 columns]

# %%
sales_dept = sales.groupby('dept_id').sum()
sales_dept.head()
# Out:
#              d_1    d_2    d_3    d_4  ...   d_1938   d_1939  d_1940   d_1941
# dept_id                                ...
# FOODS_1     2343   2216   1657   1508  ...   3251.0   3735.0    4195   4031.0
# FOODS_2     4094   4209   3174   3606  ...   4551.0   4815.0    5940   6535.0
# FOODS_3    16741  16333  12343  13764  ...  16935.0  19586.0   23464  25401.0
# HOBBIES_1   3610   3172   2497   2531  ...   3027.0   3761.0    4832   4720.0
# HOBBIES_2    154    185    185    138  ...    448.0    382.0     501    560.0
#
# [5 rows x 1941 columns]

# %%
sales_store = sales.groupby('store_id').sum()
sales_store.head()
# Out:
#            d_1   d_2   d_3   d_4   d_5  ...  d_1937  d_1938  d_1939  d_1940  d_1941
# store_id                                ...
# CA_1      4337  4155  2816  3051  2630  ...  3995.0  4136.0  4433.0    5764  6289.0
# CA_2      3494  3046  2121  2324  1942  ...  3789.0  4037.0  4751.0    7120  6614.0
# CA_3      4739  4827  3785  4232  3817  ...  5375.0  5580.0  5542.0    7073  8144.0
# CA_4      1625  1777  1386  1440  1536  ...  2519.0  2544.0  2704.0    3146  3597.0
# TX_1      2556  2687  1822  2258  1694  ...  3147.0  2748.0  3664.0    4167  4624.0
#
# [5 rows x 1941 columns]

# %%
sales_cat = sales.groupby('cat_id').sum().T
sales_cat.head()
# Out:
# cat_id    FOODS  HOBBIES  HOUSEHOLD
# d_1     23178.0   3764.0     5689.0
# d_2     22758.0   3357.0     5634.0
# d_3     17174.0   2682.0     3927.0
# d_4     18878.0   2669.0     3865.0
# d_5     14603.0   1814.0     2729.0

# %%
# UPDATE 10/28 SS

sales_dept = sales.groupby('dept_id').sum().T
sales_dept.head()
# Out:
# dept_id  FOODS_1  FOODS_2  FOODS_3  ...  HOBBIES_2  HOUSEHOLD_1  HOUSEHOLD_2
# d_1       2343.0   4094.0  16741.0  ...      154.0       4105.0       1584.0
# d_2       2216.0   4209.0  16333.0  ...      185.0       3858.0       1776.0
# d_3       1657.0   3174.0  12343.0  ...      185.0       2827.0       1100.0
# d_4       1508.0   3606.0  13764.0  ...      138.0       2732.0       1133.0
# d_5       1209.0   2869.0  10525.0  ...      100.0       1802.0        927.0
#
# [5 rows x 7 columns]

# %%
sales_cat['days'] = sales_cat.index

# %%
sales_cat.head()
# Out:
# cat_id    FOODS  HOBBIES  HOUSEHOLD days
# d_1     23178.0   3764.0     5689.0  d_1
# d_2     22758.0   3357.0     5634.0  d_2
# d_3     17174.0   2682.0     3927.0  d_3
# d_4     18878.0   2669.0     3865.0  d_4
# d_5     14603.0   1814.0     2729.0  d_5

# %%
print(calendar.event_name_1.count(), calendar.event_type_1.count(), calendar.event_name_2.count(), calendar.event_type_2.count())
# Out:
# 162 162 5 5

# %%
# UPDATE 10/29 SS

sales_calender = calendar.iloc[:,[0,2,3,4,5,6,8,10,11,12,13]]  # Including all special day events
print(sales_calender.shape)
sales_calender.head(10)
# Out:
# (1969, 11)
#         date    weekday  wday  month  ...  event_type_2 snap_CA snap_TX snap_WI
# 0 2011-01-29   Saturday     1      1  ...           NaN       0       0       0
# 1 2011-01-30     Sunday     2      1  ...           NaN       0       0       0
# 2 2011-01-31     Monday     3      1  ...           NaN       0       0       0
# 3 2011-02-01    Tuesday     4      2  ...           NaN       1       1       0
# 4 2011-02-02  Wednesday     5      2  ...           NaN       1       0       1
# 5 2011-02-03   Thursday     6      2  ...           NaN       1       1       1
# 6 2011-02-04     Friday     7      2  ...           NaN       1       0       0
# 7 2011-02-05   Saturday     1      2  ...           NaN       1       1       1
# 8 2011-02-06     Sunday     2      2  ...           NaN       1       1       1
# 9 2011-02-07     Monday     3      2  ...           NaN       1       1       0
#
# [10 rows x 11 columns]

# %%
#sales_calender = calendar.iloc[:,[0,2,3,4,5,6,7]]
print(sales_cat.shape, sales_calender.shape)
sales_cat = pd.merge(sales_calender,sales_cat,how = 'inner', left_on = 'd', right_on = 'days')
sales_cat['date'] = pd.to_datetime(sales_cat['date'])
# Out:
# (1941, 4) (1969, 11)

# %%
print(sales_cat.shape)
sales_cat.head()
# Out:
# (1941, 15)
#         date    weekday  wday  month  ...    FOODS HOBBIES HOUSEHOLD days
# 0 2011-01-29   Saturday     1      1  ...  23178.0  3764.0    5689.0  d_1
# 1 2011-01-30     Sunday     2      1  ...  22758.0  3357.0    5634.0  d_2
# 2 2011-01-31     Monday     3      1  ...  17174.0  2682.0    3927.0  d_3
# 3 2011-02-01    Tuesday     4      2  ...  18878.0  2669.0    3865.0  d_4
# 4 2011-02-02  Wednesday     5      2  ...  14603.0  1814.0    2729.0  d_5
#
# [5 rows x 15 columns]

# %%
sales_cat = sales_cat.set_index('date')

# %%
sales_cat.head()
# Out:
#               weekday  wday  month  year  ...    FOODS HOBBIES HOUSEHOLD  days
# date                                      ...
# 2011-01-29   Saturday     1      1  2011  ...  23178.0  3764.0    5689.0   d_1
# 2011-01-30     Sunday     2      1  2011  ...  22758.0  3357.0    5634.0   d_2
# 2011-01-31     Monday     3      1  2011  ...  17174.0  2682.0    3927.0   d_3
# 2011-02-01    Tuesday     4      2  2011  ...  18878.0  2669.0    3865.0   d_4
# 2011-02-02  Wednesday     5      2  2011  ...  14603.0  1814.0    2729.0   d_5
#
# [5 rows x 14 columns]

# %%
sales_cat['weekday'].unique()
# Out:
# array(['Saturday', 'Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday',
#        'Friday'], dtype=object)

# %%
print(sales_cat.event_type_1.unique())
print(sales_cat.event_type_2.unique())
# Out:
# [nan 'Sporting' 'Cultural' 'National' 'Religious']
# [nan 'Cultural' 'Religious']

# %% [markdown]
# ## Creating exogenous variables from within the data

# %%
sales_cat["isWeekend"] = [1 if d =="Saturday" or d == "Sunday" else 0 for d in sales_cat.weekday] # To capture weekend sales
sales_cat["isWeekday"] = [0 if d =="Saturday" or d == "Sunday" else 1 for d in sales_cat.weekday] # To capture weekday sales
sales_cat['inbetween25and5'] = [1 if d >= 25 or d <= 5 else 0 for d in sales_cat.index.day] # Usual Payday
sales_cat['event_on_weekend'] = [1 if (wknd == 1 and (event1 not in [np.nan] or event2 not in [np.nan])) else 0 for wknd, event1, event2 in  
                              sales_cat[['isWeekend','event_type_1','event_type_2']].values] # If event was on weekends
sales_cat['event_on_weekday'] = [1 if (wkday == 1 and (event1 not in [np.nan] or event2 not in [np.nan])) else 0 for wkday, event1, event2 in
                              sales_cat[['isWeekday','event_type_1','event_type_2']].values] # If event was on weekdays

sales_cat = pd.get_dummies(sales_cat, columns=['event_type_1','event_type_2'], 
                             prefix=['event_type_1','event_type_2'], 
                             dummy_na=False)  # Dummy variable for all the events

sales_cat
print(sales_cat.shape)
sales_cat.head(10)
# Out:
# (1941, 23)
#               weekday  wday  ...  event_type_2_Cultural  event_type_2_Religious
# date                         ...
# 2011-01-29   Saturday     1  ...                      0                       0
# 2011-01-30     Sunday     2  ...                      0                       0
# 2011-01-31     Monday     3  ...                      0                       0
# 2011-02-01    Tuesday     4  ...                      0                       0
# 2011-02-02  Wednesday     5  ...                      0                       0
# 2011-02-03   Thursday     6  ...                      0                       0
# 2011-02-04     Friday     7  ...                      0                       0
# 2011-02-05   Saturday     1  ...                      0                       0
# 2011-02-06     Sunday     2  ...                      0                       0
# 2011-02-07     Monday     3  ...                      0                       0
#
# [10 rows x 23 columns]

# %%
sales_cat.drop(['weekday','wday','month','year','d','days'],axis=1,inplace=True)
sales_cat.head()
# Out:
#             snap_CA  snap_TX  ...  event_type_2_Cultural  event_type_2_Religious
# date                          ...
# 2011-01-29        0        0  ...                      0                       0
# 2011-01-30        0        0  ...                      0                       0
# 2011-01-31        0        0  ...                      0                       0
# 2011-02-01        1        1  ...                      0                       0
# 2011-02-02        1        0  ...                      0                       0
#
# [5 rows x 17 columns]

# %%
sales_cat.iloc[:,3:-1]
# Out:
#               FOODS  HOBBIES  ...  event_type_1_Sporting  event_type_2_Cultural
# date                          ...
# 2011-01-29  23178.0   3764.0  ...                      0                      0
# 2011-01-30  22758.0   3357.0  ...                      0                      0
# 2011-01-31  17174.0   2682.0  ...                      0                      0
# 2011-02-01  18878.0   2669.0  ...                      0                      0
# 2011-02-02  14603.0   1814.0  ...                      0                      0
# ...             ...      ...  ...                    ...                    ...
# 2016-05-18  24790.0   3740.0  ...                      0                      0
# 2016-05-19  24737.0   3475.0  ...                      0                      0
# 2016-05-20  28136.0   4143.0  ...                      0                      0
# 2016-05-21  33599.0   5333.0  ...                      0                      0
# 2016-05-22  35967.0   5280.0  ...                      0                      0
#
# [1941 rows x 13 columns]

# %% [markdown]
# # Timeseries Analysis

# %%
def resampleData(inputData, type="D"):
  """
  Helper Function to resample Data 

  Input: 
    inputData: Sales Data
    type: Parameter for daily, weekly or monthly

  Output: Resampled data with aggregated sales
  """
  if type=="W":
    return inputData.iloc[:,3:-1].resample('W').sum()[8:-1] 
  elif type=="D":
    return inputData.iloc[:,3:-1].resample('D').sum()
  elif type=="M":
    return inputData.iloc[:,3:-1].resample('M').sum()

# %% [markdown]
# # Phase 1: Resampled Weekly

# %%
sales_cat_weekly = resampleData(sales_cat.copy(),"W") #weekly resampling

# Necessary data cleaning required for weekly aggregation

sales_cat_weekly.drop(['isWeekend','isWeekday'],axis=1,inplace=True)  # Dropping as not relevant for weekly aggregated data
sales_cat_weekly.iloc[:,3:-1] = sales_cat_weekly.iloc[:,3:-1].clip(upper=1) # Setting the max upper bounds for relevant exog variables to 1

# %%
sales_cat_weekly
# Out:
#                FOODS  HOBBIES  ...  event_type_1_Sporting  event_type_2_Cultural
# date                           ...
# 2011-03-27  111979.0  19833.0  ...                      0                      0
# 2011-04-03  121015.0  21793.0  ...                      0                      0
# 2011-04-10  129467.0  20335.0  ...                      0                      0
# 2011-04-17  123350.0  19998.0  ...                      0                      0
# 2011-04-24  110804.0  17479.0  ...                      0                      1
# ...              ...      ...  ...                    ...                    ...
# 2016-04-17  201045.0  27683.0  ...                      0                      0
# 2016-04-24  189333.0  27490.0  ...                      0                      0
# 2016-05-01  191019.0  29056.0  ...                      0                      0
# 2016-05-08  213122.0  28886.0  ...                      0                      0
# 2016-05-15  225812.0  28786.0  ...                      0                      0
#
# [269 rows x 11 columns]

# %%
exog_list = list(sales_cat_weekly.columns[3:])
lists = ['FOODS','HOBBIES','HOUSEHOLD']

def plotSeries(inputData,lists=lists):
  """
  Helper Function to plot Time Series

  Input:
    inputData: Resampled Dataframe
    lists: category/department names

  Output:
    Timeseries plot

  """
  for i in lists:
        fig = go.Figure(data = [
              go.Scatter(y = inputData[i],x = inputData[i].index,name = i)
        ])
        fig.update_layout(title_text=i)
        fig.show()

# %%
plotSeries(sales_cat_weekly,lists)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="cbf6eb82-1cd4-4a74-9bcc-5143af75c620" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("cbf6eb82-1cd4-4a74-9bcc-5143af75c620")) {
#                     Plotly.newPlot(
#                         'cbf6eb82-1cd4-4a74-9bcc-5143af75c620',
#                         [{"name": "FOODS", "type": "scatter", "x": ["2011-03-27T00:00:00", "2011-04-03T00:00:00", "2011-04-10T00:00:00", "2011-04-17T00:00:00", "2011-04-24T00:00:00", "2011-05-01T00:00:00", "2011-05-08T00:00:00", "2011-05-15T00:00:00", "2011-05-22T00:00:00", "2011-05-29T00:00:00", "2011-06-05T00:00:00", "2011-06-12T00:00:00", "2011-06-19T00:00:00", "2011-06-26T00:00:00", "2011-07-03T00:00:00", "2011-07-10T00:00:00", "2011-07-17T00:00:00", "2011-07-24T00:00:00", "2011-07-31T00:00:00", "2011-08-07T00:00:00", "2011-08-14T00:00:00", "2011-08-21T00:00:00", "2011-08-28T00:00:00", "2011-09-04T00:00:00", "2011-09-11T00:00:00", "2011-09-18T00:00:00", "2011-09-25T00:00:00", "2011-10-02T00:00:00", "2011-10-09T00:00:00", "2011-10-16T00:00:00", "2011-10-23T00:00:00", "2011-10-30T00:00:00", "2011-11-06T00:00:00", "2011-11-13T00:00:00", "2011-11-20T00:00:00", "2011-11-27T00:00:00", "2011-12-04T00:00:00", "2011-12-11T00:00:00", "2011-12-18T00:00:00", "2011-12-25T00:00:00", "2012-01-01T00:00:00", "2012-01-08T00:00:00", "2012-01-15T00:00:00", "2012-01-22T00:00:00", "2012-01-29T00:00:00", "2012-02-05T00:00:00", "2012-02-12T00:00:00", "2012-02-19T00:00:00", "2012-02-26T00:00:00", "2012-03-04T00:00:00", "2012-03-11T00:00:00", "2012-03-18T00:00:00", "2012-03-25T00:00:00", "2012-04-01T00:00:00", "2012-04-08T00:00:00", "2012-04-15T00:00:00", "2012-04-22T00:00:00", "2012-04-29T00:00:00", "2012-05-06T00:00:00", "2012-05-13T00:00:00", "2012-05-20T00:00:00", "2012-05-27T00:00:00", "2012-06-03T00:00:00", "2012-06-10T00:00:00", "2012-06-17T00:00:00", "2012-06-24T00:00:00", "2012-07-01T00:00:00", "2012-07-08T00:00:00", "2012-07-15T00:00:00", "2012-07-22T00:00:00", "2012-07-29T00:00:00", "2012-08-05T00:00:00", "2012-08-12T00:00:00", "2012-08-19T00:00:00", "2012-08-26T00:00:00", "2012-09-02T00:00:00", "2012-09-09T00:00:00", "2012-09-16T00:00:00", "2012-09-23T00:00:00", "2012-09-30T00:00:00", "2012-10-07T00:00:00", "2012-10-14T00:00:00", "2012-10-21T00:00:00", "2012-10-28T00:00:00", "2012-11-04T00:00:00", "2012-11-11T00:00:00", "2012-11-18T00:00:00", "2012-11-25T00:00:00", "2012-12-02T00:00:00", "2012-12-09T00:00:00", "2012-12-16T00:00:00", "2012-12-23T00:00:00", "2012-12-30T00:00:00", "2013-01-06T00:00:00", "2013-01-13T00:00:00", "2013-01-20T00:00:00", "2013-01-27T00:00:00", "2013-02-03T00:00:00", "2013-02-10T00:00:00", "2013-02-17T00:00:00", "2013-02-24T00:00:00", "2013-03-03T00:00:00", "2013-03-10T00:00:00", "2013-03-17T00:00:00", "2013-03-24T00:00:00", "2013-03-31T00:00:00", "2013-04-07T00:00:00", "2013-04-14T00:00:00", "2013-04-21T00:00:00", "2013-04-28T00:00:00", "2013-05-05T00:00:00", "2013-05-12T00:00:00", "2013-05-19T00:00:00", "2013-05-26T00:00:00", "2013-06-02T00:00:00", "2013-06-09T00:00:00", "2013-06-16T00:00:00", "2013-06-23T00:00:00", "2013-06-30T00:00:00", "2013-07-07T00:00:00", "2013-07-14T00:00:00", "2013-07-21T00:00:00", "2013-07-28T00:00:00", "2013-08-04T00:00:00", "2013-08-11T00:00:00", "2013-08-18T00:00:00", "2013-08-25T00:00:00", "2013-09-01T00:00:00", "2013-09-08T00:00:00", "2013-09-15T00:00:00", "2013-09-22T00:00:00", "2013-09-29T00:00:00", "2013-10-06T00:00:00", "2013-10-13T00:00:00", "2013-10-20T00:00:00", "2013-10-27T00:00:00", "2013-11-03T00:00:00", "2013-11-10T00:00:00", "2013-11-17T00:00:00", "2013-11-24T00:00:00", "2013-12-01T00:00:00", "2013-12-08T00:00:00", "2013-12-15T00:00:00", "2013-12-22T00:00:00", "2013-12-29T00:00:00", "2014-01-05T00:00:00", "2014-01-12T00:00:00", "2014-01-19T00:00:00", "2014-01-26T00:00:00", "2014-02-02T00:00:00", "2014-02-09T00:00:00", "2014-02-16T00:00:00", "2014-02-23T00:00:00", "2014-03-02T00:00:00", "2014-03-09T00:00:00", "2014-03-16T00:00:00", "2014-03-23T00:00:00", "2014-03-30T00:00:00", "2014-04-06T00:00:00", "2014-04-13T00:00:00", "2014-04-20T00:00:00", "2014-04-27T00:00:00", "2014-05-04T00:00:00", "2014-05-11T00:00:00", "2014-05-18T00:00:00", "2014-05-25T00:00:00", "2014-06-01T00:00:00", "2014-06-08T00:00:00", "2014-06-15T00:00:00", "2014-06-22T00:00:00", "2014-06-29T00:00:00", ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="2ba5d0f6-37e5-4320-9a31-2b01ccf59621" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2ba5d0f6-37e5-4320-9a31-2b01ccf59621")) {
#                     Plotly.newPlot(
#                         '2ba5d0f6-37e5-4320-9a31-2b01ccf59621',
#                         [{"name": "HOBBIES", "type": "scatter", "x": ["2011-03-27T00:00:00", "2011-04-03T00:00:00", "2011-04-10T00:00:00", "2011-04-17T00:00:00", "2011-04-24T00:00:00", "2011-05-01T00:00:00", "2011-05-08T00:00:00", "2011-05-15T00:00:00", "2011-05-22T00:00:00", "2011-05-29T00:00:00", "2011-06-05T00:00:00", "2011-06-12T00:00:00", "2011-06-19T00:00:00", "2011-06-26T00:00:00", "2011-07-03T00:00:00", "2011-07-10T00:00:00", "2011-07-17T00:00:00", "2011-07-24T00:00:00", "2011-07-31T00:00:00", "2011-08-07T00:00:00", "2011-08-14T00:00:00", "2011-08-21T00:00:00", "2011-08-28T00:00:00", "2011-09-04T00:00:00", "2011-09-11T00:00:00", "2011-09-18T00:00:00", "2011-09-25T00:00:00", "2011-10-02T00:00:00", "2011-10-09T00:00:00", "2011-10-16T00:00:00", "2011-10-23T00:00:00", "2011-10-30T00:00:00", "2011-11-06T00:00:00", "2011-11-13T00:00:00", "2011-11-20T00:00:00", "2011-11-27T00:00:00", "2011-12-04T00:00:00", "2011-12-11T00:00:00", "2011-12-18T00:00:00", "2011-12-25T00:00:00", "2012-01-01T00:00:00", "2012-01-08T00:00:00", "2012-01-15T00:00:00", "2012-01-22T00:00:00", "2012-01-29T00:00:00", "2012-02-05T00:00:00", "2012-02-12T00:00:00", "2012-02-19T00:00:00", "2012-02-26T00:00:00", "2012-03-04T00:00:00", "2012-03-11T00:00:00", "2012-03-18T00:00:00", "2012-03-25T00:00:00", "2012-04-01T00:00:00", "2012-04-08T00:00:00", "2012-04-15T00:00:00", "2012-04-22T00:00:00", "2012-04-29T00:00:00", "2012-05-06T00:00:00", "2012-05-13T00:00:00", "2012-05-20T00:00:00", "2012-05-27T00:00:00", "2012-06-03T00:00:00", "2012-06-10T00:00:00", "2012-06-17T00:00:00", "2012-06-24T00:00:00", "2012-07-01T00:00:00", "2012-07-08T00:00:00", "2012-07-15T00:00:00", "2012-07-22T00:00:00", "2012-07-29T00:00:00", "2012-08-05T00:00:00", "2012-08-12T00:00:00", "2012-08-19T00:00:00", "2012-08-26T00:00:00", "2012-09-02T00:00:00", "2012-09-09T00:00:00", "2012-09-16T00:00:00", "2012-09-23T00:00:00", "2012-09-30T00:00:00", "2012-10-07T00:00:00", "2012-10-14T00:00:00", "2012-10-21T00:00:00", "2012-10-28T00:00:00", "2012-11-04T00:00:00", "2012-11-11T00:00:00", "2012-11-18T00:00:00", "2012-11-25T00:00:00", "2012-12-02T00:00:00", "2012-12-09T00:00:00", "2012-12-16T00:00:00", "2012-12-23T00:00:00", "2012-12-30T00:00:00", "2013-01-06T00:00:00", "2013-01-13T00:00:00", "2013-01-20T00:00:00", "2013-01-27T00:00:00", "2013-02-03T00:00:00", "2013-02-10T00:00:00", "2013-02-17T00:00:00", "2013-02-24T00:00:00", "2013-03-03T00:00:00", "2013-03-10T00:00:00", "2013-03-17T00:00:00", "2013-03-24T00:00:00", "2013-03-31T00:00:00", "2013-04-07T00:00:00", "2013-04-14T00:00:00", "2013-04-21T00:00:00", "2013-04-28T00:00:00", "2013-05-05T00:00:00", "2013-05-12T00:00:00", "2013-05-19T00:00:00", "2013-05-26T00:00:00", "2013-06-02T00:00:00", "2013-06-09T00:00:00", "2013-06-16T00:00:00", "2013-06-23T00:00:00", "2013-06-30T00:00:00", "2013-07-07T00:00:00", "2013-07-14T00:00:00", "2013-07-21T00:00:00", "2013-07-28T00:00:00", "2013-08-04T00:00:00", "2013-08-11T00:00:00", "2013-08-18T00:00:00", "2013-08-25T00:00:00", "2013-09-01T00:00:00", "2013-09-08T00:00:00", "2013-09-15T00:00:00", "2013-09-22T00:00:00", "2013-09-29T00:00:00", "2013-10-06T00:00:00", "2013-10-13T00:00:00", "2013-10-20T00:00:00", "2013-10-27T00:00:00", "2013-11-03T00:00:00", "2013-11-10T00:00:00", "2013-11-17T00:00:00", "2013-11-24T00:00:00", "2013-12-01T00:00:00", "2013-12-08T00:00:00", "2013-12-15T00:00:00", "2013-12-22T00:00:00", "2013-12-29T00:00:00", "2014-01-05T00:00:00", "2014-01-12T00:00:00", "2014-01-19T00:00:00", "2014-01-26T00:00:00", "2014-02-02T00:00:00", "2014-02-09T00:00:00", "2014-02-16T00:00:00", "2014-02-23T00:00:00", "2014-03-02T00:00:00", "2014-03-09T00:00:00", "2014-03-16T00:00:00", "2014-03-23T00:00:00", "2014-03-30T00:00:00", "2014-04-06T00:00:00", "2014-04-13T00:00:00", "2014-04-20T00:00:00", "2014-04-27T00:00:00", "2014-05-04T00:00:00", "2014-05-11T00:00:00", "2014-05-18T00:00:00", "2014-05-25T00:00:00", "2014-06-01T00:00:00", "2014-06-08T00:00:00", "2014-06-15T00:00:00", "2014-06-22T00:00:00", "2014-06-29T00:00:00 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="06e52e88-57c0-4a96-ac0c-83a6af751435" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("06e52e88-57c0-4a96-ac0c-83a6af751435")) {
#                     Plotly.newPlot(
#                         '06e52e88-57c0-4a96-ac0c-83a6af751435',
#                         [{"name": "HOUSEHOLD", "type": "scatter", "x": ["2011-03-27T00:00:00", "2011-04-03T00:00:00", "2011-04-10T00:00:00", "2011-04-17T00:00:00", "2011-04-24T00:00:00", "2011-05-01T00:00:00", "2011-05-08T00:00:00", "2011-05-15T00:00:00", "2011-05-22T00:00:00", "2011-05-29T00:00:00", "2011-06-05T00:00:00", "2011-06-12T00:00:00", "2011-06-19T00:00:00", "2011-06-26T00:00:00", "2011-07-03T00:00:00", "2011-07-10T00:00:00", "2011-07-17T00:00:00", "2011-07-24T00:00:00", "2011-07-31T00:00:00", "2011-08-07T00:00:00", "2011-08-14T00:00:00", "2011-08-21T00:00:00", "2011-08-28T00:00:00", "2011-09-04T00:00:00", "2011-09-11T00:00:00", "2011-09-18T00:00:00", "2011-09-25T00:00:00", "2011-10-02T00:00:00", "2011-10-09T00:00:00", "2011-10-16T00:00:00", "2011-10-23T00:00:00", "2011-10-30T00:00:00", "2011-11-06T00:00:00", "2011-11-13T00:00:00", "2011-11-20T00:00:00", "2011-11-27T00:00:00", "2011-12-04T00:00:00", "2011-12-11T00:00:00", "2011-12-18T00:00:00", "2011-12-25T00:00:00", "2012-01-01T00:00:00", "2012-01-08T00:00:00", "2012-01-15T00:00:00", "2012-01-22T00:00:00", "2012-01-29T00:00:00", "2012-02-05T00:00:00", "2012-02-12T00:00:00", "2012-02-19T00:00:00", "2012-02-26T00:00:00", "2012-03-04T00:00:00", "2012-03-11T00:00:00", "2012-03-18T00:00:00", "2012-03-25T00:00:00", "2012-04-01T00:00:00", "2012-04-08T00:00:00", "2012-04-15T00:00:00", "2012-04-22T00:00:00", "2012-04-29T00:00:00", "2012-05-06T00:00:00", "2012-05-13T00:00:00", "2012-05-20T00:00:00", "2012-05-27T00:00:00", "2012-06-03T00:00:00", "2012-06-10T00:00:00", "2012-06-17T00:00:00", "2012-06-24T00:00:00", "2012-07-01T00:00:00", "2012-07-08T00:00:00", "2012-07-15T00:00:00", "2012-07-22T00:00:00", "2012-07-29T00:00:00", "2012-08-05T00:00:00", "2012-08-12T00:00:00", "2012-08-19T00:00:00", "2012-08-26T00:00:00", "2012-09-02T00:00:00", "2012-09-09T00:00:00", "2012-09-16T00:00:00", "2012-09-23T00:00:00", "2012-09-30T00:00:00", "2012-10-07T00:00:00", "2012-10-14T00:00:00", "2012-10-21T00:00:00", "2012-10-28T00:00:00", "2012-11-04T00:00:00", "2012-11-11T00:00:00", "2012-11-18T00:00:00", "2012-11-25T00:00:00", "2012-12-02T00:00:00", "2012-12-09T00:00:00", "2012-12-16T00:00:00", "2012-12-23T00:00:00", "2012-12-30T00:00:00", "2013-01-06T00:00:00", "2013-01-13T00:00:00", "2013-01-20T00:00:00", "2013-01-27T00:00:00", "2013-02-03T00:00:00", "2013-02-10T00:00:00", "2013-02-17T00:00:00", "2013-02-24T00:00:00", "2013-03-03T00:00:00", "2013-03-10T00:00:00", "2013-03-17T00:00:00", "2013-03-24T00:00:00", "2013-03-31T00:00:00", "2013-04-07T00:00:00", "2013-04-14T00:00:00", "2013-04-21T00:00:00", "2013-04-28T00:00:00", "2013-05-05T00:00:00", "2013-05-12T00:00:00", "2013-05-19T00:00:00", "2013-05-26T00:00:00", "2013-06-02T00:00:00", "2013-06-09T00:00:00", "2013-06-16T00:00:00", "2013-06-23T00:00:00", "2013-06-30T00:00:00", "2013-07-07T00:00:00", "2013-07-14T00:00:00", "2013-07-21T00:00:00", "2013-07-28T00:00:00", "2013-08-04T00:00:00", "2013-08-11T00:00:00", "2013-08-18T00:00:00", "2013-08-25T00:00:00", "2013-09-01T00:00:00", "2013-09-08T00:00:00", "2013-09-15T00:00:00", "2013-09-22T00:00:00", "2013-09-29T00:00:00", "2013-10-06T00:00:00", "2013-10-13T00:00:00", "2013-10-20T00:00:00", "2013-10-27T00:00:00", "2013-11-03T00:00:00", "2013-11-10T00:00:00", "2013-11-17T00:00:00", "2013-11-24T00:00:00", "2013-12-01T00:00:00", "2013-12-08T00:00:00", "2013-12-15T00:00:00", "2013-12-22T00:00:00", "2013-12-29T00:00:00", "2014-01-05T00:00:00", "2014-01-12T00:00:00", "2014-01-19T00:00:00", "2014-01-26T00:00:00", "2014-02-02T00:00:00", "2014-02-09T00:00:00", "2014-02-16T00:00:00", "2014-02-23T00:00:00", "2014-03-02T00:00:00", "2014-03-09T00:00:00", "2014-03-16T00:00:00", "2014-03-23T00:00:00", "2014-03-30T00:00:00", "2014-04-06T00:00:00", "2014-04-13T00:00:00", "2014-04-20T00:00:00", "2014-04-27T00:00:00", "2014-05-04T00:00:00", "2014-05-11T00:00:00", "2014-05-18T00:00:00", "2014-05-25T00:00:00", "2014-06-01T00:00:00", "2014-06-08T00:00:00", "2014-06-15T00:00:00", "2014-06-22T00:00:00", "2014-06-29T00:00: ...

# %%
print('Seasonal Decompose on Weekly Resampled Sales')

for i in lists:
    
    sm.tsa.seasonal_decompose(sales_cat_weekly[i]).plot()
    #fig.update_layout(title_text=i)
# Out:
# Seasonal Decompose on Weekly Resampled Sales

# %% [markdown]
# **ADF TEST FOR ALL CATEGORIES and PLOTS FOR ACF AND PACF**

# %%
def performADFTest(inputData, lists=lists):
  """
  Helper Function to perform ADF Test for non-stationarity tests

  Input:
    inputData: Resampled Data
    lists: category/department names

  Output:
    Test Results
      Interpretation: p-value > 0.05 indicates failure to reject null hypothesis i.e, series is non-stationary

  """

  for i in lists:

    print('Results of Dickey-Fuller Test for : ',i)
    dftest = adfuller(inputData[i])

    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key, value in dftest[4].items():
      dfoutput['Critical Value (%s)'%key] = round(value,2)

    print(dfoutput)
    print('++++++++++++++++++++++++++++++++++++++')
    print('\n')

    fig, (ax1, ax2) = plt.subplots(nrows=2, ncols=1, figsize=(14,6), sharex=False, sharey=False)
    ax1 = plot_acf(inputData[i], lags=50, ax=ax1)
    ax2 = plot_pacf(inputData[i], lags=50, ax=ax2)
    plt.show()

# %%
performADFTest(sales_cat_weekly)
# Out:
# Results of Dickey-Fuller Test for :  FOODS
# Test Statistic                  -2.042534
# p-value                          0.268240
# #Lags Used                      16.000000
# Number of Observations Used    252.000000
# Critical Value (1%)             -3.460000
# Critical Value (5%)             -2.870000
# Critical Value (10%)            -2.570000
# dtype: float64
# ++++++++++++++++++++++++++++++++++++++
# Results of Dickey-Fuller Test for :  HOBBIES
# Test Statistic                  -1.418464
# p-value                          0.573393
# #Lags Used                       3.000000
# Number of Observations Used    265.000000
# Critical Value (1%)             -3.460000
# Critical Value (5%)             -2.870000
# Critical Value (10%)            -2.570000
# dtype: float64
# ++++++++++++++++++++++++++++++++++++++
# Results of Dickey-Fuller Test for :  HOUSEHOLD
# Test Statistic                  -1.323889
# p-value                          0.618173
# #Lags Used                      12.000000
# Number of Observations Used    256.000000
# Critical Value (1%)             -3.460000
# Critical Value (5%)             -2.870000
# Critical Value (10%)            -2.570000
# dtype: float64
# ++++++++++++++++++++++++++++++++++++++

# %%
sales_cat_weekly_food = sales_cat_weekly['FOODS']
sales_cat_weekly_house = sales_cat_weekly['HOUSEHOLD']
sales_cat_weekly_hobbies = sales_cat_weekly['HOBBIES']

# %%
# Apply differentiation based on ACF - PACF plots

sales_cat_weekly_food_diff = sales_cat_weekly_food.diff(2)
sales_cat_weekly_house_diff = sales_cat_weekly_house.diff(1)
sales_cat_weekly_hobbies_diff = sales_cat_weekly_hobbies.diff(1)
sales_cat_weekly_food_diff = sales_cat_weekly_food_diff.dropna()
sales_cat_weekly_house_diff = sales_cat_weekly_house_diff.dropna()
sales_cat_weekly_hobbies_diff = sales_cat_weekly_hobbies_diff.dropna()

# %%
lists = [sales_cat_weekly_food_diff,sales_cat_weekly_house_diff,sales_cat_weekly_hobbies_diff]

for i in lists:

  print('Results of Dickey-Fuller Test for : ',i.name)
  dftest = adfuller(i)

  dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
  for key, value in dftest[4].items():
    dfoutput['Critical Value (%s)'%key] = round(value,2)

  print(dfoutput)
  print('++++++++++++++++++++++++++++++++++++++')
  print('\n')

  fig, (ax1, ax2) = plt.subplots(nrows=2, ncols=1, figsize=(14,6), sharex=False, sharey=False)
  ax1 = plot_acf(i, lags=50, ax=ax1)
  ax2 = plot_pacf(i, lags=50, ax=ax2)
  plt.show()
# Out:
# Results of Dickey-Fuller Test for :  FOODS
# Test Statistic                  -4.641156
# p-value                          0.000108
# #Lags Used                      13.000000
# Number of Observations Used    253.000000
# Critical Value (1%)             -3.460000
# Critical Value (5%)             -2.870000
# Critical Value (10%)            -2.570000
# dtype: float64
# ++++++++++++++++++++++++++++++++++++++
# Results of Dickey-Fuller Test for :  HOUSEHOLD
# Test Statistic                -6.607054e+00
# p-value                        6.516829e-09
# #Lags Used                     1.100000e+01
# Number of Observations Used    2.560000e+02
# Critical Value (1%)           -3.460000e+00
# Critical Value (5%)           -2.870000e+00
# Critical Value (10%)          -2.570000e+00
# dtype: float64
# ++++++++++++++++++++++++++++++++++++++
# Results of Dickey-Fuller Test for :  HOBBIES
# Test Statistic                -1.424993e+01
# p-value                        1.487108e-26
# #Lags Used                     2.000000e+00
# Number of Observations Used    2.650000e+02
# Critical Value (1%)           -3.460000e+00
# Critical Value (5%)           -2.870000e+00
# Critical Value (10%)          -2.570000e+00
# dtype: float64
# ++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# ## Train ARIMA

# %%
# Perform Train Test Splits
train = sales_cat_weekly[:int(0.98*(len(sales_cat_weekly)))]
test = sales_cat_weekly[int(0.98*(len(sales_cat_weekly))):]

# %%
# evaluate an ARIMA model for a given order (p,d,q) using Sliding Window Approach
def evaluate_arima_model(train_set, test_set, arima_order,category='FOODS',logTransformation=False):
  """
  Helper function to evaluate ARIMA Model

  Input: 
    train_set: Train dataframe
    test_set: Test dataframe
    arima_order: order in format (p,d,q)
    category: available choices are FOODS, HOBBIES, HOUSEHOLD

  Output: RMSE score and model fit object for diagnostics
  """

  
  train = train_set[category]

  if logTransformation: # Applying Log transformation for multipicative series
    train = np.log(train)

  test = test_set[category]
  history = [x for x in train]
  
  # make predictions with Walk Forward Evaluation
  predictions = list() 
  for t in range(len(test)):
    model = ARIMA(history, order=arima_order)
    model_fit = model.fit()
    yhat = model_fit.forecast()[0]
    predictions.append(yhat)
    if logTransformation:
      history.append(np.log(test[t]))
    else:
      history.append(test[t])
  # calculate out of sample error

  if logTransformation:
    predictions = np.exp(predictions) # transform forecast back to non-log scale

  error = sqrt(mean_squared_error(test, predictions))
  return error, model_fit

# %%
def modelSummary(originalDF, test_set, category, results, model="arima",logTransformation=False, showConf=True):
  
  """
  Helper Function to show model performance

  Input:
    originalDF: Complete resampled dataframe(daily/weekly/monthly)
    test_set: Test Dataframe containing actual values
    category: available choices are FOODS, HOBBIES, HOUSEHOLD
    results: Model fit argument from evaluation phase

  Output: Shows complete summary along with evaluation plots

  """
  # Result Summary
  print(results.summary())

  # Show complete Diagnostic
  results.plot_diagnostics(figsize=(16, 8))
  plt.savefig('modeldiagnostics')
  plt.show()

  # Get Forecasts
  if model == "arima":
    forecast_object = results.get_forecast(steps=len(test_set))
  elif model == "sarimax":
    forecast_object = results.get_forecast(steps=len(test_set), exog=test_set[exog_list])
  mean = forecast_object.predicted_mean
  conf_int = pd.DataFrame(forecast_object.conf_int())

  if logTransformation: # Transform back to non-log scale
    mean = np.exp(mean)
    conf_int = np.exp(conf_int)
  
  # Plot graph for model evaluation
  plt.figure(figsize=(16,8))

  # Plot original series
  plt.plot(originalDF.index, originalDF[category], label='real')

  # Plot the prediction means as line
  plt.plot(test_set.index, mean, label='predicted')

  # Shade between the confidence intervals
  if showConf:
    plt.fill_between(test_set.index, conf_int.iloc[:,0], conf_int.iloc[:,1],alpha=0.2)

  # Plot legend and show figure
  plt.legend()
  plt.title("Result for "+category+" : "+model+" model")
  plt.xlabel("Timestamp")
  plt.ylabel("Aggregated Sales")
  plt.savefig('predtest_'+category)
  plt.show()

# %%
# Training for ARIMA model using pmdarima library
def trainAutoARIMA(train_set, category, logTransformation=False, param_p=0, param_d=2, param_q=0):
  """
  Helper function to train Auto Arima

  Input: 
    train_set: Train Dataframe
    category: available choices are FOODS, HOBBIES, HOUSEHOLD
    param_p: p for order (p,d,q)
    param_d: d for order (p,d,q)
    param_q: q for order (p,d,q)

  Output: Returns Best Model based on best AIC scores

  """
  if logTransformation: # Apply log transformation for additive series
    train_set[category] = np.log(train_set[category])

  model_a = pm.auto_arima(train_set[category], d=param_d,
                        seasonal=False, trend='c', 
                        start_p=param_p, start_q=param_q, max_order=6, test='adf', 
                        stepwise=True, trace=True)
  return model_a

# %%
# Training for ARIMA using GridSearch based approach(performs slower than Auto ARIMA but capable of better results)
def trainARIMAGridSearch(train_set, test_set, category, p_values, d_values, q_values, logTransformation=False):
  """
  Helper function to train ARIMA using Grid Search

  Input:
    train_set: Train dataframe
    test_set: Test Dataframe
    category: available choices are FOODS, HOBBIES, HOUSEHOLD
    p_values: a list
    d_values: a list
    q_values: a list

  Output:
    Returns the model with best RMSE score

  """
  best_score, best_cfg = float("inf"), None # Initialization
  best_model = None
  for p in p_values:
    for d in d_values:
      for q in q_values:
        order = (p,d,q)
        try:
          [rmse,model_fit] = evaluate_arima_model(train_set, test_set, order,category,logTransformation)
          if rmse < best_score:
            best_score, best_cfg = rmse, order
            print('ARIMA%s RMSE=%.3f' % (order,rmse))
            best_model = model_fit
        except:
          continue
  print('Best ARIMA%s RMSE=%.3f' % (best_cfg, best_score))
  return(best_model)

# %% [markdown]
# ### FOODS

# %%
sales_cat_weekly.FOODS.describe()
# Out:
# count       269.000000
# mean     166428.460967
# std       22526.638756
# min      100337.000000
# 25%      153994.000000
# 50%      170327.000000
# 75%      180856.000000
# max      225812.000000
# Name: FOODS, dtype: float64

# %%
#sales_cat_weekly.FOODS.plot()
train.FOODS.plot()
test.FOODS.plot()

# %%
transformLog_flag = False

# %%
# Train using Auto Arima
model_food = trainAutoARIMA(train.copy(),'FOODS', logTransformation = transformLog_flag)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,2,0)(0,0,0)[0] intercept   : AIC=5985.937, Time=0.06 sec
#  ARIMA(1,2,0)(0,0,0)[0] intercept   : AIC=5981.485, Time=0.04 sec
#  ARIMA(0,2,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.25 sec
#  ARIMA(0,2,0)(0,0,0)[0]             : AIC=5985.937, Time=0.02 sec
#  ARIMA(2,2,0)(0,0,0)[0] intercept   : AIC=5900.881, Time=0.10 sec
#  ARIMA(3,2,0)(0,0,0)[0] intercept   : AIC=5674.390, Time=0.21 sec
#  ARIMA(4,2,0)(0,0,0)[0] intercept   : AIC=5647.003, Time=0.30 sec
#  ARIMA(5,2,0)(0,0,0)[0] intercept   : AIC=5650.335, Time=0.34 sec
#  ARIMA(4,2,1)(0,0,0)[0] intercept   : AIC=inf, Time=1.02 sec
#  ARIMA(3,2,1)(0,0,0)[0] intercept   : AIC=5611.864, Time=0.43 sec
#  ARIMA(2,2,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.60 sec
#  ARIMA(3,2,2)(0,0,0)[0] intercept   : AIC=5631.050, Time=0.69 sec
#  ARIMA(2,2,2)(0,0,0)[0] intercept   : AIC=5679.543, Time=0.66 sec
#  ARIMA(4,2,2)(0,0,0)[0] intercept   : AIC=5646.221, Time=1.13 sec
#  ARIMA(3,2,1)(0,0,0)[0]             : AIC=5611.864, Time=0.42 sec
#
# Best model:  ARIMA(3,2,1)(0,0,0)[0]
# Total fit time: 6.278 seconds

# %%
[rmse_foods, results_foods] = evaluate_arima_model(train.copy(), test.copy(), model_food.get_params()['order'], 
                                                   'FOODS',logTransformation = transformLog_flag)
print(rmse_foods)
# Out:
# 9802.528686386711

# %%
modelSummary(sales_cat_weekly, test, 'FOODS', results_foods, logTransformation = transformLog_flag)
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  268
# Model:                 ARIMA(3, 2, 1)   Log Likelihood               -2853.150
# Date:                Sat, 30 Oct 2021   AIC                           5716.299
# Time:                        16:32:10   BIC                           5734.217
# Sample:                             0   HQIC                          5723.497
#                                 - 268
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.3093      0.023    -13.510      0.000      -0.354      -0.264
# ar.L2         -0.6337      0.030    -21.087      0.000      -0.693      -0.575
# ar.L3         -0.5186      0.042    -12.476      0.000      -0.600      -0.437
# ma.L1         -0.9504      0.024    -38.863      0.000      -0.998      -0.902
# sigma2      1.149e+08   1.07e-10   1.07e+18      0.000    1.15e+08    1.15e+08
# ===================================================================================
# Ljung-Box (L1) (Q):                   5.32   Jarque-Bera (JB):               291.69
# Prob(Q):                              0.02   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.45   Skew:                            -0.83
# Prob(H) (two-sided):                  0.00   Kurtosis:                         7.86
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 9.74e+31. Standard errors may be unstable.

# %%
# Train using gridsearch

# parameters
p_values = range(0,7)
d_values = range(0, 4)
q_values = range(0, 4)
warnings.filterwarnings("ignore")

results_foods_gs = trainARIMAGridSearch(train.copy(), test.copy(), 'FOODS',p_values,d_values,q_values, logTransformation = transformLog_flag)
# Out:
# ARIMA(0, 0, 0) RMSE=41434.930
# ARIMA(0, 0, 1) RMSE=27616.879
# ARIMA(0, 0, 2) RMSE=21664.494
# ARIMA(0, 0, 3) RMSE=21092.094
# ARIMA(0, 1, 0) RMSE=15223.920
# ARIMA(0, 1, 2) RMSE=14697.310
# ARIMA(0, 2, 3) RMSE=13722.273
# ARIMA(0, 3, 3) RMSE=11849.415
# ARIMA(2, 1, 2) RMSE=6304.814
# ARIMA(4, 2, 3) RMSE=6217.832
# Best ARIMA(4, 2, 3) RMSE=6217.832

# %%
modelSummary(sales_cat_weekly, test.copy(), 'FOODS', results_foods_gs, logTransformation = transformLog_flag)
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  268
# Model:                 ARIMA(4, 2, 3)   Log Likelihood               -2838.849
# Date:                Mon, 01 Nov 2021   AIC                           5693.697
# Time:                        01:41:01   BIC                           5722.365
# Sample:                             0   HQIC                          5705.214
#                                 - 268
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.0842      0.036      2.353      0.019       0.014       0.154
# ar.L2         -0.9185      0.045    -20.442      0.000      -1.007      -0.830
# ar.L3         -0.1689      0.034     -4.976      0.000      -0.235      -0.102
# ar.L4          0.0256      0.042      0.614      0.539      -0.056       0.107
# ma.L1         -1.1732      0.032    -36.627      0.000      -1.236      -1.110
# ma.L2          1.0602      0.035     30.404      0.000       0.992       1.129
# ma.L3         -0.8824      0.028    -31.661      0.000      -0.937      -0.828
# sigma2      7.342e+07   2.27e-10   3.23e+17      0.000    7.34e+07    7.34e+07
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.25   Jarque-Bera (JB):               248.44
# Prob(Q):                              0.26   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.37   Skew:                            -0.99
# Prob(H) (two-sided):                  0.00   Kurtosis:                         7.30
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 5.94e+32. Standard errors may be unstable.

# %% [markdown]
# ### HOBBIES

# %%
sales_cat_weekly.HOBBIES.describe()
# Out:
# count      269.000000
# mean     22569.717472
# std       3585.786673
# min      13504.000000
# 25%      19761.000000
# 50%      22647.000000
# 75%      25464.000000
# max      30690.000000
# Name: HOBBIES, dtype: float64

# %%
train.HOBBIES.plot()
test.HOBBIES.plot()

# %%
transformLog_flag = True

# %%
model_hobbies = trainAutoARIMA(train.copy(), 'HOBBIES', logTransformation = transformLog_flag)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,2,0)(0,0,0)[0] intercept   : AIC=-242.303, Time=0.07 sec
#  ARIMA(1,2,0)(0,0,0)[0] intercept   : AIC=-398.826, Time=0.12 sec
#  ARIMA(0,2,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.44 sec
#  ARIMA(0,2,0)(0,0,0)[0]             : AIC=-242.303, Time=0.10 sec
#  ARIMA(2,2,0)(0,0,0)[0] intercept   : AIC=-446.904, Time=0.14 sec
#  ARIMA(3,2,0)(0,0,0)[0] intercept   : AIC=-483.926, Time=0.43 sec
#  ARIMA(4,2,0)(0,0,0)[0] intercept   : AIC=-506.610, Time=0.37 sec
#  ARIMA(5,2,0)(0,0,0)[0] intercept   : AIC=-515.951, Time=0.51 sec
#  ARIMA(5,2,1)(0,0,0)[0] intercept   : AIC=-571.943, Time=1.22 sec
#  ARIMA(4,2,1)(0,0,0)[0] intercept   : AIC=-578.283, Time=1.07 sec
#  ARIMA(3,2,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.82 sec
#  ARIMA(4,2,2)(0,0,0)[0] intercept   : AIC=-572.745, Time=1.11 sec
#  ARIMA(3,2,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.99 sec
#  ARIMA(5,2,2)(0,0,0)[0] intercept   : AIC=inf, Time=1.31 sec
#  ARIMA(4,2,1)(0,0,0)[0]             : AIC=-578.283, Time=1.10 sec
#
# Best model:  ARIMA(4,2,1)(0,0,0)[0] intercept
# Total fit time: 9.832 seconds

# %%
[rmse_hobbies, results_hobbies] = evaluate_arima_model(train.copy(), test.copy(), model_hobbies.get_params()['order'], 
                                                       'HOBBIES', logTransformation = transformLog_flag)
print(rmse_hobbies)
# Out:
# Log Transformation enabled for  HOBBIES
# 712.3897347204284

# %%
modelSummary(sales_cat_weekly, test.copy(), 'HOBBIES', results_hobbies, logTransformation = transformLog_flag)
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  268
# Model:                 ARIMA(4, 2, 1)   Log Likelihood                 307.221
# Date:                Sat, 30 Oct 2021   AIC                           -602.442
# Time:                        17:30:08   BIC                           -580.941
# Sample:                             0   HQIC                          -593.804
#                                 - 268
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.5879      0.042    -14.139      0.000      -0.669      -0.506
# ar.L2         -0.3110      0.069     -4.537      0.000      -0.445      -0.177
# ar.L3         -0.2470      0.048     -5.101      0.000      -0.342      -0.152
# ar.L4         -0.0982      0.041     -2.400      0.016      -0.178      -0.018
# ma.L1         -0.9996      0.533     -1.876      0.061      -2.044       0.045
# sigma2         0.0056      0.003      1.841      0.066      -0.000       0.012
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.02   Jarque-Bera (JB):               114.18
# Prob(Q):                              0.88   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.51   Skew:                            -0.13
# Prob(H) (two-sided):                  0.00   Kurtosis:                         6.20
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
# Train using gridsearch

# parameters
p_values = range(0,7)
d_values = range(0, 4)
q_values = range(0, 4)
warnings.filterwarnings("ignore")

results_hobbies_gs = trainARIMAGridSearch(train.copy(), test.copy(), 'HOBBIES',p_values,d_values,q_values, logTransformation = transformLog_flag)
# Out:
# Log Transformation enabled for  HOBBIES
# ARIMA(0, 0, 0) RMSE=6033.481
# Log Transformation enabled for  HOBBIES
# ARIMA(0, 0, 1) RMSE=4031.374
# Log Transformation enabled for  HOBBIES
# ARIMA(0, 0, 2) RMSE=2923.697
# Log Transformation enabled for  HOBBIES
# ARIMA(0, 0, 3) RMSE=2539.599
# Log Transformation enabled for  HOBBIES
# ARIMA(0, 1, 0) RMSE=787.972
# Log Transformation enabled for  HOBBIES
# Log Transformation enabled for  HOBBIES
# Log Transformation enabled for  HOBBIES
# Log Transformation enabled for  HOBBIES
# Log Transformation enabled for  HOBBIES
# ARIMA(0, 2, 1) RMSE=786.991
# Log Transformation enabled for  HOBBIES
# ARIMA(0, 2, 2) RMSE=769.395
# Log Transformation enabled for  HOBBIES
# Log Transformation enabled for  HOBBIES
# Log Transformation enabled for  HOBBIES
# Log Transformation enabled for  HOBBIES
# Log Transformation enabled for  HOBBIES
# ARIMA(0, 3, 3) RMSE=701.475
# Log Transformation enabled for  HOBBIES
# Log Transformation enabled for  HOBBIES
# Log Transformation enabled for  HOBBIES
# Log Transformation enabled for  HOBBIES
# Log Transformation enabled for  HOBBIES
# ARIMA(1, 1, 0) RMSE=656.426
# Log Transformation enabled for  HOBBIES
# Log Transformation enabled for  HOBBIES
# Log Transformation enabled for  HOBBIES
# Log Transformation enabled for  HOBBIES
# Log Transformation enabled for  HOBBIES
# ARIMA(1, 2, 1) RMSE=633.634
# Log Transformation enabled for  HOBBIES
# Log Transformation enabled for  HOBBIES
# Log Transformation enabled for  HOBBIES
# Log Transformation enabled for  HOBBIES
# Log Transformation enabled for  HOBBIES
# Log Transformation enabled for  HOBBIES
# Log Transformation enabled for  HOBBIES
# Log Transformation enabled for  HOBBIES
# Log Transformation enabled for  HOBBIES
# Log Transformation enabled for  HOBBIES
# Log Transformation enabled for  HOBBIES
# Log Transformation enabled for  HOBBIES
# Log Transformation enabled for  HOBBIES
# Log Transformation enabled for  HOBBIES
# Log Transformation enabled for  HOBBIES
# Log Transformation enabled for  HOBBIES
# Log Transformation enabled for  HOBBIES
# Log Transformation enabled for  HOBBIES
# Log Transformation enabled for  HOBBIES
# Log Transformation enabled for  HOBBIES
# Log Transformation enabled for  HOBBIES
# Log Transformation enabled for  HOBBIES
# ARIMA(2, 3, 3) RMSE=597.855
# Log Transformation enabled for  HOBBIES
# Log Transformation enabled for  HOBBIES
# Log Transformation enabled for  HOBBIES
# Log Transformation enabled for  HOBBIES
# Log Transformation enabled for  HOBBIES
# Log Transformation enabled for  HOBBIES
# Log Transformation enabled for  HOBBIES
# Log Transformation enabled for  HOBBIES
# Log Transformation enabled for  HOBBIES
# ARIMA(3, 2, 0) RMSE=554.810
# Log Transformation enabled for  HOBBIES
# Log Transformation enabled for  HOBBIES
# Log Transformation enabled for  HOBBIES
# Log Transformation enabled for  HOBBIES
# Log Transformation enabled for  HOBBIES
# Log Transformation enabled for  HOBBIES
# Log Transformation enabled for  HOBBIES
# Log Transformation enabled for  HOBBIES
# Log Transformation enabled for  HOBBIES
# Log Transformation enabled for  HOBBIES
# Log Transformation enabled for  HOBBIES
# Log Transformation enabled for  HOBBIES
# Log Transformation enabled for  HOBBIES
# Log Transformation enabled for  HOBBIES
# Log Transformation enabled for  HOBBIES
# Log Transformation enabled for  HOBBIES
# ARIMA(4, 2, 0) RMSE=466.828
# Log Transformation enabled for  HOBBIES
# Log Transformation enabled for  HOBBIES
# Log Transformation enabled for  HOBBIES
# Log Transformation enabled for  HOBBIES
# Log Transformation enabled for  HOBBIES
# Log Transformation enabled for  HOBBIES
# Log Transformation enabled for  HOBBIES
# Log Transformation enabled for  HOBBIES
# Log Transformation enabled for  HOBBIES
# Log Transformation enabled for  HOBBIES
# Log Transformation enabled for  HOBBIES
# Log Transformation enabled for  HOBBIES
# Log Transformation enabled for  HOBBIES
# Log Transformation enabled for  HOBBIES
# Log Transformation enabled for  HOBBIES
# Log Transformation enabled for  HOBBIES
# Log Transformation enabled for  HOBBIES
# Log Transformation enabled for  HOBBIES
# Log Transformation enabled for  HOBBIES
# Log Transformation enabled for  HOBBIES
# Log Transformation enabled for  HOBBIES
# Log Transformation enabled for  HOBBIES
# Log Transformation enabled for  HOBBIES
# Log Transformation enabled for  HOBBIES
# Log Transformation enabled for  HOBBIES
# Log Transformation enabled for  HOBBIES
# Log Transformation enabled for  HOBBIES
# Log Transformation enabled for  HOBBIES
# Log Transformation enabled for  HOBBIES
# Log Transformation enabled for  HOBBIES
# Log Transformation enabled for  HOBBIES
# Log Transformation enabled for  HOBBIES
# Log Transformation enabled for  HOBBIES
# Log Transformation enabled for  HOBBIES
# Log Transformation enabled for  HOBBIES
# Log Transformation enabled for  HOBBIES
# Log Transformation enabled for  HOBBIES
# Log Transformation enabled for  HOBBIES
# Log Transformation enabled for  HOBBIES
# Best ARIMA(4, 2, 0) RMSE=466.828

# %%
modelSummary(sales_cat_weekly, test.copy(), 'HOBBIES', results_hobbies_gs, logTransformation = transformLog_flag)
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  268
# Model:                 ARIMA(4, 2, 0)   Log Likelihood                 266.714
# Date:                Mon, 01 Nov 2021   AIC                           -523.429
# Time:                        01:47:18   BIC                           -505.511
# Sample:                             0   HQIC                          -516.231
#                                 - 268
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -1.2302      0.047    -25.962      0.000      -1.323      -1.137
# ar.L2         -1.0143      0.072    -14.021      0.000      -1.156      -0.873
# ar.L3         -0.7117      0.071    -10.061      0.000      -0.850      -0.573
# ar.L4         -0.3017      0.052     -5.748      0.000      -0.405      -0.199
# sigma2         0.0078      0.000     17.514      0.000       0.007       0.009
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.00   Jarque-Bera (JB):               101.62
# Prob(Q):                              0.32   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.45   Skew:                             0.04
# Prob(H) (two-sided):                  0.00   Kurtosis:                         6.03
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# ### HOUSEHOLDS

# %%
sales_cat_weekly.HOUSEHOLD.describe()
# Out:
# count      269.000000
# mean     53721.802974
# std      11577.713712
# min      27146.000000
# 25%      46174.000000
# 50%      55698.000000
# 75%      61994.000000
# max      75163.000000
# Name: HOUSEHOLD, dtype: float64

# %%
train.HOUSEHOLD.plot()
test.HOUSEHOLD.plot()

# %%
transformLog_flag = True

# %%
model_household = trainAutoARIMA(train.copy(), 'HOUSEHOLD', logTransformation = transformLog_flag)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,2,0)(0,0,0)[0] intercept   : AIC=-360.974, Time=0.06 sec
#  ARIMA(1,2,0)(0,0,0)[0] intercept   : AIC=-528.243, Time=0.07 sec
#  ARIMA(0,2,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.57 sec
#  ARIMA(0,2,0)(0,0,0)[0]             : AIC=-360.974, Time=0.08 sec
#  ARIMA(2,2,0)(0,0,0)[0] intercept   : AIC=-559.300, Time=0.17 sec
#  ARIMA(3,2,0)(0,0,0)[0] intercept   : AIC=-622.363, Time=0.31 sec
#  ARIMA(4,2,0)(0,0,0)[0] intercept   : AIC=-665.353, Time=0.48 sec
#  ARIMA(5,2,0)(0,0,0)[0] intercept   : AIC=-667.290, Time=0.62 sec
#  ARIMA(5,2,1)(0,0,0)[0] intercept   : AIC=-680.818, Time=1.31 sec
#  ARIMA(4,2,1)(0,0,0)[0] intercept   : AIC=-679.100, Time=1.04 sec
#  ARIMA(5,2,2)(0,0,0)[0] intercept   : AIC=-692.759, Time=1.38 sec
#  ARIMA(4,2,2)(0,0,0)[0] intercept   : AIC=-686.323, Time=1.23 sec
#  ARIMA(5,2,3)(0,0,0)[0] intercept   : AIC=-652.866, Time=1.60 sec
#  ARIMA(4,2,3)(0,0,0)[0] intercept   : AIC=-688.583, Time=1.21 sec
#  ARIMA(5,2,2)(0,0,0)[0]             : AIC=-692.759, Time=1.40 sec
#
# Best model:  ARIMA(5,2,2)(0,0,0)[0] intercept
# Total fit time: 11.534 seconds

# %%
[rmse_household, results_household] = evaluate_arima_model(train.copy(), test.copy(), model_household.get_params()['order'], 
                                                           'HOUSEHOLD', logTransformation = transformLog_flag)
print(rmse_household)
# Out:
# Log Transformation enabled for  HOUSEHOLD
# 2532.6308809215525

# %%
modelSummary(sales_cat_weekly, test, 'HOUSEHOLD', results_household, logTransformation = transformLog_flag)
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  268
# Model:                 ARIMA(5, 2, 2)   Log Likelihood                 366.921
# Date:                Sat, 30 Oct 2021   AIC                           -717.842
# Time:                        17:41:56   BIC                           -689.174
# Sample:                             0   HQIC                          -706.325
#                                 - 268
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -1.2730      0.121    -10.555      0.000      -1.509      -1.037
# ar.L2         -0.5406      0.105     -5.137      0.000      -0.747      -0.334
# ar.L3         -0.2974      0.105     -2.843      0.004      -0.502      -0.092
# ar.L4          0.0098      0.113      0.087      0.931      -0.211       0.231
# ar.L5          0.1882      0.063      2.973      0.003       0.064       0.312
# ma.L1         -0.1816      0.128     -1.424      0.154      -0.432       0.068
# ma.L2         -0.8109      0.117     -6.925      0.000      -1.040      -0.581
# sigma2         0.0036      0.000     10.454      0.000       0.003       0.004
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.12   Jarque-Bera (JB):                15.94
# Prob(Q):                              0.73   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.68   Skew:                             0.57
# Prob(H) (two-sided):                  0.07   Kurtosis:                         3.38
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
# Train using gridsearch

# parameters
p_values = range(0,7)
d_values = range(0, 4)
q_values = range(0, 4)
warnings.filterwarnings("ignore")

results_household_gs = trainARIMAGridSearch(train.copy(), test.copy(), 'HOUSEHOLD',p_values,d_values,q_values, logTransformation = transformLog_flag)
# Out:
# ARIMA(0, 0, 0) RMSE=17824.416
# ARIMA(0, 0, 1) RMSE=10723.707
# ARIMA(0, 0, 2) RMSE=7846.898
# ARIMA(0, 0, 3) RMSE=6493.357
# ARIMA(0, 1, 0) RMSE=2505.612
# ARIMA(0, 1, 1) RMSE=2210.714
# ARIMA(5, 1, 3) RMSE=2139.595
# ARIMA(6, 2, 1) RMSE=2130.081
# Best ARIMA(6, 2, 1) RMSE=2130.081

# %%
modelSummary(sales_cat_weekly, test.copy(), 'HOUSEHOLD', results_household_gs, logTransformation = transformLog_flag)
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  268
# Model:                 ARIMA(6, 2, 1)   Log Likelihood                 363.453
# Date:                Mon, 01 Nov 2021   AIC                           -710.907
# Time:                        01:43:46   BIC                           -682.239
# Sample:                             0   HQIC                          -699.390
#                                 - 268
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.4857      0.047    -10.339      0.000      -0.578      -0.394
# ar.L2         -0.2004      0.060     -3.333      0.001      -0.318      -0.083
# ar.L3         -0.2207      0.066     -3.334      0.001      -0.350      -0.091
# ar.L4          0.1365      0.073      1.872      0.061      -0.006       0.279
# ar.L5          0.1451      0.063      2.306      0.021       0.022       0.268
# ar.L6         -0.0638      0.057     -1.117      0.264      -0.176       0.048
# ma.L1         -0.9710      0.032    -30.152      0.000      -1.034      -0.908
# sigma2         0.0033      0.000     13.019      0.000       0.003       0.004
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.09   Jarque-Bera (JB):                19.08
# Prob(Q):                              0.77   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.67   Skew:                             0.61
# Prob(H) (two-sided):                  0.06   Kurtosis:                         3.49
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# ## SARIMAX Training

# %%
def trainSeasonalAutoARIMA(train_set, category, tr='t', param_p=5, param_d=2, param_q=3, param_D=1,logTransformation = False):
  """
  Helper function to train Seasonal Auto Arima

  Input: 
    train_set: Train Dataframe
    category: available choices are FOODS, HOBBIES, HOUSEHOLD
    tr: parameter to specify trend ('c', 't', 'ct')
    param_p: p for order (p,d,q)
    param_d: d for order (p,d,q)
    param_q: q for order (p,d,q)
    param_D: D for order (P,D,Q,m)

  Output: Returns Best Model based on best AIC scores

  """
  if logTransformation:
    train_set[category] = np.log(train_set[category])

  model_b = pm.auto_arima(y=train_set[category], X= train_set[exog_list], d=param_d, D=param_D,
                      seasonal=True, m=12, trend=tr, start_p=0, start_q=0,
                      max_p=param_p, max_q=param_q, max_order=8, test='adf', stepwise=True, 
                      trace=True, n_jobs=-1 )
  return model_b

# %%
# Training for ARIMA using GridSearch based approach(performs slower than Auto ARIMA but capable of better results)
def trainSeasonalARIMAGridSearch(train_set, test_set, category, p_values, d_values, q_values, t_params, 
                                 P_values, D_values, Q_values, logTransformation = False):
  """
  Helper function to train ARIMA using Grid Search

  Input:
    train_set: Train dataframe
    test_set: Test Dataframe
    category: available choices are FOODS, HOBBIES, HOUSEHOLD
    p_values: a list
    d_values: a list
    q_values: a list

  Output:
    Returns the model with best RMSE score

  """
  best_score, best_cfg = float("inf"), None 
  best_model = None
  for p in p_values:
    for d in d_values:
      for q in q_values:
        for t in t_params:
          for P in P_values:
            for D in D_values:
              for Q in Q_values:
                order = [(p,d,q), (P,D,Q,12), t]
                try:
                  #print('Fitting for ',order)
                  [rmse,model_fit] = evaluate_seasonal_arima_model(train_set.copy(), test_set.copy(), order,category, logTransformation)
                  if rmse < best_score:
                    best_score, best_cfg = rmse, order
                    print('SARIMAX%s RMSE=%.3f' % (order,rmse))
                    best_model = model_fit
                except:
                  continue
  print('Best SARIMAX%s RMSE=%.3f' % (best_cfg, best_score))
  return(best_model)

# %%
# evaluate an Seasonal ARIMA model with Walk Forward Evaluation
def evaluate_seasonal_arima_model(train_set, test_set, config_params,category='FOODS', logTransformation = False):
  """
  Helper function to evaluate Seasonal ARIMA Model

  Input: 
    train_set: Train dataframe
    test_set: Test dataframe
    arima_order: order in format (p,d,q)
    category: available choices are FOODS, HOBBIES, HOUSEHOLD

  Output: RMSE score and model fit object for diagnostics
  """
  
  test = test_set[category]
  order, sorder, trend = config_params
  
  if logTransformation:
    #print("Log transformation enabled with config ", config_params)
    train_set[category] = np.log(train_set[category])

  model = SARIMAX(endog=train_set[category],exog=train[exog_list],order=order,
                  seasonal_order=sorder, trend=trend)
  model_fit = model.fit()

  forecast_object = model_fit.get_forecast(steps=len(test_set), 
                                           exog=test_set[exog_list])
  mean = forecast_object.predicted_mean

  if logTransformation:
    mean = np.exp(mean)

  error = sqrt(mean_squared_error(test, mean))

  # # make predictions with Walk Forward Evaluation
  # predictions = list() 
  # for t in range(len(test)):
  #   model = SARIMAX(endog=train_set[category], exog=train_set[exog_list], order=order, seasonal_order=sorder, trend=trend)
  #   model_fit = model.fit()
  #   yhat = model_fit.predict(len(train_set), len(train_set),exog=test_set[exog_list].iloc[[t]])[0]
  #   predictions.append(yhat)
  #   train_set = train_set.append(test_set.iloc[[t]])
  # # calculate out of sample error
  # error = sqrt(mean_squared_error(test, predictions))

  return error, model_fit

# %%
train = sales_cat_weekly[:int(0.98*(len(sales_cat_weekly)))]
test = sales_cat_weekly[int(0.98*(len(sales_cat_weekly))):]

# %% [markdown]
# ### FOODS

# %%
transformLog_flag = False

# %%
sarima_model_foods = trainSeasonalAutoARIMA(train.copy(),'FOODS', logTransformation = transformLog_flag)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,2,0)(1,1,1)[12]             : AIC=inf, Time=2.05 sec
#  ARIMA(0,2,0)(0,1,0)[12]             : AIC=5889.353, Time=0.12 sec
#  ARIMA(1,2,0)(1,1,0)[12]             : AIC=5871.723, Time=1.06 sec
#  ARIMA(0,2,1)(0,1,1)[12]             : AIC=inf, Time=6.08 sec
#  ARIMA(1,2,0)(0,1,0)[12]             : AIC=5879.619, Time=0.22 sec
#  ARIMA(1,2,0)(2,1,0)[12]             : AIC=5776.957, Time=2.99 sec
#  ARIMA(1,2,0)(2,1,1)[12]             : AIC=5731.751, Time=7.01 sec
#  ARIMA(1,2,0)(1,1,1)[12]             : AIC=inf, Time=2.31 sec
#  ARIMA(1,2,0)(2,1,2)[12]             : AIC=5726.369, Time=8.22 sec
#  ARIMA(1,2,0)(1,1,2)[12]             : AIC=inf, Time=6.43 sec
#  ARIMA(0,2,0)(2,1,2)[12]             : AIC=5758.617, Time=6.53 sec
#  ARIMA(2,2,0)(2,1,2)[12]             : AIC=5675.986, Time=8.14 sec
#  ARIMA(2,2,0)(1,1,2)[12]             : AIC=inf, Time=8.09 sec
#  ARIMA(2,2,0)(2,1,1)[12]             : AIC=5683.156, Time=6.56 sec
#  ARIMA(2,2,0)(1,1,1)[12]             : AIC=5718.188, Time=3.09 sec
#  ARIMA(3,2,0)(2,1,2)[12]             : AIC=5474.982, Time=13.84 sec
#  ARIMA(3,2,0)(1,1,2)[12]             : AIC=5474.351, Time=11.98 sec
#  ARIMA(3,2,0)(0,1,2)[12]             : AIC=5472.460, Time=7.24 sec
#  ARIMA(3,2,0)(0,1,1)[12]             : AIC=5470.617, Time=3.87 sec
#  ARIMA(3,2,0)(0,1,0)[12]             : AIC=5578.436, Time=0.85 sec
#  ARIMA(3,2,0)(1,1,1)[12]             : AIC=5472.489, Time=4.74 sec
#  ARIMA(3,2,0)(1,1,0)[12]             : AIC=5509.971, Time=2.85 sec
#  ARIMA(2,2,0)(0,1,1)[12]             : AIC=5716.204, Time=2.25 sec
#  ARIMA(4,2,0)(0,1,1)[12]             : AIC=5399.578, Time=5.45 sec
#  ARIMA(4,2,0)(0,1,0)[12]             : AIC=5517.949, Time=1.40 sec
#  ARIMA(4,2,0)(1,1,1)[12]             : AIC=5400.422, Time=5.69 sec
#  ARIMA(4,2,0)(0,1,2)[12]             : AIC=5400.094, Time=8.18 sec
#  ARIMA(4,2,0)(1,1,0)[12]             : AIC=5446.513, Time=3.28 sec
#  ARIMA(4,2,0)(1,1,2)[12]             : AIC=5401.728, Time=13.01 sec
#  ARIMA(5,2,0)(0,1,1)[12]             : AIC=5398.423, Time=5.69 sec
#  ARIMA(5,2,0)(0,1,0)[12]             : AIC=5517.709, Time=1.60 sec
#  ARIMA(5,2,0)(1,1,1)[12]             : AIC=5398.997, Time=7.64 sec
#  ARIMA(5,2,0)(0,1,2)[12]             : AIC=5398.634, Time=10.75 sec
#  ARIMA(5,2,0)(1,1,0)[12]             : AIC=5443.855, Time=3.95 sec
#  ARIMA(5,2,0)(1,1,2)[12]             : AIC=5400.323, Time=15.21 sec
#  ARIMA(5,2,1)(0,1,1)[12]             : AIC=inf, Time=6.11 sec
#  ARIMA(4,2,1)(0,1,1)[12]             : AIC=5385.200, Time=4.72 sec
#  ARIMA(4,2,1)(0,1,0)[12]             : AIC=inf, Time=3.82 sec
#  ARIMA(4,2,1)(1,1,1)[12]             : AIC=5386.433, Time=6.68 sec
#  ARIMA(4,2,1)(0,1,2)[12]             : AIC=5386.260, Time=9.20 sec
#  ARIMA(4,2,1)(1,1,0)[12]             : AIC=inf, Time=6.80 sec
#  ARIMA(4,2,1)(1,1,2)[12]             : AIC=5388.112, Time=13.45 sec
#  ARIMA(3,2,1)(0,1,1)[12]             : AIC=5428.412, Time=3.73 sec
#  ARIMA(4,2,2)(0,1,1)[12]             : AIC=5392.651, Time=9.14 sec
#  ARIMA(3,2,2)(0,1,1)[12]             : AIC=5391.696, Time=6.45 sec
#  ARIMA(5,2,2)(0,1,1)[12]             : AIC=5369.582, Time=7.91 sec
#  ARIMA(5,2,2)(0,1,0)[12]             : AIC=inf, Time=4.84 sec
#  ARIMA(5,2,2)(1,1,1)[12]             : AIC=5370.098, Time=11.44 sec
#  ARIMA(5,2,2)(0,1,2)[12]             : AIC=5369.623, Time=19.03 sec
#  ARIMA(5,2,2)(1,1,0)[12]             : AIC=inf, Time=10.75 sec
#  ARIMA(5,2,2)(1,1,2)[12]             : AIC=5371.287, Time=19.05 sec
#  ARIMA(5,2,3)(0,1,1)[12]             : AIC=inf, Time=10.24 sec
#  ARIMA(4,2,3)(0,1,1)[12]             : AIC=5327.503, Time=9.46 sec
#  ARIMA(4,2,3)(0,1,0)[12]             : AIC=inf, Time=4.35 sec
#  ARIMA(4,2,3)(1,1,1)[12]             : AIC=5330.330, Time=10.05 sec
#  ARIMA(4,2,3)(0,1,2)[12]             : AIC=5327.973, Time=20.07 sec
#  ARIMA(4,2,3)(1,1,0)[12]             : AIC=inf, Time=10.39 sec
#  ARIMA(4,2,3)(1,1,2)[12]             : AIC=5329.895, Time=19.58 sec
#  ARIMA(3,2,3)(0,1,1)[12]             : AIC=inf, Time=8.80 sec
#  ARIMA(4,2,3)(0,1,1)[12] intercept   : AIC=5327.503, Time=9.42 sec
#
# Best model:  ARIMA(4,2,3)(0,1,1)[12] intercept
# Total fit time: 443.986 seconds

# %%
# Extract Model Parameters
order = sarima_model_foods.get_params()['order']
seasonal_order = sarima_model_foods.get_params()['seasonal_order']
trend = sarima_model_foods.get_params()['trend']

model_params = [order, seasonal_order, trend]
model_params
# Out:
# [(4, 2, 3), (0, 1, 1, 12), 't']

# %%
[rmse_sarima_foods, smodel_foods] = evaluate_seasonal_arima_model(train.copy(), test.copy(), [(4, 2, 3), (0, 1, 1, 12), 't'],
                                                                  'FOODS', logTransformation = transformLog_flag)
print(rmse_sarima_foods)
# Out:
# 4969.277016909974

# %%
modelSummary(sales_cat_weekly, test.copy(), 'FOODS', smodel_foods, model="sarimax", logTransformation = transformLog_flag)
# Out:
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:                                FOODS   No. Observations:                  263
# Model:             SARIMAX(4, 2, 3)x(0, 1, [1], 12)   Log Likelihood               -2645.752
# Date:                              Mon, 01 Nov 2021   AIC                           5327.503
# Time:                                      01:50:04   BIC                           5390.817
# Sample:                                  03-27-2011   HQIC                          5352.988
#                                        - 04-03-2016
# Covariance Type:                                opg
# ==========================================================================================
#                              coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# drift                      0.0839      0.107      0.785      0.433      -0.126       0.293
# inbetween25and5        -4221.3449   3127.253     -1.350      0.177   -1.04e+04    1907.958
# event_on_weekend        -671.7467   4101.959     -0.164      0.870   -8711.438    7367.945
# event_on_weekday        3734.6037   4479.822      0.834      0.404   -5045.686    1.25e+04
# event_type_1_Cultural   2616.4144   5068.216      0.516      0.606   -7317.106    1.25e+04
# event_type_1_National  -2797.3249   4259.521     -0.657      0.511   -1.11e+04    5551.183
# event_type_1_Religious -1482.8797   3723.890     -0.398      0.690   -8781.569    5815.810
# event_type_1_Sporting   2295.9416   5601.106      0.410      0.682   -8682.025    1.33e+04
# event_type_2_Cultural   8548.2810   1.01e+04      0.850      0.395   -1.12e+04    2.83e+04
# ar.L1                     -0.2105      0.128     -1.640      0.101      -0.462       0.041
# ar.L2                     -0.9349      0.116     -8.077      0.000      -1.162      -0.708
# ar.L3                     -0.4418      0.109     -4.041      0.000      -0.656      -0.228
# ar.L4                     -0.0574      0.130     -0.442      0.659      -0.312       0.197
# ma.L1                     -1.1065      0.092    -12.033      0.000      -1.287      -0.926
# ma.L2                      1.0021      0.088     11.411      0.000       0.830       1.174
# ma.L3                     -0.8725      0.090     -9.686      0.000      -1.049      -0.696
# ma.S.L12                  -0.7074      0.107     -6.616      0.000      -0.917      -0.498
# sigma2                   1.47e+08      0.302   4.87e+08      0.000    1.47e+08    1.47e+08
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.94   Jarque-Bera (JB):                 1.62
# Prob(Q):                              0.33   Prob(JB):                         0.44
# Heteroskedasticity (H):               0.65   Skew:                             0.16
# Prob(H) (two-sided):                  0.05   Kurtosis:                         2.76
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 3.64e+25. Standard errors may be unstable.

# %% [markdown]
# ### HOBBIES

# %%
transformLog_flag = True

# %%
sarima_model_hobbies = trainSeasonalAutoARIMA(train.copy(),'HOBBIES',tr='c', logTransformation = transformLog_flag, param_D=1, param_d=1)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(1,1,1)[12]             : AIC=inf, Time=5.20 sec
#  ARIMA(0,1,0)(0,1,0)[12]             : AIC=-320.881, Time=0.31 sec
#  ARIMA(1,1,0)(1,1,0)[12]             : AIC=-435.732, Time=5.17 sec
#  ARIMA(0,1,1)(0,1,1)[12]             : AIC=inf, Time=6.31 sec
#  ARIMA(1,1,0)(0,1,0)[12]             : AIC=-392.715, Time=0.88 sec
#  ARIMA(1,1,0)(2,1,0)[12]             : AIC=-469.641, Time=10.92 sec
#  ARIMA(1,1,0)(2,1,1)[12]             : AIC=inf, Time=12.09 sec
#  ARIMA(1,1,0)(1,1,1)[12]             : AIC=inf, Time=5.90 sec
#  ARIMA(0,1,0)(2,1,0)[12]             : AIC=-410.179, Time=6.64 sec
#  ARIMA(2,1,0)(2,1,0)[12]             : AIC=-479.069, Time=12.85 sec
#  ARIMA(2,1,0)(1,1,0)[12]             : AIC=-447.401, Time=6.10 sec
#  ARIMA(2,1,0)(2,1,1)[12]             : AIC=-530.524, Time=15.01 sec
#  ARIMA(2,1,0)(1,1,1)[12]             : AIC=inf, Time=7.28 sec
#  ARIMA(2,1,0)(2,1,2)[12]             : AIC=inf, Time=15.80 sec
#  ARIMA(2,1,0)(1,1,2)[12]             : AIC=inf, Time=13.69 sec
#  ARIMA(3,1,0)(2,1,1)[12]             : AIC=-537.282, Time=13.71 sec
#  ARIMA(3,1,0)(1,1,1)[12]             : AIC=inf, Time=6.97 sec
#  ARIMA(3,1,0)(2,1,0)[12]             : AIC=-489.144, Time=12.89 sec
#  ARIMA(3,1,0)(2,1,2)[12]             : AIC=inf, Time=14.67 sec
#  ARIMA(3,1,0)(1,1,0)[12]             : AIC=-448.303, Time=7.26 sec
#  ARIMA(3,1,0)(1,1,2)[12]             : AIC=inf, Time=14.20 sec
#  ARIMA(4,1,0)(2,1,1)[12]             : AIC=-536.401, Time=17.17 sec
#  ARIMA(3,1,1)(2,1,1)[12]             : AIC=-534.639, Time=14.23 sec
#  ARIMA(2,1,1)(2,1,1)[12]             : AIC=-527.713, Time=17.40 sec
#  ARIMA(4,1,1)(2,1,1)[12]             : AIC=-528.528, Time=18.39 sec
#  ARIMA(3,1,0)(2,1,1)[12] intercept   : AIC=-537.282, Time=13.61 sec
#
# Best model:  ARIMA(3,1,0)(2,1,1)[12] intercept
# Total fit time: 274.691 seconds

# %%
# Extract Model Parameters
order = sarima_model_hobbies.get_params()['order']
seasonal_order = sarima_model_hobbies.get_params()['seasonal_order']
trend = sarima_model_hobbies.get_params()['trend']

model_params = [order, seasonal_order, trend]
model_params
# Out:
# [(3, 1, 0), (2, 1, 1, 12), 'c']

# %%
[rmse_sarima_hobbies, smodel_hobbies] = evaluate_seasonal_arima_model(train.copy(), test.copy(), model_params,
                                                                      'HOBBIES', logTransformation = transformLog_flag)
print(rmse_sarima_hobbies)
# Out:
# 873.4392835152723

# %%
modelSummary(sales_cat_weekly, test.copy(), 'HOBBIES', smodel_hobbies, model="sarimax", logTransformation = transformLog_flag)
# Out:
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:                              HOBBIES   No. Observations:                  263
# Model:             SARIMAX(3, 1, 0)x(2, 1, [1], 12)   Log Likelihood                 284.641
# Date:                              Sat, 30 Oct 2021   AIC                           -537.282
# Time:                                      18:35:14   BIC                           -480.938
# Sample:                                  03-27-2011   HQIC                          -514.605
#                                        - 04-03-2016
# Covariance Type:                                opg
# ==========================================================================================
#                              coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# intercept                  0.0003      0.001      0.249      0.804      -0.002       0.003
# inbetween25and5           -0.0062      0.012     -0.524      0.600      -0.029       0.017
# event_on_weekend           0.0189      0.024      0.779      0.436      -0.029       0.066
# event_on_weekday           0.0247      0.025      0.968      0.333      -0.025       0.075
# event_type_1_Cultural     -0.0250      0.025     -1.005      0.315      -0.074       0.024
# event_type_1_National     -0.0551      0.024     -2.256      0.024      -0.103      -0.007
# event_type_1_Religious    -0.0069      0.023     -0.300      0.764      -0.052       0.038
# event_type_1_Sporting      0.0132      0.031      0.430      0.667      -0.047       0.073
# event_type_2_Cultural     -0.1713      0.044     -3.897      0.000      -0.257      -0.085
# ar.L1                     -0.5805      0.054    -10.815      0.000      -0.686      -0.475
# ar.L2                     -0.2965      0.067     -4.427      0.000      -0.428      -0.165
# ar.L3                     -0.1860      0.048     -3.886      0.000      -0.280      -0.092
# ar.S.L12                  -0.0394      0.083     -0.473      0.636      -0.202       0.124
# ar.S.L24                  -0.1649      0.070     -2.358      0.018      -0.302      -0.028
# ma.S.L12                  -0.8531      0.091     -9.360      0.000      -1.032      -0.675
# sigma2                     0.0055      0.000     12.373      0.000       0.005       0.006
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.09   Jarque-Bera (JB):                69.47
# Prob(Q):                              0.77   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.60   Skew:                             0.23
# Prob(H) (two-sided):                  0.02   Kurtosis:                         5.54
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
# define config lists
p_params = [0, 1, 2, 3, 4]
d_params = [0, 1, 2]
q_params = [0, 1, 2]
t_params = ['n','c','t']
P_params = [0, 1, 2]
D_params = [0, 1]
Q_params = [0, 1, 2]

smodel_hobbies_gs = trainSeasonalARIMAGridSearch(train.copy(), test.copy(), 'HOBBIES', p_params, d_params, q_params, t_params, 
                                                 P_params, D_params, Q_params, logTransformation = transformLog_flag)
# Out:
# Log transformation enabled with config  [(0, 0, 0), (0, 0, 0, 12), 'n']
# SARIMAX[(0, 0, 0), (0, 0, 0, 12), 'n'] RMSE=710797.221
# Log transformation enabled with config  [(0, 0, 0), (0, 0, 1, 12), 'n']
# SARIMAX[(0, 0, 0), (0, 0, 1, 12), 'n'] RMSE=29635.316
# Log transformation enabled with config  [(0, 0, 0), (0, 0, 2, 12), 'n']
# SARIMAX[(0, 0, 0), (0, 0, 2, 12), 'n'] RMSE=25898.197
# Log transformation enabled with config  [(0, 0, 0), (0, 1, 0, 12), 'n']
# SARIMAX[(0, 0, 0), (0, 1, 0, 12), 'n'] RMSE=1990.683
# Log transformation enabled with config  [(0, 0, 0), (0, 1, 1, 12), 'n']
# SARIMAX[(0, 0, 0), (0, 1, 1, 12), 'n'] RMSE=1517.195
# Log transformation enabled with config  [(0, 0, 0), (0, 1, 2, 12), 'n']
# Log transformation enabled with config  [(0, 0, 0), (1, 0, 0, 12), 'n']
# Log transformation enabled with config  [(0, 0, 0), (1, 0, 1, 12), 'n']
# Log transformation enabled with config  [(0, 0, 0), (1, 0, 2, 12), 'n']
# Log transformation enabled with config  [(0, 0, 0), (1, 1, 0, 12), 'n']
# Log transformation enabled with config  [(0, 0, 0), (1, 1, 1, 12), 'n']
# Log transformation enabled with config  [(0, 0, 0), (1, 1, 2, 12), 'n']
# Log transformation enabled with config  [(0, 0, 0), (2, 0, 0, 12), 'n']
# Log transformation enabled with config  [(0, 0, 0), (2, 0, 1, 12), 'n']
# Log transformation enabled with config  [(0, 0, 0), (2, 0, 2, 12), 'n']
# Log transformation enabled with config  [(0, 0, 0), (2, 1, 0, 12), 'n']
# Log transformation enabled with config  [(0, 0, 0), (2, 1, 1, 12), 'n']
# Log transformation enabled with config  [(0, 0, 0), (2, 1, 2, 12), 'n']
# Log transformation enabled with config  [(0, 0, 0), (0, 0, 0, 12), 'c']
# Log transformation enabled with config  [(0, 0, 0), (0, 0, 1, 12), 'c']
# Log transformation enabled with config  [(0, 0, 0), (0, 0, 2, 12), 'c']
# Log transformation enabled with config  [(0, 0, 0), (0, 1, 0, 12), 'c']
# Log transformation enabled with config  [(0, 0, 0), (0, 1, 1, 12), 'c']
# SARIMAX[(0, 0, 0), (0, 1, 1, 12), 'c'] RMSE=965.617
# Log transformation enabled with config  [(0, 0, 0), (0, 1, 2, 12), 'c']
# Log transformation enabled with config  [(0, 0, 0), (1, 0, 0, 12), 'c']
# Log transformation enabled with config  [(0, 0, 0), (1, 0, 1, 12), 'c']
# Log transformation enabled with config  [(0, 0, 0), (1, 0, 2, 12), 'c']
# Log transformation enabled with config  [(0, 0, 0), (1, 1, 0, 12), 'c']
# Log transformation enabled with config  [(0, 0, 0), (1, 1, 1, 12), 'c']
# Log transformation enabled with config  [(0, 0, 0), (1, 1, 2, 12), 'c']
# Log transformation enabled with config  [(0, 0, 0), (2, 0, 0, 12), 'c']
# Log transformation enabled with config  [(0, 0, 0), (2, 0, 1, 12), 'c']
# Log transformation enabled with config  [(0, 0, 0), (2, 0, 2, 12), 'c']
# Log transformation enabled with config  [(0, 0, 0), (2, 1, 0, 12), 'c']
# Log transformation enabled with config  [(0, 0, 0), (2, 1, 1, 12), 'c']
# Log transformation enabled with config  [(0, 0, 0), (2, 1, 2, 12), 'c']
# Log transformation enabled with config  [(0, 0, 0), (0, 0, 0, 12), 't']
# Log transformation enabled with config  [(0, 0, 0), (0, 0, 1, 12), 't']
# Log transformation enabled with config  [(0, 0, 0), (0, 0, 2, 12), 't']
# Log transformation enabled with config  [(0, 0, 0), (0, 1, 0, 12), 't']
# Log transformation enabled with config  [(0, 0, 0), (0, 1, 1, 12), 't']
# Log transformation enabled with config  [(0, 0, 0), (0, 1, 2, 12), 't']
# Log transformation enabled with config  [(0, 0, 0), (1, 0, 0, 12), 't']
# Log transformation enabled with config  [(0, 0, 0), (1, 0, 1, 12), 't']
# Log transformation enabled with config  [(0, 0, 0), (1, 0, 2, 12), 't']
# Log transformation enabled with config  [(0, 0, 0), (1, 1, 0, 12), 't']
# Log transformation enabled with config  [(0, 0, 0), (1, 1, 1, 12), 't']
# Log transformation enabled with config  [(0, 0, 0), (1, 1, 2, 12), 't']
# SARIMAX[(0, 0, 0), (1, 1, 2, 12), 't'] RMSE=961.569
# Log transformation enabled with config  [(0, 0, 0), (2, 0, 0, 12), 't']
# Log transformation enabled with config  [(0, 0, 0), (2, 0, 1, 12), 't']
# Log transformation enabled with config  [(0, 0, 0), (2, 0, 2, 12), 't']
# Log transformation enabled with config  [(0, 0, 0), (2, 1, 0, 12), 't']
# Log transformation enabled with config  [(0, 0, 0), (2, 1, 1, 12), 't']
# SARIMAX[(0, 0, 0), (2, 1, 1, 12), 't'] RMSE=948.546
# Log transformation enabled with config  [(0, 0, 0), (2, 1, 2, 12), 't']
# Log transformation enabled with config  [(0, 0, 1), (0, 0, 0, 12), 'n']
# Log transformation enabled with config  [(0, 0, 1), (0, 0, 1, 12), 'n']
# Log transformation enabled with config  [(0, 0, 1), (0, 0, 2, 12), 'n']
# Log transformation enabled with config  [(0, 0, 1), (0, 1, 0, 12), 'n']
# Log transformation enabled with config  [(0, 0, 1), (0, 1, 1, 12), 'n']
# Log transformation enabled with config  [(0, 0, 1), (0, 1, 2, 12), 'n']
# Log transformation enabled with config  [(0, 0, 1), (1, 0, 0, 12), 'n']
# Log transformation enabled with config  [(0, 0, 1), (1, 0, 1, 12), 'n']
# Log transformation enabled with config  [(0, 0, 1), (1, 0, 2, 12), 'n']
# Log transformation enabled with config  [(0, 0, 1), (1, 1, 0, 12), 'n']
# Log transformation enabled with config  [(0, 0, 1), (1, 1, 1, 12), 'n']
# Log transformation enabled with config  [(0, 0, 1), (1, 1, 2, 12), 'n']
# Log transformation enabled with config  [(0, 0, 1), (2, 0, 0, 12), 'n']
# Log transformation enabled with config  [(0, 0, 1), (2, 0, 1, 12), 'n']
# Log transformation enabled with config  [(0, 0, 1), (2, 0, 2, 12), 'n']
# Log transformation enabled with config  [(0, 0, 1), (2, 1, 0, 12), 'n']
# Log transformation enabled with config  [(0, 0, 1), (2, 1, 1, 12), 'n']
# Log transformation enabled with config  [(0, 0, 1), (2, 1, 2, 12), 'n']
# Log transformation enabled with config  [(0, 0, 1), (0, 0, 0, 12), 'c']
# Log transformation enabled with config  [(0, 0, 1), (0, 0, 1, 12), 'c']
# Log transformation enabled with config  [(0, 0, 1), (0, 0, 2, 12), 'c']
# Log transformation enabled with config  [(0, 0, 1), (0, 1, 0, 12), 'c']
# Log transformation enabled with config  [(0, 0, 1), (0, 1, 1, 12), 'c']
# Log transformation enabled with config  [(0, 0, 1), (0, 1, 2, 12), 'c']
# Log transformation enabled with config  [(0, 0, 1), (1, 0, 0, 12), 'c']
# Log transformation enabled with config  [(0, 0, 1), (1, 0, 1, 12), 'c']
# Log transformation enabled with config  [(0, 0, 1), (1, 0, 2, 12), 'c']
# Log transformation enabled with config  [(0, 0, 1), (1, 1, 0, 12), 'c']
# Log transformation enabled with config  [(0, 0, 1), (1, 1, 1, 12), 'c']
# Log transformation enabled with config  [(0, 0, 1), (1, 1, 2, 12), 'c']
# Log transformation enabled with config  [(0, 0, 1), (2, 0, 0, 12), 'c']
# Log transformation enabled with config  [(0, 0, 1), (2, 0, 1, 12), 'c']
# Log transformation enabled with config  [(0, 0, 1), (2, 0, 2, 12), 'c']
# Log transformation enabled with config  [(0, 0, 1), (2, 1, 0, 12), 'c']
# Log transformation enabled with config  [(0, 0, 1), (2, 1, 1, 12), 'c']
# Log transformation enabled with config  [(0, 0, 1), (2, 1, 2, 12), 'c']
# Log transformation enabled with config  [(0, 0, 1), (0, 0, 0, 12), 't']
# Log transformation enabled with config  [(0, 0, 1), (0, 0, 1, 12), 't']
# Log transformation enabled with config  [(0, 0, 1), (0, 0, 2, 12), 't']
# Log transformation enabled with config  [(0, 0, 1), (0, 1, 0, 12), 't']
# Log transformation enabled with config  [(0, 0, 1), (0, 1, 1, 12), 't']
# Log transformation enabled with config  [(0, 0, 1), (0, 1, 2, 12), 't']
# Log transformation enabled with config  [(0, 0, 1), (1, 0, 0, 12), 't']
# Log transformation enabled with config  [(0, 0, 1), (1, 0, 1, 12), 't']
# Log transformation enabled with config  [(0, 0, 1), (1, 0, 2, 12), 't']
# Log transformation enabled with config  [(0, 0, 1), (1, 1, 0, 12), 't']
# Log transformation enabled with config  [(0, 0, 1), (1, 1, 1, 12), 't']
# Log transformation enabled with config  [(0, 0, 1), (1, 1, 2, 12), 't']
# Log transformation enabled with config  [(0, 0, 1), (2, 0, 0, 12), 't']
# Log transformation enabled with config  [(0, 0, 1), (2, 0, 1, 12), 't']
# Log transformation enabled with config  [(0, 0, 1), (2, 0, 2, 12), 't']
# Log transformation enabled with config  [(0, 0, 1), (2, 1, 0, 12), 't']
# Log transformation enabled with config  [(0, 0, 1), (2, 1, 1, 12), 't']
# Log transformation enabled with config  [(0, 0, 1), (2, 1, 2, 12), 't']
# Log transformation enabled with config  [(0, 0, 2), (0, 0, 0, 12), 'n']
# Log transformation enabled with config  [(0, 0, 2), (0, 0, 1, 12), 'n']
# Log transformation enabled with config  [(0, 0, 2), (0, 0, 2, 12), 'n']
# Log transformation enabled with config  [(0, 0, 2), (0, 1, 0, 12), 'n']
# Log transformation enabled with config  [(0, 0, 2), (0, 1, 1, 12), 'n']
# Log transformation enabled with config  [(0, 0, 2), (0, 1, 2, 12), 'n']
# Log transformation enabled with config  [(0, 0, 2), (1, 0, 0, 12), 'n']
# Log transformation enabled with config  [(0, 0, 2), (1, 0, 1, 12), 'n']
# Log transformation enabled with config  [(0, 0, 2), (1, 0, 2, 12), 'n']
# Log transformation enabled with config  [(0, 0, 2), (1, 1, 0, 12), 'n']
# Log transformation enabled with config  [(0, 0, 2), (1, 1, 1, 12), 'n']
# Log transformation enabled with config  [(0, 0, 2), (1, 1, 2, 12), 'n']
# Log transformation enabled with config  [(0, 0, 2), (2, 0, 0, 12), 'n']
# Log transformation enabled with config  [(0, 0, 2), (2, 0, 1, 12), 'n']
# Log transformation enabled with config  [(0, 0, 2), (2, 0, 2, 12), 'n']
# Log transformation enabled with config  [(0, 0, 2), (2, 1, 0, 12), 'n']
# Log transformation enabled with config  [(0, 0, 2), (2, 1, 1, 12), 'n']
# Log transformation enabled with config  [(0, 0, 2), (2, 1, 2, 12), 'n']
# Log transformation enabled with config  [(0, 0, 2), (0, 0, 0, 12), 'c']
# Log transformation enabled with config  [(0, 0, 2), (0, 0, 1, 12), 'c']
# Log transformation enabled with config  [(0, 0, 2), (0, 0, 2, 12), 'c']
# Log transformation enabled with config  [(0, 0, 2), (0, 1, 0, 12), 'c']
# Log transformation enabled with config  [(0, 0, 2), (0, 1, 1, 12), 'c']
# SARIMAX[(0, 0, 2), (0, 1, 1, 12), 'c'] RMSE=860.091
# Log transformation enabled with config  [(0, 0, 2), (0, 1, 2, 12), 'c']
# SARIMAX[(0, 0, 2), (0, 1, 2, 12), 'c'] RMSE=847.896
# Log transformation enabled with config  [(0, 0, 2), (1, 0, 0, 12), 'c']
# Log transformation enabled with config  [(0, 0, 2), (1, 0, 1, 12), 'c']
# Log transformation enabled with config  [(0, 0, 2), (1, 0, 2, 12), 'c']
# Log transformation enabled with config  [(0, 0, 2), (1, 1, 0, 12), 'c']
# Log transformation enabled with config  [(0, 0, 2), (1, 1, 1, 12), 'c']
# Log transformation enabled with config  [(0, 0, 2), (1, 1, 2, 12), 'c']
# Log transformation enabled with config  [(0, 0, 2), (2, 0, 0, 12), 'c']
# Log transformation enabled with config  [(0, 0, 2), (2, 0, 1, 12), 'c']
# Log transformation enabled with config  [(0, 0, 2), (2, 0, 2, 12), 'c']
# Log transformation enabled with config  [(0, 0, 2), (2, 1, 0, 12), 'c']
# Log transformation enabled with config  [(0, 0, 2), (2, 1, 1, 12), 'c']
# Log transformation enabled with config  [(0, 0, 2), (2, 1, 2, 12), 'c']
# Log transformation enabled with config  [(0, 0, 2), (0, 0, 0, 12), 't']
# Log transformation enabled with config  [(0, 0, 2), (0, 0, 1, 12), 't']
# Log transformation enabled with config  [(0, 0, 2), (0, 0, 2, 12), 't']
# Log transformation enabled with config  [(0, 0, 2), (0, 1, 0, 12), 't']
# Log transformation enabled with config  [(0, 0, 2), (0, 1, 1, 12), 't']
# Log transformation enabled with config  [(0, 0, 2), (0, 1, 2, 12), 't']
# Log transformation enabled with config  [(0, 0, 2), (1, 0, 0, 12), 't']
# Log transformation enabled with config  [(0, 0, 2), (1, 0, 1, 12), 't']
# Log transformation enabled with config  [(0, 0, 2), (1, 0, 2, 12), 't']
# Log transformation enabled with config  [(0, 0, 2), (1, 1, 0, 12), 't']
# Log transformation enabled with config  [(0, 0, 2), (1, 1, 1, 12), 't']
# Log transformation enabled with config  [(0, 0, 2), (1, 1, 2, 12), 't']
# Log transformation enabled with config  [(0, 0, 2), (2, 0, 0, 12), 't']
# Log transformation enabled with config  [(0, 0, 2), (2, 0, 1, 12), 't']
# Log transformation enabled with config  [(0, 0, 2), (2, 0, 2, 12), 't']
# Log transformation enabled with config  [(0, 0, 2), (2, 1, 0, 12), 't']
# Log transformation enabled with config  [(0, 0, 2), (2, 1, 1, 12), 't']
# Log transformation enabled with config  [(0, 0, 2), (2, 1, 2, 12), 't']
# Log transformation enabled with config  [(0, 1, 0), (0, 0, 0, 12), 'n']
# SARIMAX[(0, 1, 0), (0, 0, 0, 12), 'n'] RMSE=750.182
# Log transformation enabled with config  [(0, 1, 0), (0, 0, 1, 12), 'n']
# Log transformation enabled with config  [(0, 1, 0), (0, 0, 2, 12), 'n']
# SARIMAX[(0, 1, 0), (0, 0, 2, 12), 'n'] RMSE=741.642
# Log transformation enabled with config  [(0, 1, 0), (0, 1, 0, 12), 'n']
# Log transformation enabled with config  [(0, 1, 0), (0, 1, 1, 12), 'n']
# Log transformation enabled with config  [(0, 1, 0), (0, 1, 2, 12), 'n']
# Log transformation enabled with config  [(0, 1, 0), (1, 0, 0, 12), 'n']
# Log transformation enabled with config  [(0, 1, 0), (1, 0, 1, 12), 'n']
# SARIMAX[(0, 1, 0), (1, 0, 1, 12), 'n'] RMSE=729.078
# Log transformation enabled with config  [(0, 1, 0), (1, 0, 2, 12), 'n']
# SARIMAX[(0, 1, 0), (1, 0, 2, 12), 'n'] RMSE=727.583
# Log transformation enabled with config  [(0, 1, 0), (1, 1, 0, 12), 'n']
# Log transformation enabled with config  [(0, 1, 0), (1, 1, 1, 12), 'n']
# Log transformation enabled with config  [(0, 1, 0), (1, 1, 2, 12), 'n']
# Log transformation enabled with config  [(0, 1, 0), (2, 0, 0, 12), 'n']
# Log transformation enabled with config  [(0, 1, 0), (2, 0, 1, 12), 'n']
# Log transformation enabled with config  [(0, 1, 0), (2, 0, 2, 12), 'n']
# Log transformation enabled with config  [(0, 1, 0), (2, 1, 0, 12), 'n']
# Log transformation enabled with config  [(0, 1, 0), (2, 1, 1, 12), 'n']
# Log transformation enabled with config  [(0, 1, 0), (2, 1, 2, 12), 'n']
# Log transformation enabled with config  [(0, 1, 0), (0, 0, 0, 12), 'c']
# Log transformation enabled with config  [(0, 1, 0), (0, 0, 1, 12), 'c']
# Log transformation enabled with config  [(0, 1, 0), (0, 0, 2, 12), 'c']
# Log transformation enabled with config  [(0, 1, 0), (0, 1, 0, 12), 'c']
# Log transformation enabled with config  [(0, 1, 0), (0, 1, 1, 12), 'c']
# Log transformation enabled with config  [(0, 1, 0), (0, 1, 2, 12), 'c']
# Log transformation enabled with config  [(0, 1, 0), (1, 0, 0, 12), 'c']
# Log transformation enabled with config  [(0, 1, 0), (1, 0, 1, 12), 'c']
# Log transformation enabled with config  [(0, 1, 0), (1, 0, 2, 12), 'c']
# Log transformation enabled with config  [(0, 1, 0), (1, 1, 0, 12), 'c']
# Log transformation enabled with config  [(0, 1, 0), (1, 1, 1, 12), 'c']
# Log transformation enabled with config  [(0, 1, 0), (1, 1, 2, 12), 'c']
# Log transformation enabled with config  [(0, 1, 0), (2, 0, 0, 12), 'c']
# Log transformation enabled with config  [(0, 1, 0), (2, 0, 1, 12), 'c']
# Log transformation enabled with config  [(0, 1, 0), (2, 0, 2, 12), 'c']
# SARIMAX[(0, 1, 0), (2, 0, 2, 12), 'c'] RMSE=692.025
# Log transformation enabled with config  [(0, 1, 0), (2, 1, 0, 12), 'c']
# Log transformation enabled with config  [(0, 1, 0), (2, 1, 1, 12), 'c']
# Log transformation enabled with config  [(0, 1, 0), (2, 1, 2, 12), 'c']
# Log transformation enabled with config  [(0, 1, 0), (0, 0, 0, 12), 't']
# Log transformation enabled with config  [(0, 1, 0), (0, 0, 1, 12), 't']
# Log transformation enabled with config  [(0, 1, 0), (0, 0, 2, 12), 't']
# Log transformation enabled with config  [(0, 1, 0), (0, 1, 0, 12), 't']
# Log transformation enabled with config  [(0, 1, 0), (0, 1, 1, 12), 't']
# Log transformation enabled with config  [(0, 1, 0), (0, 1, 2, 12), 't']
# Log transformation enabled with config  [(0, 1, 0), (1, 0, 0, 12), 't']
# Log transformation enabled with config  [(0, 1, 0), (1, 0, 1, 12), 't']
# Log transformation enabled with config  [(0, 1, 0), (1, 0, 2, 12), 't']
# Log transformation enabled with config  [(0, 1, 0), (1, 1, 0, 12), 't']
# Log transformation enabled with config  [(0, 1, 0), (1, 1, 1, 12), 't']
# Log transformation enabled with config  [(0, 1, 0), (1, 1, 2, 12), 't']
# Log transformation enabled with config  [(0, 1, 0), (2, 0, 0, 12), 't']
# Log transformation enabled with config  [(0, 1, 0), (2, 0, 1, 12), 't']
# Log transformation enabled with config  [(0, 1, 0), (2, 0, 2, 12), 't']
# Log transformation enabled with config  [(0, 1, 0), (2, 1, 0, 12), 't']
# Log transformation enabled with config  [(0, 1, 0), (2, 1, 1, 12), 't']
# Log transformation enabled with config  [(0, 1, 0), (2, 1, 2, 12), 't']
# Log transformation enabled with config  [(0, 1, 1), (0, 0, 0, 12), 'n']
# Log transformation enabled with config  [(0, 1, 1), (0, 0, 1, 12), 'n']
# Log transformation enabled with config  [(0, 1, 1), (0, 0, 2, 12), 'n']
# Log transformation enabled with config  [(0, 1, 1), (0, 1, 0, 12), 'n']
# Log transformation enabled with config  [(0, 1, 1), (0, 1, 1, 12), 'n']
# Log transformation enabled with config  [(0, 1, 1), (0, 1, 2, 12), 'n']
# Log transformation enabled with config  [(0, 1, 1), (1, 0, 0, 12), 'n']
# Log transformation enabled with config  [(0, 1, 1), (1, 0, 1, 12), 'n']
# Log transformation enabled with config  [(0, 1, 1), (1, 0, 2, 12), 'n']
# Log transformation enabled with config  [(0, 1, 1), (1, 1, 0, 12), 'n']
# Log transformation enabled with config  [(0, 1, 1), (1, 1, 1, 12), 'n']
# Log transformation enabled with config  [(0, 1, 1), (1, 1, 2, 12), 'n']
# Log transformation enabled with config  [(0, 1, 1), (2, 0, 0, 12), 'n']
# Log transformation enabled with config  [(0, 1, 1), (2, 0, 1, 12), 'n']
# Log transformation enabled with config  [(0, 1, 1), (2, 0, 2, 12), 'n']
# Log transformation enabled with config  [(0, 1, 1), (2, 1, 0, 12), 'n']
# Log transformation enabled with config  [(0, 1, 1), (2, 1, 1, 12), 'n']
# Log transformation enabled with config  [(0, 1, 1), (2, 1, 2, 12), 'n']
# Log transformation enabled with config  [(0, 1, 1), (0, 0, 0, 12), 'c']
# Log transformation enabled with config  [(0, 1, 1), (0, 0, 1, 12), 'c']
# Log transformation enabled with config  [(0, 1, 1), (0, 0, 2, 12), 'c']
# Log transformation enabled with config  [(0, 1, 1), (0, 1, 0, 12), 'c']
# Log transformation enabled with config  [(0, 1, 1), (0, 1, 1, 12), 'c']
# Log transformation enabled with config  [(0, 1, 1), (0, 1, 2, 12), 'c']
# Log transformation enabled with config  [(0, 1, 1), (1, 0, 0, 12), 'c']
# Log transformation enabled with config  [(0, 1, 1), (1, 0, 1, 12), 'c']
# Log transformation enabled with config  [(0, 1, 1), (1, 0, 2, 12), 'c']
# Log transformation enabled with config  [(0, 1, 1), (1, 1, 0, 12), 'c']
# Log transformation enabled with config  [(0, 1, 1), (1, 1, 1, 12), 'c']
# Log transformation enabled with config  [(0, 1, 1), (1, 1, 2, 12), 'c']
# Log transformation enabled with config  [(0, 1, 1), (2, 0, 0, 12), 'c']
# Log transformation enabled with config  [(0, 1, 1), (2, 0, 1, 12), 'c']
# Log transformation enabled with config  [(0, 1, 1), (2, 0, 2, 12), 'c']
# Log transformation enabled with config  [(0, 1, 1), (2, 1, 0, 12), 'c']
# Log transformation enabled with config  [(0, 1, 1), (2, 1, 1, 12), 'c']
# Log transformation enabled with config  [(0, 1, 1), (2, 1, 2, 12), 'c']
# Log transformation enabled with config  [(0, 1, 1), (0, 0, 0, 12), 't']
# Log transformation enabled with config  [(0, 1, 1), (0, 0, 1, 12), 't']
# Log transformation enabled with config  [(0, 1, 1), (0, 0, 2, 12), 't']
# Log transformation enabled with config  [(0, 1, 1), (0, 1, 0, 12), 't']
# Log transformation enabled with config  [(0, 1, 1), (0, 1, 1, 12), 't']
# Log transformation enabled with config  [(0, 1, 1), (0, 1, 2, 12), 't']
# Log transformation enabled with config  [(0, 1, 1), (1, 0, 0, 12), 't']
# Log transformation enabled with config  [(0, 1, 1), (1, 0, 1, 12), 't']
# Log transformation enabled with config  [(0, 1, 1), (1, 0, 2, 12), 't']
# Log transformation enabled with config  [(0, 1, 1), (1, 1, 0, 12), 't']
# Log transformation enabled with config  [(0, 1, 1), (1, 1, 1, 12), 't']
# Log transformation enabled with config  [(0, 1, 1), (1, 1, 2, 12), 't']
# Log transformation enabled with config  [(0, 1, 1), (2, 0, 0, 12), 't']
# Log transformation enabled with config  [(0, 1, 1), (2, 0, 1, 12), 't']
# Log transformation enabled with config  [(0, 1, 1), (2, 0, 2, 12), 't']
# Log transformation enabled with config  [(0, 1, 1), (2, 1, 0, 12), 't']
# Log transformation enabled with config  [(0, 1, 1), (2, 1, 1, 12), 't']
# Log transformation enabled with config  [(0, 1, 1), (2, 1, 2, 12), 't']
# Log transformation enabled with config  [(0, 1, 2), (0, 0, 0, 12), 'n']
# Log transformation enabled with config  [(0, 1, 2), (0, 0, 1, 12), 'n']
# Log transformation enabled with config  [(0, 1, 2), (0, 0, 2, 12), 'n']
# Log transformation enabled with config  [(0, 1, 2), (0, 1, 0, 12), 'n']
# Log transformation enabled with config  [(0, 1, 2), (0, 1, 1, 12), 'n']
# Log transformation enabled with config  [(0, 1, 2), (0, 1, 2, 12), 'n']
# Log transformation enabled with config  [(0, 1, 2), (1, 0, 0, 12), 'n']
# Log transformation enabled with config  [(0, 1, 2), (1, 0, 1, 12), 'n']
# Log transformation enabled with config  [(0, 1, 2), (1, 0, 2, 12), 'n']
# Log transformation enabled with config  [(0, 1, 2), (1, 1, 0, 12), 'n']
# Log transformation enabled with config  [(0, 1, 2), (1, 1, 1, 12), 'n']
# Log transformation enabled with config  [(0, 1, 2), (1, 1, 2, 12), 'n']
# Log transformation enabled with config  [(0, 1, 2), (2, 0, 0, 12), 'n']
# Log transformation enabled with config  [(0, 1, 2), (2, 0, 1, 12), 'n']
# Log transformation enabled with config  [(0, 1, 2), (2, 0, 2, 12), 'n']
# Log transformation enabled with config  [(0, 1, 2), (2, 1, 0, 12), 'n']
# Log transformation enabled with config  [(0, 1, 2), (2, 1, 1, 12), 'n']
# Log transformation enabled with config  [(0, 1, 2), (2, 1, 2, 12), 'n']
# Log transformation enabled with config  [(0, 1, 2), (0, 0, 0, 12), 'c']
# Log transformation enabled with config  [(0, 1, 2), (0, 0, 1, 12), 'c']
# Log transformation enabled with config  [(0, 1, 2), (0, 0, 2, 12), 'c']
# Log transformation enabled with config  [(0, 1, 2), (0, 1, 0, 12), 'c']
# Log transformation enabled with config  [(0, 1, 2), (0, 1, 1, 12), 'c']
# Log transformation enabled with config  [(0, 1, 2), (0, 1, 2, 12), 'c']
# Log transformation enabled with config  [(0, 1, 2), (1, 0, 0, 12), 'c']
# Log transformation enabled with config  [(0, 1, 2), (1, 0, 1, 12), 'c']
# Log transformation enabled with config  [(0, 1, 2), (1, 0, 2, 12), 'c']
# Log transformation enabled with config  [(0, 1, 2), (1, 1, 0, 12), 'c']
# Log transformation enabled with config  [(0, 1, 2), (1, 1, 1, 12), 'c']
# Log transformation enabled with config  [(0, 1, 2), (1, 1, 2, 12), 'c']
# Log transformation enabled with config  [(0, 1, 2), (2, 0, 0, 12), 'c']
# Log transformation enabled with config  [(0, 1, 2), (2, 0, 1, 12), 'c']
# Log transformation enabled with config  [(0, 1, 2), (2, 0, 2, 12), 'c']
# Log transformation enabled with config  [(0, 1, 2), (2, 1, 0, 12), 'c']
# Log transformation enabled with config  [(0, 1, 2), (2, 1, 1, 12), 'c']
# Log transformation enabled with config  [(0, 1, 2), (2, 1, 2, 12), 'c']
# Log transformation enabled with config  [(0, 1, 2), (0, 0, 0, 12), 't']
# Log transformation enabled with config  [(0, 1, 2), (0, 0, 1, 12), 't']
# Log transformation enabled with config  [(0, 1, 2), (0, 0, 2, 12), 't']
# Log transformation enabled with config  [(0, 1, 2), (0, 1, 0, 12), 't']
# Log transformation enabled with config  [(0, 1, 2), (0, 1, 1, 12), 't']
# Log transformation enabled with config  [(0, 1, 2), (0, 1, 2, 12), 't']
# Log transformation enabled with config  [(0, 1, 2), (1, 0, 0, 12), 't']
# Log transformation enabled with config  [(0, 1, 2), (1, 0, 1, 12), 't']
# Log transformation enabled with config  [(0, 1, 2), (1, 0, 2, 12), 't']
# Log transformation enabled with config  [(0, 1, 2), (1, 1, 0, 12), 't']
# Log transformation enabled with config  [(0, 1, 2), (1, 1, 1, 12), 't']
# Log transformation enabled with config  [(0, 1, 2), (1, 1, 2, 12), 't']
# Log transformation enabled with config  [(0, 1, 2), (2, 0, 0, 12), 't']
# Log transformation enabled with config  [(0, 1, 2), (2, 0, 1, 12), 't']
# Log transformation enabled with config  [(0, 1, 2), (2, 0, 2, 12), 't']
# Log transformation enabled with config  [(0, 1, 2), (2, 1, 0, 12), 't']
# Log transformation enabled with config  [(0, 1, 2), (2, 1, 1, 12), 't']
# Log transformation enabled with config  [(0, 1, 2), (2, 1, 2, 12), 't']
# Log transformation enabled with config  [(0, 2, 0), (0, 0, 0, 12), 'n']
# Log transformation enabled with config  [(0, 2, 0), (0, 0, 1, 12), 'n']
# Log transformation enabled with config  [(0, 2, 0), (0, 0, 2, 12), 'n']
# Log transformation enabled with config  [(0, 2, 0), (0, 1, 0, 12), 'n']
# Log transformation enabled with config  [(0, 2, 0), (0, 1, 1, 12), 'n']
# Log transformation enabled with config  [(0, 2, 0), (0, 1, 2, 12), 'n']
# Log transformation enabled with config  [(0, 2, 0), (1, 0, 0, 12), 'n']
# Log transformation enabled with config  [(0, 2, 0), (1, 0, 1, 12), 'n']
# Log transformation enabled with config  [(0, 2, 0), (1, 0, 2, 12), 'n']
# Log transformation enabled with config  [(0, 2, 0), (1, 1, 0, 12), 'n']
# Log transformation enabled with config  [(0, 2, 0), (1, 1, 1, 12), 'n']
# Log transformation enabled with config  [(0, 2, 0), (1, 1, 2, 12), 'n']
# Log transformation enabled with config  [(0, 2, 0), (2, 0, 0, 12), 'n']
# Log transformation enabled with config  [(0, 2, 0), (2, 0, 1, 12), 'n']
# Log transformation enabled with config  [(0, 2, 0), (2, 0, 2, 12), 'n']
# Log transformation enabled with config  [(0, 2, 0), (2, 1, 0, 12), 'n']
# Log transformation enabled with config  [(0, 2, 0), (2, 1, 1, 12), 'n']
# Log transformation enabled with config  [(0, 2, 0), (2, 1, 2, 12), 'n']
# Log transformation enabled with config  [(0, 2, 0), (0, 0, 0, 12), 'c']
# Log transformation enabled with config  [(0, 2, 0), (0, 0, 1, 12), 'c']
# Log transformation enabled with config  [(0, 2, 0), (0, 0, 2, 12), 'c']
# Log transformation enabled with config  [(0, 2, 0), (0, 1, 0, 12), 'c']
# Log transformation enabled with config  [(0, 2, 0), (0, 1, 1, 12), 'c']
# Log transformation enabled with config  [(0, 2, 0), (0, 1, 2, 12), 'c']
# Log transformation enabled with config  [(0, 2, 0), (1, 0, 0, 12), 'c']
# Log transformation enabled with config  [(0, 2, 0), (1, 0, 1, 12), 'c']
# Log transformation enabled with config  [(0, 2, 0), (1, 0, 2, 12), 'c']
# Log transformation enabled with config  [(0, 2, 0), (1, 1, 0, 12), 'c']
# Log transformation enabled with config  [(0, 2, 0), (1, 1, 1, 12), 'c']
# Log transformation enabled with config  [(0, 2, 0), (1, 1, 2, 12), 'c']
# Log transformation enabled with config  [(0, 2, 0), (2, 0, 0, 12), 'c']
# Log transformation enabled with config  [(0, 2, 0), (2, 0, 1, 12), 'c']
# Log transformation enabled with config  [(0, 2, 0), (2, 0, 2, 12), 'c']
# Log transformation enabled with config  [(0, 2, 0), (2, 1, 0, 12), 'c']
# Log transformation enabled with config  [(0, 2, 0), (2, 1, 1, 12), 'c']
# Log transformation enabled with config  [(0, 2, 0), (2, 1, 2, 12), 'c']
# Log transformation enabled with config  [(0, 2, 0), (0, 0, 0, 12), 't']
# Log transformation enabled with config  [(0, 2, 0), (0, 0, 1, 12), 't']
# Log transformation enabled with config  [(0, 2, 0), (0, 0, 2, 12), 't']
# Log transformation enabled with config  [(0, 2, 0), (0, 1, 0, 12), 't']
# Log transformation enabled with config  [(0, 2, 0), (0, 1, 1, 12), 't']
# Log transformation enabled with config  [(0, 2, 0), (0, 1, 2, 12), 't']
# Log transformation enabled with config  [(0, 2, 0), (1, 0, 0, 12), 't']
# Log transformation enabled with config  [(0, 2, 0), (1, 0, 1, 12), 't']
# Log transformation enabled with config  [(0, 2, 0), (1, 0, 2, 12), 't']
# Log transformation enabled with config  [(0, 2, 0), (1, 1, 0, 12), 't']
# Log transformation enabled with config  [(0, 2, 0), (1, 1, 1, 12), 't']
# Log transformation enabled with config  [(0, 2, 0), (1, 1, 2, 12), 't']
# Log transformation enabled with config  [(0, 2, 0), (2, 0, 0, 12), 't']
# Log transformation enabled with config  [(0, 2, 0), (2, 0, 1, 12), 't']
# Log transformation enabled with config  [(0, 2, 0), (2, 0, 2, 12), 't']
# Log transformation enabled with config  [(0, 2, 0), (2, 1, 0, 12), 't']
# Log transformation enabled with config  [(0, 2, 0), (2, 1, 1, 12), 't']
# Log transformation enabled with config  [(0, 2, 0), (2, 1, 2, 12), 't']
# Log transformation enabled with config  [(0, 2, 1), (0, 0, 0, 12), 'n']
# Log transformation enabled with config  [(0, 2, 1), (0, 0, 1, 12), 'n']
# Log transformation enabled with config  [(0, 2, 1), (0, 0, 2, 12), 'n']
# Log transformation enabled with config  [(0, 2, 1), (0, 1, 0, 12), 'n']
# Log transformation enabled with config  [(0, 2, 1), (0, 1, 1, 12), 'n']
# Log transformation enabled with config  [(0, 2, 1), (0, 1, 2, 12), 'n']
# Log transformation enabled with config  [(0, 2, 1), (1, 0, 0, 12), 'n']
# Log transformation enabled with config  [(0, 2, 1), (1, 0, 1, 12), 'n']
# Log transformation enabled with config  [(0, 2, 1), (1, 0, 2, 12), 'n']
# Log transformation enabled with config  [(0, 2, 1), (1, 1, 0, 12), 'n']
# Log transformation enabled with config  [(0, 2, 1), (1, 1, 1, 12), 'n']
# Log transformation enabled with config  [(0, 2, 1), (1, 1, 2, 12), 'n']
# Log transformation enabled with config  [(0, 2, 1), (2, 0, 0, 12), 'n']
# Log transformation enabled with config  [(0, 2, 1), (2, 0, 1, 12), 'n']
# Log transformation enabled with config  [(0, 2, 1), (2, 0, 2, 12), 'n']
# Log transformation enabled with config  [(0, 2, 1), (2, 1, 0, 12), 'n']
# Log transformation enabled with config  [(0, 2, 1), (2, 1, 1, 12), 'n']
# Log transformation enabled with config  [(0, 2, 1), (2, 1, 2, 12), 'n']
# Log transformation enabled with config  [(0, 2, 1), (0, 0, 0, 12), 'c']
# Log transformation enabled with config  [(0, 2, 1), (0, 0, 1, 12), 'c']
# Log transformation enabled with config  [(0, 2, 1), (0, 0, 2, 12), 'c']
# Log transformation enabled with config  [(0, 2, 1), (0, 1, 0, 12), 'c']
# Log transformation enabled with config  [(0, 2, 1), (0, 1, 1, 12), 'c']
# Log transformation enabled with config  [(0, 2, 1), (0, 1, 2, 12), 'c']
# Log transformation enabled with config  [(0, 2, 1), (1, 0, 0, 12), 'c']
# Log transformation enabled with config  [(0, 2, 1), (1, 0, 1, 12), 'c']
# Log transformation enabled with config  [(0, 2, 1), (1, 0, 2, 12), 'c']
# Log transformation enabled with config  [(0, 2, 1), (1, 1, 0, 12), 'c']
# Log transformation enabled with config  [(0, 2, 1), (1, 1, 1, 12), 'c']
# Log transformation enabled with config  [(0, 2, 1), (1, 1, 2, 12), 'c']
# Log transformation enabled with config  [(0, 2, 1), (2, 0, 0, 12), 'c']
# Log transformation enabled with config  [(0, 2, 1), (2, 0, 1, 12), 'c']
# Log transformation enabled with config  [(0, 2, 1), (2, 0, 2, 12), 'c']
# Log transformation enabled with config  [(0, 2, 1), (2, 1, 0, 12), 'c']
# Log transformation enabled with config  [(0, 2, 1), (2, 1, 1, 12), 'c']
# Log transformation enabled with config  [(0, 2, 1), (2, 1, 2, 12), 'c']
# Log transformation enabled with config  [(0, 2, 1), (0, 0, 0, 12), 't']
# Log transformation enabled with config  [(0, 2, 1), (0, 0, 1, 12), 't']
# Log transformation enabled with config  [(0, 2, 1), (0, 0, 2, 12), 't']
# Log transformation enabled with config  [(0, 2, 1), (0, 1, 0, 12), 't']
# Log transformation enabled with config  [(0, 2, 1), (0, 1, 1, 12), 't']
# Log transformation enabled with config  [(0, 2, 1), (0, 1, 2, 12), 't']
# Log transformation enabled with config  [(0, 2, 1), (1, 0, 0, 12), 't']
# Log transformation enabled with config  [(0, 2, 1), (1, 0, 1, 12), 't']
# Log transformation enabled with config  [(0, 2, 1), (1, 0, 2, 12), 't']
# Log transformation enabled with config  [(0, 2, 1), (1, 1, 0, 12), 't']
# Log transformation enabled with config  [(0, 2, 1), (1, 1, 1, 12), 't']
# Log transformation enabled with config  [(0, 2, 1), (1, 1, 2, 12), 't']
# Log transformation enabled with config  [(0, 2, 1), (2, 0, 0, 12), 't']
# Log transformation enabled with config  [(0, 2, 1), (2, 0, 1, 12), 't']
# Log transformation enabled with config  [(0, 2, 1), (2, 0, 2, 12), 't']
# Log transformation enabled with config  [(0, 2, 1), (2, 1, 0, 12), 't']
# Log transformation enabled with config  [(0, 2, 1), (2, 1, 1, 12), 't']
# Log transformation enabled with config  [(0, 2, 1), (2, 1, 2, 12), 't']
# Log transformation enabled with config  [(0, 2, 2), (0, 0, 0, 12), 'n']
# Log transformation enabled with config  [(0, 2, 2), (0, 0, 1, 12), 'n']
# Log transformation enabled with config  [(0, 2, 2), (0, 0, 2, 12), 'n']
# Log transformation enabled with config  [(0, 2, 2), (0, 1, 0, 12), 'n']
# Log transformation enabled with config  [(0, 2, 2), (0, 1, 1, 12), 'n']
# Log transformation enabled with config  [(0, 2, 2), (0, 1, 2, 12), 'n']
# Log transformation enabled with config  [(0, 2, 2), (1, 0, 0, 12), 'n']
# Log transformation enabled with config  [(0, 2, 2), (1, 0, 1, 12), 'n']
# Log transformation enabled with config  [(0, 2, 2), (1, 0, 2, 12), 'n']
# Log transformation enabled with config  [(0, 2, 2), (1, 1, 0, 12), 'n']
# Log transformation enabled with config  [(0, 2, 2), (1, 1, 1, 12), 'n']
# Log transformation enabled with config  [(0, 2, 2), (1, 1, 2, 12), 'n']
# Log transformation enabled with config  [(0, 2, 2), (2, 0, 0, 12), 'n']
# Log transformation enabled with config  [(0, 2, 2), (2, 0, 1, 12), 'n']
# Log transformation enabled with config  [(0, 2, 2), (2, 0, 2, 12), 'n']
# Log transformation enabled with config  [(0, 2, 2), (2, 1, 0, 12), 'n']
# Log transformation enabled with config  [(0, 2, 2), (2, 1, 1, 12), 'n']
# Log transformation enabled with config  [(0, 2, 2), (2, 1, 2, 12), 'n']
# Log transformation enabled with config  [(0, 2, 2), (0, 0, 0, 12), 'c']
# Log transformation enabled with config  [(0, 2, 2), (0, 0, 1, 12), 'c']
# Log transformation enabled with config  [(0, 2, 2), (0, 0, 2, 12), 'c']
# Log transformation enabled with config  [(0, 2, 2), (0, 1, 0, 12), 'c']
# Log transformation enabled with config  [(0, 2, 2), (0, 1, 1, 12), 'c']
# Log transformation enabled with config  [(0, 2, 2), (0, 1, 2, 12), 'c']
# Log transformation enabled with config  [(0, 2, 2), (1, 0, 0, 12), 'c']
# Log transformation enabled with config  [(0, 2, 2), (1, 0, 1, 12), 'c']
# Log transformation enabled with config  [(0, 2, 2), (1, 0, 2, 12), 'c']
# Log transformation enabled with config  [(0, 2, 2), (1, 1, 0, 12), 'c']
# Log transformation enabled with config  [(0, 2, 2), (1, 1, 1, 12), 'c']
# Log transformation enabled with config  [(0, 2, 2), (1, 1, 2, 12), 'c']
# Log transformation enabled with config  [(0, 2, 2), (2, 0, 0, 12), 'c']
# Log transformation enabled with config  [(0, 2, 2), (2, 0, 1, 12), 'c']
# Log transformation enabled with config  [(0, 2, 2), (2, 0, 2, 12), 'c']
# Log transformation enabled with config  [(0, 2, 2), (2, 1, 0, 12), 'c']
# Log transformation enabled with config  [(0, 2, 2), (2, 1, 1, 12), 'c']
# Log transformation enabled with config  [(0, 2, 2), (2, 1, 2, 12), 'c']
# Log transformation enabled with config  [(0, 2, 2), (0, 0, 0, 12), 't']
# Log transformation enabled with config  [(0, 2, 2), (0, 0, 1, 12), 't']
# Log transformation enabled with config  [(0, 2, 2), (0, 0, 2, 12), 't']
# Log transformation enabled with config  [(0, 2, 2), (0, 1, 0, 12), 't']
# Log transformation enabled with config  [(0, 2, 2), (0, 1, 1, 12), 't']
# Log transformation enabled with config  [(0, 2, 2), (0, 1, 2, 12), 't']
# Log transformation enabled with config  [(0, 2, 2), (1, 0, 0, 12), 't']
# Log transformation enabled with config  [(0, 2, 2), (1, 0, 1, 12), 't']
# Log transformation enabled with config  [(0, 2, 2), (1, 0, 2, 12), 't']
# Log transformation enabled with config  [(0, 2, 2), (1, 1, 0, 12), 't']
# Log transformation enabled with config  [(0, 2, 2), (1, 1, 1, 12), 't']
# Log transformation enabled with config  [(0, 2, 2), (1, 1, 2, 12), 't']
# Log transformation enabled with config  [(0, 2, 2), (2, 0, 0, 12), 't']
# Log transformation enabled with config  [(0, 2, 2), (2, 0, 1, 12), 't']
# Log transformation enabled with config  [(0, 2, 2), (2, 0, 2, 12), 't']
# Log transformation enabled with config  [(0, 2, 2), (2, 1, 0, 12), 't']
# Log transformation enabled with config  [(0, 2, 2), (2, 1, 1, 12), 't']
# Log transformation enabled with config  [(0, 2, 2), (2, 1, 2, 12), 't']
# Log transformation enabled with config  [(1, 0, 0), (0, 0, 0, 12), 'n']
# Log transformation enabled with config  [(1, 0, 0), (0, 0, 1, 12), 'n']
# Log transformation enabled with config  [(1, 0, 0), (0, 0, 2, 12), 'n']
# Log transformation enabled with config  [(1, 0, 0), (0, 1, 0, 12), 'n']
# Log transformation enabled with config  [(1, 0, 0), (0, 1, 1, 12), 'n']
# Log transformation enabled with config  [(1, 0, 0), (0, 1, 2, 12), 'n']
# Log transformation enabled with config  [(1, 0, 0), (1, 0, 0, 12), 'n']
# Log transformation enabled with config  [(1, 0, 0), (1, 0, 1, 12), 'n']
# Log transformation enabled with config  [(1, 0, 0), (1, 0, 2, 12), 'n']
# Log transformation enabled with config  [(1, 0, 0), (1, 1, 0, 12), 'n']
# Log transformation enabled with config  [(1, 0, 0), (1, 1, 1, 12), 'n']
# Log transformation enabled with config  [(1, 0, 0), (1, 1, 2, 12), 'n']
# Log transformation enabled with config  [(1, 0, 0), (2, 0, 0, 12), 'n']
# Log transformation enabled with config  [(1, 0, 0), (2, 0, 1, 12), 'n']
# Log transformation enabled with config  [(1, 0, 0), (2, 0, 2, 12), 'n']
# Log transformation enabled with config  [(1, 0, 0), (2, 1, 0, 12), 'n']
# Log transformation enabled with config  [(1, 0, 0), (2, 1, 1, 12), 'n']
# Log transformation enabled with config  [(1, 0, 0), (2, 1, 2, 12), 'n']
# Log transformation enabled with config  [(1, 0, 0), (0, 0, 0, 12), 'c']
# Log transformation enabled with config  [(1, 0, 0), (0, 0, 1, 12), 'c']
# Log transformation enabled with config  [(1, 0, 0), (0, 0, 2, 12), 'c']
# Log transformation enabled with config  [(1, 0, 0), (0, 1, 0, 12), 'c']
# Log transformation enabled with config  [(1, 0, 0), (0, 1, 1, 12), 'c']
# Log transformation enabled with config  [(1, 0, 0), (0, 1, 2, 12), 'c']
# Log transformation enabled with config  [(1, 0, 0), (1, 0, 0, 12), 'c']
# Log transformation enabled with config  [(1, 0, 0), (1, 0, 1, 12), 'c']
# Log transformation enabled with config  [(1, 0, 0), (1, 0, 2, 12), 'c']
# Log transformation enabled with config  [(1, 0, 0), (1, 1, 0, 12), 'c']
# Log transformation enabled with config  [(1, 0, 0), (1, 1, 1, 12), 'c']
# Log transformation enabled with config  [(1, 0, 0), (1, 1, 2, 12), 'c']
# Log transformation enabled with config  [(1, 0, 0), (2, 0, 0, 12), 'c']
# Log transformation enabled with config  [(1, 0, 0), (2, 0, 1, 12), 'c']
# Log transformation enabled with config  [(1, 0, 0), (2, 0, 2, 12), 'c']
# Log transformation enabled with config  [(1, 0, 0), (2, 1, 0, 12), 'c']
# Log transformation enabled with config  [(1, 0, 0), (2, 1, 1, 12), 'c']
# Log transformation enabled with config  [(1, 0, 0), (2, 1, 2, 12), 'c']
# Log transformation enabled with config  [(1, 0, 0), (0, 0, 0, 12), 't']
# Log transformation enabled with config  [(1, 0, 0), (0, 0, 1, 12), 't']
# Log transformation enabled with config  [(1, 0, 0), (0, 0, 2, 12), 't']
# Log transformation enabled with config  [(1, 0, 0), (0, 1, 0, 12), 't']
# Log transformation enabled with config  [(1, 0, 0), (0, 1, 1, 12), 't']
# Log transformation enabled with config  [(1, 0, 0), (0, 1, 2, 12), 't']
# Log transformation enabled with config  [(1, 0, 0), (1, 0, 0, 12), 't']
# Log transformation enabled with config  [(1, 0, 0), (1, 0, 1, 12), 't']
# Log transformation enabled with config  [(1, 0, 0), (1, 0, 2, 12), 't']
# Log transformation enabled with config  [(1, 0, 0), (1, 1, 0, 12), 't']
# Log transformation enabled with config  [(1, 0, 0), (1, 1, 1, 12), 't']
# Log transformation enabled with config  [(1, 0, 0), (1, 1, 2, 12), 't']
# Log transformation enabled with config  [(1, 0, 0), (2, 0, 0, 12), 't']
# Log transformation enabled with config  [(1, 0, 0), (2, 0, 1, 12), 't']
# Log transformation enabled with config  [(1, 0, 0), (2, 0, 2, 12), 't']
# Log transformation enabled with config  [(1, 0, 0), (2, 1, 0, 12), 't']
# Log transformation enabled with config  [(1, 0, 0), (2, 1, 1, 12), 't']
# Log transformation enabled with config  [(1, 0, 0), (2, 1, 2, 12), 't']
# Log transformation enabled with config  [(1, 0, 1), (0, 0, 0, 12), 'n']
# Log transformation enabled with config  [(1, 0, 1), (0, 0, 1, 12), 'n']
# Log transformation enabled with config  [(1, 0, 1), (0, 0, 2, 12), 'n']
# Log transformation enabled with config  [(1, 0, 1), (0, 1, 0, 12), 'n']
# Log transformation enabled with config  [(1, 0, 1), (0, 1, 1, 12), 'n']
# Log transformation enabled with config  [(1, 0, 1), (0, 1, 2, 12), 'n']
# Log transformation enabled with config  [(1, 0, 1), (1, 0, 0, 12), 'n']
# Log transformation enabled with config  [(1, 0, 1), (1, 0, 1, 12), 'n']
# Log transformation enabled with config  [(1, 0, 1), (1, 0, 2, 12), 'n']
# Log transformation enabled with config  [(1, 0, 1), (1, 1, 0, 12), 'n']
# Log transformation enabled with config  [(1, 0, 1), (1, 1, 1, 12), 'n']
# Log transformation enabled with config  [(1, 0, 1), (1, 1, 2, 12), 'n']
# Log transformation enabled with config  [(1, 0, 1), (2, 0, 0, 12), 'n']
# Log transformation enabled with config  [(1, 0, 1), (2, 0, 1, 12), 'n']
# Log transformation enabled with config  [(1, 0, 1), (2, 0, 2, 12), 'n']
# Log transformation enabled with config  [(1, 0, 1), (2, 1, 0, 12), 'n']
# Log transformation enabled with config  [(1, 0, 1), (2, 1, 1, 12), 'n']
# Log transformation enabled with config  [(1, 0, 1), (2, 1, 2, 12), 'n']
# Log transformation enabled with config  [(1, 0, 1), (0, 0, 0, 12), 'c']
# Log transformation enabled with config  [(1, 0, 1), (0, 0, 1, 12), 'c']
# Log transformation enabled with config  [(1, 0, 1), (0, 0, 2, 12), 'c']
# Log transformation enabled with config  [(1, 0, 1), (0, 1, 0, 12), 'c']
# Log transformation enabled with config  [(1, 0, 1), (0, 1, 1, 12), 'c']
# Log transformation enabled with config  [(1, 0, 1), (0, 1, 2, 12), 'c']
# Log transformation enabled with config  [(1, 0, 1), (1, 0, 0, 12), 'c']
# Log transformation enabled with config  [(1, 0, 1), (1, 0, 1, 12), 'c']
# Log transformation enabled with config  [(1, 0, 1), (1, 0, 2, 12), 'c']
# Log transformation enabled with config  [(1, 0, 1), (1, 1, 0, 12), 'c']
# Log transformation enabled with config  [(1, 0, 1), (1, 1, 1, 12), 'c']
# Log transformation enabled with config  [(1, 0, 1), (1, 1, 2, 12), 'c']
# Log transformation enabled with config  [(1, 0, 1), (2, 0, 0, 12), 'c']
# Log transformation enabled with config  [(1, 0, 1), (2, 0, 1, 12), 'c']
# Log transformation enabled with config  [(1, 0, 1), (2, 0, 2, 12), 'c']
# Log transformation enabled with config  [(1, 0, 1), (2, 1, 0, 12), 'c']
# Log transformation enabled with config  [(1, 0, 1), (2, 1, 1, 12), 'c']
# Log transformation enabled with config  [(1, 0, 1), (2, 1, 2, 12), 'c']
# Log transformation enabled with config  [(1, 0, 1), (0, 0, 0, 12), 't']
# Log transformation enabled with config  [(1, 0, 1), (0, 0, 1, 12), 't']
# Log transformation enabled with config  [(1, 0, 1), (0, 0, 2, 12), 't']
# Log transformation enabled with config  [(1, 0, 1), (0, 1, 0, 12), 't']
# Log transformation enabled with config  [(1, 0, 1), (0, 1, 1, 12), 't']
# Log transformation enabled with config  [(1, 0, 1), (0, 1, 2, 12), 't']
# Log transformation enabled with config  [(1, 0, 1), (1, 0, 0, 12), 't']
# Log transformation enabled with config  [(1, 0, 1), (1, 0, 1, 12), 't']
# Log transformation enabled with config  [(1, 0, 1), (1, 0, 2, 12), 't']
# Log transformation enabled with config  [(1, 0, 1), (1, 1, 0, 12), 't']
# Log transformation enabled with config  [(1, 0, 1), (1, 1, 1, 12), 't']
# Log transformation enabled with config  [(1, 0, 1), (1, 1, 2, 12), 't']
# Log transformation enabled with config  [(1, 0, 1), (2, 0, 0, 12), 't']
# Log transformation enabled with config  [(1, 0, 1), (2, 0, 1, 12), 't']
# Log transformation enabled with config  [(1, 0, 1), (2, 0, 2, 12), 't']
# Log transformation enabled with config  [(1, 0, 1), (2, 1, 0, 12), 't']
# Log transformation enabled with config  [(1, 0, 1), (2, 1, 1, 12), 't']
# Log transformation enabled with config  [(1, 0, 1), (2, 1, 2, 12), 't']
# Log transformation enabled with config  [(1, 0, 2), (0, 0, 0, 12), 'n']
# Log transformation enabled with config  [(1, 0, 2), (0, 0, 1, 12), 'n']
# Log transformation enabled with config  [(1, 0, 2), (0, 0, 2, 12), 'n']
# Log transformation enabled with config  [(1, 0, 2), (0, 1, 0, 12), 'n']
# Log transformation enabled with config  [(1, 0, 2), (0, 1, 1, 12), 'n']
# Log transformation enabled with config  [(1, 0, 2), (0, 1, 2, 12), 'n']
# Log transformation enabled with config  [(1, 0, 2), (1, 0, 0, 12), 'n']
# Log transformation enabled with config  [(1, 0, 2), (1, 0, 1, 12), 'n']
# Log transformation enabled with config  [(1, 0, 2), (1, 0, 2, 12), 'n']
# Log transformation enabled with config  [(1, 0, 2), (1, 1, 0, 12), 'n']
# Log transformation enabled with config  [(1, 0, 2), (1, 1, 1, 12), 'n']
# Log transformation enabled with config  [(1, 0, 2), (1, 1, 2, 12), 'n']
# Log transformation enabled with config  [(1, 0, 2), (2, 0, 0, 12), 'n']
# Log transformation enabled with config  [(1, 0, 2), (2, 0, 1, 12), 'n']
# Log transformation enabled with config  [(1, 0, 2), (2, 0, 2, 12), 'n']
# Log transformation enabled with config  [(1, 0, 2), (2, 1, 0, 12), 'n']
# Log transformation enabled with config  [(1, 0, 2), (2, 1, 1, 12), 'n']
# Log transformation enabled with config  [(1, 0, 2), (2, 1, 2, 12), 'n']
# Log transformation enabled with config  [(1, 0, 2), (0, 0, 0, 12), 'c']
# Log transformation enabled with config  [(1, 0, 2), (0, 0, 1, 12), 'c']
# Log transformation enabled with config  [(1, 0, 2), (0, 0, 2, 12), 'c']
# Log transformation enabled with config  [(1, 0, 2), (0, 1, 0, 12), 'c']
# Log transformation enabled with config  [(1, 0, 2), (0, 1, 1, 12), 'c']
# Log transformation enabled with config  [(1, 0, 2), (0, 1, 2, 12), 'c']
# Log transformation enabled with config  [(1, 0, 2), (1, 0, 0, 12), 'c']
# Log transformation enabled with config  [(1, 0, 2), (1, 0, 1, 12), 'c']
# Log transformation enabled with config  [(1, 0, 2), (1, 0, 2, 12), 'c']
# Log transformation enabled with config  [(1, 0, 2), (1, 1, 0, 12), 'c']
# Log transformation enabled with config  [(1, 0, 2), (1, 1, 1, 12), 'c']
# Log transformation enabled with config  [(1, 0, 2), (1, 1, 2, 12), 'c']
# Log transformation enabled with config  [(1, 0, 2), (2, 0, 0, 12), 'c']
# Log transformation enabled with config  [(1, 0, 2), (2, 0, 1, 12), 'c']
# Log transformation enabled with config  [(1, 0, 2), (2, 0, 2, 12), 'c']
# Log transformation enabled with config  [(1, 0, 2), (2, 1, 0, 12), 'c']
# Log transformation enabled with config  [(1, 0, 2), (2, 1, 1, 12), 'c']
# Log transformation enabled with config  [(1, 0, 2), (2, 1, 2, 12), 'c']
# Log transformation enabled with config  [(1, 0, 2), (0, 0, 0, 12), 't']
# Log transformation enabled with config  [(1, 0, 2), (0, 0, 1, 12), 't']
# Log transformation enabled with config  [(1, 0, 2), (0, 0, 2, 12), 't']
# Log transformation enabled with config  [(1, 0, 2), (0, 1, 0, 12), 't']
# Log transformation enabled with config  [(1, 0, 2), (0, 1, 1, 12), 't']
# Log transformation enabled with config  [(1, 0, 2), (0, 1, 2, 12), 't']
# Log transformation enabled with config  [(1, 0, 2), (1, 0, 0, 12), 't']
# Log transformation enabled with config  [(1, 0, 2), (1, 0, 1, 12), 't']
# Log transformation enabled with config  [(1, 0, 2), (1, 0, 2, 12), 't']
# Log transformation enabled with config  [(1, 0, 2), (1, 1, 0, 12), 't']
# Log transformation enabled with config  [(1, 0, 2), (1, 1, 1, 12), 't']
# Log transformation enabled with config  [(1, 0, 2), (1, 1, 2, 12), 't']
# Log transformation enabled with config  [(1, 0, 2), (2, 0, 0, 12), 't']
# Log transformation enabled with config  [(1, 0, 2), (2, 0, 1, 12), 't']
# Log transformation enabled with config  [(1, 0, 2), (2, 0, 2, 12), 't']
# Log transformation enabled with config  [(1, 0, 2), (2, 1, 0, 12), 't']
# Log transformation enabled with config  [(1, 0, 2), (2, 1, 1, 12), 't']
# Log transformation enabled with config  [(1, 0, 2), (2, 1, 2, 12), 't']
# Log transformation enabled with config  [(1, 1, 0), (0, 0, 0, 12), 'n']
# Log transformation enabled with config  [(1, 1, 0), (0, 0, 1, 12), 'n']
# Log transformation enabled with config  [(1, 1, 0), (0, 0, 2, 12), 'n']
# Log transformation enabled with config  [(1, 1, 0), (0, 1, 0, 12), 'n']
# Log transformation enabled with config  [(1, 1, 0), (0, 1, 1, 12), 'n']
# Log transformation enabled with config  [(1, 1, 0), (0, 1, 2, 12), 'n']
# Log transformation enabled with config  [(1, 1, 0), (1, 0, 0, 12), 'n']
# ...
# Log transformation enabled with config  [(4, 1, 1), (2, 0, 1, 12), 't']
# Log transformation enabled with config  [(4, 1, 1), (2, 0, 2, 12), 't']
# Log transformation enabled with config  [(4, 1, 1), (2, 1, 0, 12), 't']
# Log transformation enabled with config  [(4, 1, 1), (2, 1, 1, 12), 't']
# Log transformation enabled with config  [(4, 1, 1), (2, 1, 2, 12), 't']
# Log transformation enabled with config  [(4, 1, 2), (0, 0, 0, 12), 'n']
# Log transformation enabled with config  [(4, 1, 2), (0, 0, 1, 12), 'n']
# Log transformation enabled with config  [(4, 1, 2), (0, 0, 2, 12), 'n']
# Log transformation enabled with config  [(4, 1, 2), (0, 1, 0, 12), 'n']
# Log transformation enabled with config  [(4, 1, 2), (0, 1, 1, 12), 'n']
# Log transformation enabled with config  [(4, 1, 2), (0, 1, 2, 12), 'n']
# Log transformation enabled with config  [(4, 1, 2), (1, 0, 0, 12), 'n']
# Log transformation enabled with config  [(4, 1, 2), (1, 0, 1, 12), 'n']
# Log transformation enabled with config  [(4, 1, 2), (1, 0, 2, 12), 'n']
# Log transformation enabled with config  [(4, 1, 2), (1, 1, 0, 12), 'n']
# Log transformation enabled with config  [(4, 1, 2), (1, 1, 1, 12), 'n']
# Log transformation enabled with config  [(4, 1, 2), (1, 1, 2, 12), 'n']
# Log transformation enabled with config  [(4, 1, 2), (2, 0, 0, 12), 'n']
# Log transformation enabled with config  [(4, 1, 2), (2, 0, 1, 12), 'n']
# Log transformation enabled with config  [(4, 1, 2), (2, 0, 2, 12), 'n']
# Log transformation enabled with config  [(4, 1, 2), (2, 1, 0, 12), 'n']
# Log transformation enabled with config  [(4, 1, 2), (2, 1, 1, 12), 'n']
# Log transformation enabled with config  [(4, 1, 2), (2, 1, 2, 12), 'n']
# Log transformation enabled with config  [(4, 1, 2), (0, 0, 0, 12), 'c']
# Log transformation enabled with config  [(4, 1, 2), (0, 0, 1, 12), 'c']
# Log transformation enabled with config  [(4, 1, 2), (0, 0, 2, 12), 'c']
# Log transformation enabled with config  [(4, 1, 2), (0, 1, 0, 12), 'c']
# Log transformation enabled with config  [(4, 1, 2), (0, 1, 1, 12), 'c']
# Log transformation enabled with config  [(4, 1, 2), (0, 1, 2, 12), 'c']
# Log transformation enabled with config  [(4, 1, 2), (1, 0, 0, 12), 'c']
# Log transformation enabled with config  [(4, 1, 2), (1, 0, 1, 12), 'c']
# Log transformation enabled with config  [(4, 1, 2), (1, 0, 2, 12), 'c']
# Log transformation enabled with config  [(4, 1, 2), (1, 1, 0, 12), 'c']
# Log transformation enabled with config  [(4, 1, 2), (1, 1, 1, 12), 'c']
# Log transformation enabled with config  [(4, 1, 2), (1, 1, 2, 12), 'c']
# Log transformation enabled with config  [(4, 1, 2), (2, 0, 0, 12), 'c']
# Log transformation enabled with config  [(4, 1, 2), (2, 0, 1, 12), 'c']
# Log transformation enabled with config  [(4, 1, 2), (2, 0, 2, 12), 'c']
# Log transformation enabled with config  [(4, 1, 2), (2, 1, 0, 12), 'c']
# Log transformation enabled with config  [(4, 1, 2), (2, 1, 1, 12), 'c']
# Log transformation enabled with config  [(4, 1, 2), (2, 1, 2, 12), 'c']
# Log transformation enabled with config  [(4, 1, 2), (0, 0, 0, 12), 't']
# Log transformation enabled with config  [(4, 1, 2), (0, 0, 1, 12), 't']
# Log transformation enabled with config  [(4, 1, 2), (0, 0, 2, 12), 't']
# Log transformation enabled with config  [(4, 1, 2), (0, 1, 0, 12), 't']
# Log transformation enabled with config  [(4, 1, 2), (0, 1, 1, 12), 't']
# Log transformation enabled with config  [(4, 1, 2), (0, 1, 2, 12), 't']
# Log transformation enabled with config  [(4, 1, 2), (1, 0, 0, 12), 't']
# Log transformation enabled with config  [(4, 1, 2), (1, 0, 1, 12), 't']
# Log transformation enabled with config  [(4, 1, 2), (1, 0, 2, 12), 't']
# Log transformation enabled with config  [(4, 1, 2), (1, 1, 0, 12), 't']
# Log transformation enabled with config  [(4, 1, 2), (1, 1, 1, 12), 't']
# Log transformation enabled with config  [(4, 1, 2), (1, 1, 2, 12), 't']
# Log transformation enabled with config  [(4, 1, 2), (2, 0, 0, 12), 't']
# Log transformation enabled with config  [(4, 1, 2), (2, 0, 1, 12), 't']
# Log transformation enabled with config  [(4, 1, 2), (2, 0, 2, 12), 't']
# Log transformation enabled with config  [(4, 1, 2), (2, 1, 0, 12), 't']
# Log transformation enabled with config  [(4, 1, 2), (2, 1, 1, 12), 't']
# Log transformation enabled with config  [(4, 1, 2), (2, 1, 2, 12), 't']
# Log transformation enabled with config  [(4, 2, 0), (0, 0, 0, 12), 'n']
# Log transformation enabled with config  [(4, 2, 0), (0, 0, 1, 12), 'n']
# Log transformation enabled with config  [(4, 2, 0), (0, 0, 2, 12), 'n']
# Log transformation enabled with config  [(4, 2, 0), (0, 1, 0, 12), 'n']
# Log transformation enabled with config  [(4, 2, 0), (0, 1, 1, 12), 'n']
# Log transformation enabled with config  [(4, 2, 0), (0, 1, 2, 12), 'n']
# Log transformation enabled with config  [(4, 2, 0), (1, 0, 0, 12), 'n']
# Log transformation enabled with config  [(4, 2, 0), (1, 0, 1, 12), 'n']
# Log transformation enabled with config  [(4, 2, 0), (1, 0, 2, 12), 'n']
# Log transformation enabled with config  [(4, 2, 0), (1, 1, 0, 12), 'n']
# Log transformation enabled with config  [(4, 2, 0), (1, 1, 1, 12), 'n']
# Log transformation enabled with config  [(4, 2, 0), (1, 1, 2, 12), 'n']
# Log transformation enabled with config  [(4, 2, 0), (2, 0, 0, 12), 'n']
# Log transformation enabled with config  [(4, 2, 0), (2, 0, 1, 12), 'n']
# Log transformation enabled with config  [(4, 2, 0), (2, 0, 2, 12), 'n']
# Log transformation enabled with config  [(4, 2, 0), (2, 1, 0, 12), 'n']
# Log transformation enabled with config  [(4, 2, 0), (2, 1, 1, 12), 'n']
# Log transformation enabled with config  [(4, 2, 0), (2, 1, 2, 12), 'n']
# Log transformation enabled with config  [(4, 2, 0), (0, 0, 0, 12), 'c']
# Log transformation enabled with config  [(4, 2, 0), (0, 0, 1, 12), 'c']
# Log transformation enabled with config  [(4, 2, 0), (0, 0, 2, 12), 'c']
# Log transformation enabled with config  [(4, 2, 0), (0, 1, 0, 12), 'c']
# Log transformation enabled with config  [(4, 2, 0), (0, 1, 1, 12), 'c']
# Log transformation enabled with config  [(4, 2, 0), (0, 1, 2, 12), 'c']
# Log transformation enabled with config  [(4, 2, 0), (1, 0, 0, 12), 'c']
# Log transformation enabled with config  [(4, 2, 0), (1, 0, 1, 12), 'c']
# Log transformation enabled with config  [(4, 2, 0), (1, 0, 2, 12), 'c']
# Log transformation enabled with config  [(4, 2, 0), (1, 1, 0, 12), 'c']
# Log transformation enabled with config  [(4, 2, 0), (1, 1, 1, 12), 'c']
# Log transformation enabled with config  [(4, 2, 0), (1, 1, 2, 12), 'c']
# Log transformation enabled with config  [(4, 2, 0), (2, 0, 0, 12), 'c']
# Log transformation enabled with config  [(4, 2, 0), (2, 0, 1, 12), 'c']
# Log transformation enabled with config  [(4, 2, 0), (2, 0, 2, 12), 'c']
# Log transformation enabled with config  [(4, 2, 0), (2, 1, 0, 12), 'c']
# Log transformation enabled with config  [(4, 2, 0), (2, 1, 1, 12), 'c']
# Log transformation enabled with config  [(4, 2, 0), (2, 1, 2, 12), 'c']
# Log transformation enabled with config  [(4, 2, 0), (0, 0, 0, 12), 't']
# Log transformation enabled with config  [(4, 2, 0), (0, 0, 1, 12), 't']
# Log transformation enabled with config  [(4, 2, 0), (0, 0, 2, 12), 't']
# Log transformation enabled with config  [(4, 2, 0), (0, 1, 0, 12), 't']
# Log transformation enabled with config  [(4, 2, 0), (0, 1, 1, 12), 't']
# Log transformation enabled with config  [(4, 2, 0), (0, 1, 2, 12), 't']
# Log transformation enabled with config  [(4, 2, 0), (1, 0, 0, 12), 't']
# Log transformation enabled with config  [(4, 2, 0), (1, 0, 1, 12), 't']
# Log transformation enabled with config  [(4, 2, 0), (1, 0, 2, 12), 't']
# Log transformation enabled with config  [(4, 2, 0), (1, 1, 0, 12), 't']
# Log transformation enabled with config  [(4, 2, 0), (1, 1, 1, 12), 't']
# Log transformation enabled with config  [(4, 2, 0), (1, 1, 2, 12), 't']
# Log transformation enabled with config  [(4, 2, 0), (2, 0, 0, 12), 't']
# Log transformation enabled with config  [(4, 2, 0), (2, 0, 1, 12), 't']
# Log transformation enabled with config  [(4, 2, 0), (2, 0, 2, 12), 't']
# Log transformation enabled with config  [(4, 2, 0), (2, 1, 0, 12), 't']
# Log transformation enabled with config  [(4, 2, 0), (2, 1, 1, 12), 't']
# Log transformation enabled with config  [(4, 2, 0), (2, 1, 2, 12), 't']
# Log transformation enabled with config  [(4, 2, 1), (0, 0, 0, 12), 'n']
# Log transformation enabled with config  [(4, 2, 1), (0, 0, 1, 12), 'n']
# Log transformation enabled with config  [(4, 2, 1), (0, 0, 2, 12), 'n']
# Log transformation enabled with config  [(4, 2, 1), (0, 1, 0, 12), 'n']
# Log transformation enabled with config  [(4, 2, 1), (0, 1, 1, 12), 'n']
# Log transformation enabled with config  [(4, 2, 1), (0, 1, 2, 12), 'n']
# Log transformation enabled with config  [(4, 2, 1), (1, 0, 0, 12), 'n']
# Log transformation enabled with config  [(4, 2, 1), (1, 0, 1, 12), 'n']
# Log transformation enabled with config  [(4, 2, 1), (1, 0, 2, 12), 'n']
# Log transformation enabled with config  [(4, 2, 1), (1, 1, 0, 12), 'n']
# Log transformation enabled with config  [(4, 2, 1), (1, 1, 1, 12), 'n']
# Log transformation enabled with config  [(4, 2, 1), (1, 1, 2, 12), 'n']
# Log transformation enabled with config  [(4, 2, 1), (2, 0, 0, 12), 'n']
# Log transformation enabled with config  [(4, 2, 1), (2, 0, 1, 12), 'n']
# Log transformation enabled with config  [(4, 2, 1), (2, 0, 2, 12), 'n']
# Log transformation enabled with config  [(4, 2, 1), (2, 1, 0, 12), 'n']
# Log transformation enabled with config  [(4, 2, 1), (2, 1, 1, 12), 'n']
# Log transformation enabled with config  [(4, 2, 1), (2, 1, 2, 12), 'n']
# Log transformation enabled with config  [(4, 2, 1), (0, 0, 0, 12), 'c']
# Log transformation enabled with config  [(4, 2, 1), (0, 0, 1, 12), 'c']
# Log transformation enabled with config  [(4, 2, 1), (0, 0, 2, 12), 'c']
# Log transformation enabled with config  [(4, 2, 1), (0, 1, 0, 12), 'c']
# Log transformation enabled with config  [(4, 2, 1), (0, 1, 1, 12), 'c']
# Log transformation enabled with config  [(4, 2, 1), (0, 1, 2, 12), 'c']
# Log transformation enabled with config  [(4, 2, 1), (1, 0, 0, 12), 'c']
# Log transformation enabled with config  [(4, 2, 1), (1, 0, 1, 12), 'c']
# Log transformation enabled with config  [(4, 2, 1), (1, 0, 2, 12), 'c']
# Log transformation enabled with config  [(4, 2, 1), (1, 1, 0, 12), 'c']
# Log transformation enabled with config  [(4, 2, 1), (1, 1, 1, 12), 'c']
# Log transformation enabled with config  [(4, 2, 1), (1, 1, 2, 12), 'c']
# Log transformation enabled with config  [(4, 2, 1), (2, 0, 0, 12), 'c']
# Log transformation enabled with config  [(4, 2, 1), (2, 0, 1, 12), 'c']
# Log transformation enabled with config  [(4, 2, 1), (2, 0, 2, 12), 'c']
# Log transformation enabled with config  [(4, 2, 1), (2, 1, 0, 12), 'c']
# Log transformation enabled with config  [(4, 2, 1), (2, 1, 1, 12), 'c']
# Log transformation enabled with config  [(4, 2, 1), (2, 1, 2, 12), 'c']
# Log transformation enabled with config  [(4, 2, 1), (0, 0, 0, 12), 't']
# Log transformation enabled with config  [(4, 2, 1), (0, 0, 1, 12), 't']
# Log transformation enabled with config  [(4, 2, 1), (0, 0, 2, 12), 't']
# Log transformation enabled with config  [(4, 2, 1), (0, 1, 0, 12), 't']
# Log transformation enabled with config  [(4, 2, 1), (0, 1, 1, 12), 't']
# Log transformation enabled with config  [(4, 2, 1), (0, 1, 2, 12), 't']
# Log transformation enabled with config  [(4, 2, 1), (1, 0, 0, 12), 't']
# Log transformation enabled with config  [(4, 2, 1), (1, 0, 1, 12), 't']
# Log transformation enabled with config  [(4, 2, 1), (1, 0, 2, 12), 't']
# Log transformation enabled with config  [(4, 2, 1), (1, 1, 0, 12), 't']
# Log transformation enabled with config  [(4, 2, 1), (1, 1, 1, 12), 't']
# Log transformation enabled with config  [(4, 2, 1), (1, 1, 2, 12), 't']
# Log transformation enabled with config  [(4, 2, 1), (2, 0, 0, 12), 't']
# Log transformation enabled with config  [(4, 2, 1), (2, 0, 1, 12), 't']
# Log transformation enabled with config  [(4, 2, 1), (2, 0, 2, 12), 't']
# Log transformation enabled with config  [(4, 2, 1), (2, 1, 0, 12), 't']
# Log transformation enabled with config  [(4, 2, 1), (2, 1, 1, 12), 't']
# Log transformation enabled with config  [(4, 2, 1), (2, 1, 2, 12), 't']
# Log transformation enabled with config  [(4, 2, 2), (0, 0, 0, 12), 'n']
# Log transformation enabled with config  [(4, 2, 2), (0, 0, 1, 12), 'n']
# Log transformation enabled with config  [(4, 2, 2), (0, 0, 2, 12), 'n']
# Log transformation enabled with config  [(4, 2, 2), (0, 1, 0, 12), 'n']
# Log transformation enabled with config  [(4, 2, 2), (0, 1, 1, 12), 'n']
# Log transformation enabled with config  [(4, 2, 2), (0, 1, 2, 12), 'n']
# Log transformation enabled with config  [(4, 2, 2), (1, 0, 0, 12), 'n']
# Log transformation enabled with config  [(4, 2, 2), (1, 0, 1, 12), 'n']
# Log transformation enabled with config  [(4, 2, 2), (1, 0, 2, 12), 'n']
# Log transformation enabled with config  [(4, 2, 2), (1, 1, 0, 12), 'n']
# Log transformation enabled with config  [(4, 2, 2), (1, 1, 1, 12), 'n']
# Log transformation enabled with config  [(4, 2, 2), (1, 1, 2, 12), 'n']
# Log transformation enabled with config  [(4, 2, 2), (2, 0, 0, 12), 'n']
# Log transformation enabled with config  [(4, 2, 2), (2, 0, 1, 12), 'n']
# Log transformation enabled with config  [(4, 2, 2), (2, 0, 2, 12), 'n']
# Log transformation enabled with config  [(4, 2, 2), (2, 1, 0, 12), 'n']
# Log transformation enabled with config  [(4, 2, 2), (2, 1, 1, 12), 'n']
# Log transformation enabled with config  [(4, 2, 2), (2, 1, 2, 12), 'n']
# Log transformation enabled with config  [(4, 2, 2), (0, 0, 0, 12), 'c']
# Log transformation enabled with config  [(4, 2, 2), (0, 0, 1, 12), 'c']
# Log transformation enabled with config  [(4, 2, 2), (0, 0, 2, 12), 'c']
# Log transformation enabled with config  [(4, 2, 2), (0, 1, 0, 12), 'c']
# Log transformation enabled with config  [(4, 2, 2), (0, 1, 1, 12), 'c']
# Log transformation enabled with config  [(4, 2, 2), (0, 1, 2, 12), 'c']
# Log transformation enabled with config  [(4, 2, 2), (1, 0, 0, 12), 'c']
# Log transformation enabled with config  [(4, 2, 2), (1, 0, 1, 12), 'c']
# Log transformation enabled with config  [(4, 2, 2), (1, 0, 2, 12), 'c']
# Log transformation enabled with config  [(4, 2, 2), (1, 1, 0, 12), 'c']
# Log transformation enabled with config  [(4, 2, 2), (1, 1, 1, 12), 'c']
# Log transformation enabled with config  [(4, 2, 2), (1, 1, 2, 12), 'c']
# Log transformation enabled with config  [(4, 2, 2), (2, 0, 0, 12), 'c']
# Log transformation enabled with config  [(4, 2, 2), (2, 0, 1, 12), 'c']
# Log transformation enabled with config  [(4, 2, 2), (2, 0, 2, 12), 'c']
# Log transformation enabled with config  [(4, 2, 2), (2, 1, 0, 12), 'c']
# Log transformation enabled with config  [(4, 2, 2), (2, 1, 1, 12), 'c']
# Log transformation enabled with config  [(4, 2, 2), (2, 1, 2, 12), 'c']
# Log transformation enabled with config  [(4, 2, 2), (0, 0, 0, 12), 't']
# Log transformation enabled with config  [(4, 2, 2), (0, 0, 1, 12), 't']
# Log transformation enabled with config  [(4, 2, 2), (0, 0, 2, 12), 't']
# Log transformation enabled with config  [(4, 2, 2), (0, 1, 0, 12), 't']
# Log transformation enabled with config  [(4, 2, 2), (0, 1, 1, 12), 't']
# Log transformation enabled with config  [(4, 2, 2), (0, 1, 2, 12), 't']
# Log transformation enabled with config  [(4, 2, 2), (1, 0, 0, 12), 't']
# Log transformation enabled with config  [(4, 2, 2), (1, 0, 1, 12), 't']
# Log transformation enabled with config  [(4, 2, 2), (1, 0, 2, 12), 't']
# Log transformation enabled with config  [(4, 2, 2), (1, 1, 0, 12), 't']
# Log transformation enabled with config  [(4, 2, 2), (1, 1, 1, 12), 't']
# Log transformation enabled with config  [(4, 2, 2), (1, 1, 2, 12), 't']
# Log transformation enabled with config  [(4, 2, 2), (2, 0, 0, 12), 't']
# Log transformation enabled with config  [(4, 2, 2), (2, 0, 1, 12), 't']
# Log transformation enabled with config  [(4, 2, 2), (2, 0, 2, 12), 't']
# Log transformation enabled with config  [(4, 2, 2), (2, 1, 0, 12), 't']
# Log transformation enabled with config  [(4, 2, 2), (2, 1, 1, 12), 't']
# Log transformation enabled with config  [(4, 2, 2), (2, 1, 2, 12), 't']
# Best SARIMAX[(3, 2, 0), (1, 0, 1, 12), 't'] RMSE=215.284

# %%
#[(3, 2, 0), (1, 0, 1, 12), 't'] RMSE=215.284

modelSummary(sales_cat_weekly, test.copy(), 'HOBBIES', smodel_hobbies_gs, model="sarimax", 
             showConf=True, logTransformation = transformLog_flag)
# Out:
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:                              HOBBIES   No. Observations:                  263
# Model:             SARIMAX(3, 2, 0)x(1, 0, [1], 12)   Log Likelihood                 264.943
# Date:                              Mon, 01 Nov 2021   AIC                           -499.886
# Time:                                      01:52:45   BIC                           -446.418
# Sample:                                  03-27-2011   HQIC                          -478.394
#                                        - 04-03-2016
# Covariance Type:                                opg
# ==========================================================================================
#                              coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# drift                  -2.408e-06   5.18e-05     -0.047      0.963      -0.000     9.9e-05
# inbetween25and5            0.0057      0.009      0.630      0.529      -0.012       0.023
# event_on_weekend           0.0016      0.031      0.053      0.958      -0.059       0.062
# event_on_weekday           0.0137      0.032      0.433      0.665      -0.048       0.076
# event_type_1_Cultural     -0.0134      0.034     -0.399      0.690      -0.079       0.052
# event_type_1_National     -0.0508      0.031     -1.650      0.099      -0.111       0.010
# event_type_1_Religious     0.0022      0.028      0.079      0.937      -0.053       0.058
# event_type_1_Sporting      0.0065      0.033      0.197      0.844      -0.059       0.072
# event_type_2_Cultural     -0.1381      0.034     -4.052      0.000      -0.205      -0.071
# ar.L1                     -1.0964      0.063    -17.268      0.000      -1.221      -0.972
# ar.L2                     -0.7999      0.066    -12.130      0.000      -0.929      -0.671
# ar.L3                     -0.3935      0.046     -8.525      0.000      -0.484      -0.303
# ar.S.L12                  -0.1491      0.949     -0.157      0.875      -2.008       1.710
# ma.S.L12                   0.0758      0.943      0.080      0.936      -1.773       1.925
# sigma2                     0.0076      0.000     16.244      0.000       0.007       0.009
# ===================================================================================
# Ljung-Box (L1) (Q):                   7.04   Jarque-Bera (JB):               135.94
# Prob(Q):                              0.01   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.50   Skew:                             0.40
# Prob(H) (two-sided):                  0.00   Kurtosis:                         6.44
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# ### HOUSEHOLD

# %%
transformLog_flag = True

# %%
sarima_model_household = trainSeasonalAutoARIMA(train.copy(),'HOUSEHOLD',tr='c',logTransformation = transformLog_flag, param_d=1, param_D=0)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(1,0,1)[12] intercept   : AIC=-658.855, Time=2.48 sec
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=-631.929, Time=0.18 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=-692.553, Time=1.89 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=-700.906, Time=2.37 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=-631.929, Time=0.18 sec
#  ARIMA(0,1,1)(0,0,0)[12] intercept   : AIC=-689.766, Time=1.26 sec
#  ARIMA(0,1,1)(1,0,1)[12] intercept   : AIC=-697.543, Time=3.10 sec
#  ARIMA(0,1,1)(0,0,2)[12] intercept   : AIC=-698.957, Time=5.92 sec
#  ARIMA(0,1,1)(1,0,0)[12] intercept   : AIC=-699.914, Time=2.27 sec
#  ARIMA(0,1,1)(1,0,2)[12] intercept   : AIC=-697.602, Time=6.58 sec
#  ARIMA(0,1,0)(0,0,1)[12] intercept   : AIC=-645.006, Time=1.43 sec
#  ARIMA(1,1,1)(0,0,1)[12] intercept   : AIC=-699.507, Time=2.73 sec
#  ARIMA(0,1,2)(0,0,1)[12] intercept   : AIC=-699.539, Time=2.51 sec
#  ARIMA(1,1,0)(0,0,1)[12] intercept   : AIC=-694.782, Time=2.28 sec
#  ARIMA(1,1,2)(0,0,1)[12] intercept   : AIC=-698.652, Time=2.82 sec
#  ARIMA(0,1,1)(0,0,1)[12]             : AIC=-700.906, Time=2.38 sec
#
# Best model:  ARIMA(0,1,1)(0,0,1)[12] intercept
# Total fit time: 40.418 seconds

# %%
# Extract Model Parameters
order = sarima_model_household.get_params()['order']
seasonal_order = sarima_model_household.get_params()['seasonal_order']
trend = sarima_model_household.get_params()['trend']

model_params = [order, seasonal_order, trend]
model_params
# Out:
# [(0, 1, 1), (0, 0, 1, 12), 'c']

# %%
[rmse_sarima_household, smodel_household] = evaluate_seasonal_arima_model(train.copy(), test.copy(), model_params,
                                                                          'HOUSEHOLD', logTransformation = transformLog_flag)
print(rmse_sarima_household)
# Out:
# 2087.4956610776103

# %%
modelSummary(sales_cat_weekly, test.copy(), 'HOUSEHOLD', smodel_household, model="sarimax", logTransformation = transformLog_flag)
# Out:
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                          HOUSEHOLD   No. Observations:                  263
# Model:             SARIMAX(0, 1, 1)x(0, 0, 1, 12)   Log Likelihood                 362.453
# Date:                            Sat, 30 Oct 2021   AIC                           -700.906
# Time:                                    18:13:59   BIC                           -658.086
# Sample:                                03-27-2011   HQIC                          -683.696
#                                      - 04-03-2016
# Covariance Type:                              opg
# ==========================================================================================
#                              coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# intercept                  0.0029      0.002      1.759      0.079      -0.000       0.006
# inbetween25and5            0.0035      0.008      0.424      0.671      -0.013       0.020
# event_on_weekend          -0.0053      0.016     -0.333      0.739      -0.036       0.026
# event_on_weekday           0.0099      0.017      0.596      0.551      -0.023       0.043
# event_type_1_Cultural     -0.0144      0.017     -0.857      0.391      -0.047       0.019
# event_type_1_National     -0.0043      0.016     -0.273      0.784      -0.036       0.027
# event_type_1_Religious     0.0090      0.014      0.637      0.524      -0.019       0.037
# event_type_1_Sporting      0.0271      0.018      1.538      0.124      -0.007       0.062
# event_type_2_Cultural     -0.0348      0.039     -0.900      0.368      -0.111       0.041
# ma.L1                     -0.4786      0.053     -9.114      0.000      -0.582      -0.376
# ma.S.L12                  -0.2434      0.069     -3.516      0.000      -0.379      -0.108
# sigma2                     0.0037      0.000     11.415      0.000       0.003       0.004
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.17   Jarque-Bera (JB):                 6.53
# Prob(Q):                              0.68   Prob(JB):                         0.04
# Heteroskedasticity (H):               0.81   Skew:                             0.34
# Prob(H) (two-sided):                  0.32   Kurtosis:                         3.36
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
# define config lists
p_params = [0, 1, 2, 3]
d_params = [0, 1, 2]
q_params = [0, 1, 2]
t_params = ['n','c','t']
P_params = [0, 1, 2]
D_params = [0, 1]
Q_params = [0, 1, 2]

smodel_household_gs = trainSeasonalARIMAGridSearch(train.copy(), test.copy(), 'HOUSEHOLD', p_params, d_params, q_params, t_params, 
                                                   P_params, D_params, Q_params, logTransformation = transformLog_flag)
# Out:
# SARIMAX[(0, 0, 0), (0, 0, 0, 12), 'n'] RMSE=2403188.631
# SARIMAX[(0, 0, 0), (0, 0, 1, 12), 'n'] RMSE=87026.581
# SARIMAX[(0, 0, 0), (0, 0, 2, 12), 'n'] RMSE=60516.331
# SARIMAX[(0, 0, 0), (0, 1, 0, 12), 'n'] RMSE=4205.081
# SARIMAX[(0, 0, 0), (0, 1, 1, 12), 'n'] RMSE=3860.776
# SARIMAX[(0, 0, 0), (2, 1, 1, 12), 'n'] RMSE=3706.414
# SARIMAX[(0, 0, 0), (0, 1, 1, 12), 'c'] RMSE=3279.826
# SARIMAX[(0, 0, 0), (0, 1, 2, 12), 'c'] RMSE=3263.577
# SARIMAX[(0, 0, 0), (1, 1, 0, 12), 'c'] RMSE=3113.706
# SARIMAX[(0, 0, 0), (1, 1, 2, 12), 'c'] RMSE=3028.356
# SARIMAX[(0, 0, 0), (2, 1, 2, 12), 'c'] RMSE=2952.140
# SARIMAX[(0, 0, 1), (0, 1, 0, 12), 'n'] RMSE=2516.981
# SARIMAX[(0, 0, 1), (2, 1, 2, 12), 'c'] RMSE=2180.295
# SARIMAX[(0, 1, 1), (0, 0, 0, 12), 'n'] RMSE=1957.349
# SARIMAX[(0, 1, 1), (0, 0, 1, 12), 'n'] RMSE=1956.448
# SARIMAX[(0, 1, 1), (0, 0, 2, 12), 'n'] RMSE=1936.969
# SARIMAX[(0, 1, 2), (0, 0, 2, 12), 'n'] RMSE=1864.541
# SARIMAX[(0, 2, 2), (2, 0, 0, 12), 'c'] RMSE=1770.416
# SARIMAX[(3, 1, 1), (0, 0, 1, 12), 'c'] RMSE=1723.619
# SARIMAX[(3, 1, 2), (0, 0, 0, 12), 'n'] RMSE=1563.462
# SARIMAX[(3, 2, 1), (0, 0, 1, 12), 'c'] RMSE=1526.591
# SARIMAX[(3, 2, 2), (0, 0, 2, 12), 't'] RMSE=1314.606
# Best SARIMAX[(3, 2, 2), (0, 0, 2, 12), 't'] RMSE=1314.606

# %%
#[(3, 2, 2), (0, 0, 2, 12), 't'] 1314.606

modelSummary(sales_cat_weekly, test.copy(), 'HOUSEHOLD', smodel_household_gs, model="sarimax", 
             showConf=True, logTransformation = transformLog_flag)
# Out:
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                          HOUSEHOLD   No. Observations:                  263
# Model:             SARIMAX(3, 2, 2)x(0, 0, 2, 12)   Log Likelihood                 347.239
# Date:                            Mon, 01 Nov 2021   AIC                           -660.478
# Time:                                    01:54:47   BIC                           -599.882
# Sample:                                03-27-2011   HQIC                          -636.120
#                                      - 04-03-2016
# Covariance Type:                              opg
# ==========================================================================================
#                              coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# drift                  -6.856e-07   1.07e-05     -0.064      0.949   -2.16e-05    2.02e-05
# inbetween25and5           -0.0126      0.012     -1.037      0.300      -0.036       0.011
# event_on_weekend          -0.0193      0.014     -1.344      0.179      -0.047       0.009
# event_on_weekday           0.0018      0.016      0.112      0.911      -0.030       0.034
# event_type_1_Cultural     -0.0002      0.017     -0.011      0.991      -0.033       0.032
# event_type_1_National      0.0044      0.016      0.275      0.783      -0.027       0.036
# event_type_1_Religious     0.0101      0.015      0.693      0.488      -0.018       0.039
# event_type_1_Sporting      0.0326      0.018      1.858      0.063      -0.002       0.067
# event_type_2_Cultural     -0.0156      0.042     -0.374      0.708      -0.098       0.066
# ar.L1                     -0.5373      0.168     -3.193      0.001      -0.867      -0.207
# ar.L2                     -0.4346      0.109     -3.976      0.000      -0.649      -0.220
# ar.L3                     -0.4252      0.067     -6.320      0.000      -0.557      -0.293
# ma.L1                     -0.7849      0.175     -4.479      0.000      -1.128      -0.441
# ma.L2                      0.1855      0.152      1.219      0.223      -0.113       0.484
# ma.S.L12                  -0.0985      0.084     -1.167      0.243      -0.264       0.067
# ma.S.L24                  -0.1129      0.079     -1.432      0.152      -0.267       0.042
# sigma2                     0.0043      0.000     10.100      0.000       0.003       0.005
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.13   Jarque-Bera (JB):                12.08
# Prob(Q):                              0.72   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.74   Skew:                             0.50
# Prob(H) (two-sided):                  0.17   Kurtosis:                         3.33
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# # Phase 2: Resampled Daily
# [Update 10/30: Yet to train the models after code refactoring]

# %%
sales_cat_daily = resampleData(sales_cat.copy(),"D") #daily resampling
sales_cat_daily.head()
# Out:
#             FOODS  HOBBIES  ...  event_type_1_Sporting  event_type_2_Cultural
# date                        ...
# 2011-01-29  23178     3764  ...                      0                      0
# 2011-01-30  22758     3357  ...                      0                      0
# 2011-01-31  17174     2682  ...                      0                      0
# 2011-02-01  18878     2669  ...                      0                      0
# 2011-02-02  14603     1814  ...                      0                      0
#
# [5 rows x 13 columns]

# %%
exog_list = list(sales_cat_daily.columns[3:])
lists = ['FOODS','HOBBIES','HOUSEHOLD']
plotSeries(sales_cat_daily, lists)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="212e6982-2d10-4239-8cb7-f90cdda83cf2" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("212e6982-2d10-4239-8cb7-f90cdda83cf2")) {
#                     Plotly.newPlot(
#                         '212e6982-2d10-4239-8cb7-f90cdda83cf2',
#                         [{"name": "FOODS", "type": "scatter", "x": ["2011-01-29T00:00:00", "2011-01-30T00:00:00", "2011-01-31T00:00:00", "2011-02-01T00:00:00", "2011-02-02T00:00:00", "2011-02-03T00:00:00", "2011-02-04T00:00:00", "2011-02-05T00:00:00", "2011-02-06T00:00:00", "2011-02-07T00:00:00", "2011-02-08T00:00:00", "2011-02-09T00:00:00", "2011-02-10T00:00:00", "2011-02-11T00:00:00", "2011-02-12T00:00:00", "2011-02-13T00:00:00", "2011-02-14T00:00:00", "2011-02-15T00:00:00", "2011-02-16T00:00:00", "2011-02-17T00:00:00", "2011-02-18T00:00:00", "2011-02-19T00:00:00", "2011-02-20T00:00:00", "2011-02-21T00:00:00", "2011-02-22T00:00:00", "2011-02-23T00:00:00", "2011-02-24T00:00:00", "2011-02-25T00:00:00", "2011-02-26T00:00:00", "2011-02-27T00:00:00", "2011-02-28T00:00:00", "2011-03-01T00:00:00", "2011-03-02T00:00:00", "2011-03-03T00:00:00", "2011-03-04T00:00:00", "2011-03-05T00:00:00", "2011-03-06T00:00:00", "2011-03-07T00:00:00", "2011-03-08T00:00:00", "2011-03-09T00:00:00", "2011-03-10T00:00:00", "2011-03-11T00:00:00", "2011-03-12T00:00:00", "2011-03-13T00:00:00", "2011-03-14T00:00:00", "2011-03-15T00:00:00", "2011-03-16T00:00:00", "2011-03-17T00:00:00", "2011-03-18T00:00:00", "2011-03-19T00:00:00", "2011-03-20T00:00:00", "2011-03-21T00:00:00", "2011-03-22T00:00:00", "2011-03-23T00:00:00", "2011-03-24T00:00:00", "2011-03-25T00:00:00", "2011-03-26T00:00:00", "2011-03-27T00:00:00", "2011-03-28T00:00:00", "2011-03-29T00:00:00", "2011-03-30T00:00:00", "2011-03-31T00:00:00", "2011-04-01T00:00:00", "2011-04-02T00:00:00", "2011-04-03T00:00:00", "2011-04-04T00:00:00", "2011-04-05T00:00:00", "2011-04-06T00:00:00", "2011-04-07T00:00:00", "2011-04-08T00:00:00", "2011-04-09T00:00:00", "2011-04-10T00:00:00", "2011-04-11T00:00:00", "2011-04-12T00:00:00", "2011-04-13T00:00:00", "2011-04-14T00:00:00", "2011-04-15T00:00:00", "2011-04-16T00:00:00", "2011-04-17T00:00:00", "2011-04-18T00:00:00", "2011-04-19T00:00:00", "2011-04-20T00:00:00", "2011-04-21T00:00:00", "2011-04-22T00:00:00", "2011-04-23T00:00:00", "2011-04-24T00:00:00", "2011-04-25T00:00:00", "2011-04-26T00:00:00", "2011-04-27T00:00:00", "2011-04-28T00:00:00", "2011-04-29T00:00:00", "2011-04-30T00:00:00", "2011-05-01T00:00:00", "2011-05-02T00:00:00", "2011-05-03T00:00:00", "2011-05-04T00:00:00", "2011-05-05T00:00:00", "2011-05-06T00:00:00", "2011-05-07T00:00:00", "2011-05-08T00:00:00", "2011-05-09T00:00:00", "2011-05-10T00:00:00", "2011-05-11T00:00:00", "2011-05-12T00:00:00", "2011-05-13T00:00:00", "2011-05-14T00:00:00", "2011-05-15T00:00:00", "2011-05-16T00:00:00", "2011-05-17T00:00:00", "2011-05-18T00:00:00", "2011-05-19T00:00:00", "2011-05-20T00:00:00", "2011-05-21T00:00:00", "2011-05-22T00:00:00", "2011-05-23T00:00:00", "2011-05-24T00:00:00", "2011-05-25T00:00:00", "2011-05-26T00:00:00", "2011-05-27T00:00:00", "2011-05-28T00:00:00", "2011-05-29T00:00:00", "2011-05-30T00:00:00", "2011-05-31T00:00:00", "2011-06-01T00:00:00", "2011-06-02T00:00:00", "2011-06-03T00:00:00", "2011-06-04T00:00:00", "2011-06-05T00:00:00", "2011-06-06T00:00:00", "2011-06-07T00:00:00", "2011-06-08T00:00:00", "2011-06-09T00:00:00", "2011-06-10T00:00:00", "2011-06-11T00:00:00", "2011-06-12T00:00:00", "2011-06-13T00:00:00", "2011-06-14T00:00:00", "2011-06-15T00:00:00", "2011-06-16T00:00:00", "2011-06-17T00:00:00", "2011-06-18T00:00:00", "2011-06-19T00:00:00", "2011-06-20T00:00:00", "2011-06-21T00:00:00", "2011-06-22T00:00:00", "2011-06-23T00:00:00", "2011-06-24T00:00:00", "2011-06-25T00:00:00", "2011-06-26T00:00:00", "2011-06-27T00:00:00", "2011-06-28T00:00:00", "2011-06-29T00:00:00", "2011-06-30T00:00:00", "2011-07-01T00:00:00", "2011-07-02T00:00:00", "2011-07-03T00:00:00", "2011-07-04T00:00:00", "2011-07-05T00:00:00", "2011-07-06T00:00:00", "2011-07-07T00:00:00", "2011-07-08T00:00:00", "2011-07-09T00:00:00", "2011-07-10T00:00:00", "2011-07-11T00:00:00", "2011-07-12T00:00:00", "2011-07-13T00:00:00", "2011-07-14T00:00:00", "2011-07-15T00:00:00", "2011-07-16T00:00:00", "2011-07-17T00:00:00", "2011-07-18T00:00:00", ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="896f429d-2903-4584-b3e8-507edfe0297f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("896f429d-2903-4584-b3e8-507edfe0297f")) {
#                     Plotly.newPlot(
#                         '896f429d-2903-4584-b3e8-507edfe0297f',
#                         [{"name": "HOBBIES", "type": "scatter", "x": ["2011-01-29T00:00:00", "2011-01-30T00:00:00", "2011-01-31T00:00:00", "2011-02-01T00:00:00", "2011-02-02T00:00:00", "2011-02-03T00:00:00", "2011-02-04T00:00:00", "2011-02-05T00:00:00", "2011-02-06T00:00:00", "2011-02-07T00:00:00", "2011-02-08T00:00:00", "2011-02-09T00:00:00", "2011-02-10T00:00:00", "2011-02-11T00:00:00", "2011-02-12T00:00:00", "2011-02-13T00:00:00", "2011-02-14T00:00:00", "2011-02-15T00:00:00", "2011-02-16T00:00:00", "2011-02-17T00:00:00", "2011-02-18T00:00:00", "2011-02-19T00:00:00", "2011-02-20T00:00:00", "2011-02-21T00:00:00", "2011-02-22T00:00:00", "2011-02-23T00:00:00", "2011-02-24T00:00:00", "2011-02-25T00:00:00", "2011-02-26T00:00:00", "2011-02-27T00:00:00", "2011-02-28T00:00:00", "2011-03-01T00:00:00", "2011-03-02T00:00:00", "2011-03-03T00:00:00", "2011-03-04T00:00:00", "2011-03-05T00:00:00", "2011-03-06T00:00:00", "2011-03-07T00:00:00", "2011-03-08T00:00:00", "2011-03-09T00:00:00", "2011-03-10T00:00:00", "2011-03-11T00:00:00", "2011-03-12T00:00:00", "2011-03-13T00:00:00", "2011-03-14T00:00:00", "2011-03-15T00:00:00", "2011-03-16T00:00:00", "2011-03-17T00:00:00", "2011-03-18T00:00:00", "2011-03-19T00:00:00", "2011-03-20T00:00:00", "2011-03-21T00:00:00", "2011-03-22T00:00:00", "2011-03-23T00:00:00", "2011-03-24T00:00:00", "2011-03-25T00:00:00", "2011-03-26T00:00:00", "2011-03-27T00:00:00", "2011-03-28T00:00:00", "2011-03-29T00:00:00", "2011-03-30T00:00:00", "2011-03-31T00:00:00", "2011-04-01T00:00:00", "2011-04-02T00:00:00", "2011-04-03T00:00:00", "2011-04-04T00:00:00", "2011-04-05T00:00:00", "2011-04-06T00:00:00", "2011-04-07T00:00:00", "2011-04-08T00:00:00", "2011-04-09T00:00:00", "2011-04-10T00:00:00", "2011-04-11T00:00:00", "2011-04-12T00:00:00", "2011-04-13T00:00:00", "2011-04-14T00:00:00", "2011-04-15T00:00:00", "2011-04-16T00:00:00", "2011-04-17T00:00:00", "2011-04-18T00:00:00", "2011-04-19T00:00:00", "2011-04-20T00:00:00", "2011-04-21T00:00:00", "2011-04-22T00:00:00", "2011-04-23T00:00:00", "2011-04-24T00:00:00", "2011-04-25T00:00:00", "2011-04-26T00:00:00", "2011-04-27T00:00:00", "2011-04-28T00:00:00", "2011-04-29T00:00:00", "2011-04-30T00:00:00", "2011-05-01T00:00:00", "2011-05-02T00:00:00", "2011-05-03T00:00:00", "2011-05-04T00:00:00", "2011-05-05T00:00:00", "2011-05-06T00:00:00", "2011-05-07T00:00:00", "2011-05-08T00:00:00", "2011-05-09T00:00:00", "2011-05-10T00:00:00", "2011-05-11T00:00:00", "2011-05-12T00:00:00", "2011-05-13T00:00:00", "2011-05-14T00:00:00", "2011-05-15T00:00:00", "2011-05-16T00:00:00", "2011-05-17T00:00:00", "2011-05-18T00:00:00", "2011-05-19T00:00:00", "2011-05-20T00:00:00", "2011-05-21T00:00:00", "2011-05-22T00:00:00", "2011-05-23T00:00:00", "2011-05-24T00:00:00", "2011-05-25T00:00:00", "2011-05-26T00:00:00", "2011-05-27T00:00:00", "2011-05-28T00:00:00", "2011-05-29T00:00:00", "2011-05-30T00:00:00", "2011-05-31T00:00:00", "2011-06-01T00:00:00", "2011-06-02T00:00:00", "2011-06-03T00:00:00", "2011-06-04T00:00:00", "2011-06-05T00:00:00", "2011-06-06T00:00:00", "2011-06-07T00:00:00", "2011-06-08T00:00:00", "2011-06-09T00:00:00", "2011-06-10T00:00:00", "2011-06-11T00:00:00", "2011-06-12T00:00:00", "2011-06-13T00:00:00", "2011-06-14T00:00:00", "2011-06-15T00:00:00", "2011-06-16T00:00:00", "2011-06-17T00:00:00", "2011-06-18T00:00:00", "2011-06-19T00:00:00", "2011-06-20T00:00:00", "2011-06-21T00:00:00", "2011-06-22T00:00:00", "2011-06-23T00:00:00", "2011-06-24T00:00:00", "2011-06-25T00:00:00", "2011-06-26T00:00:00", "2011-06-27T00:00:00", "2011-06-28T00:00:00", "2011-06-29T00:00:00", "2011-06-30T00:00:00", "2011-07-01T00:00:00", "2011-07-02T00:00:00", "2011-07-03T00:00:00", "2011-07-04T00:00:00", "2011-07-05T00:00:00", "2011-07-06T00:00:00", "2011-07-07T00:00:00", "2011-07-08T00:00:00", "2011-07-09T00:00:00", "2011-07-10T00:00:00", "2011-07-11T00:00:00", "2011-07-12T00:00:00", "2011-07-13T00:00:00", "2011-07-14T00:00:00", "2011-07-15T00:00:00", "2011-07-16T00:00:00", "2011-07-17T00:00:00", "2011-07-18T00:00:00 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="fd6e8914-29fc-4ae9-855f-f7e551382dca" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("fd6e8914-29fc-4ae9-855f-f7e551382dca")) {
#                     Plotly.newPlot(
#                         'fd6e8914-29fc-4ae9-855f-f7e551382dca',
#                         [{"name": "HOUSEHOLD", "type": "scatter", "x": ["2011-01-29T00:00:00", "2011-01-30T00:00:00", "2011-01-31T00:00:00", "2011-02-01T00:00:00", "2011-02-02T00:00:00", "2011-02-03T00:00:00", "2011-02-04T00:00:00", "2011-02-05T00:00:00", "2011-02-06T00:00:00", "2011-02-07T00:00:00", "2011-02-08T00:00:00", "2011-02-09T00:00:00", "2011-02-10T00:00:00", "2011-02-11T00:00:00", "2011-02-12T00:00:00", "2011-02-13T00:00:00", "2011-02-14T00:00:00", "2011-02-15T00:00:00", "2011-02-16T00:00:00", "2011-02-17T00:00:00", "2011-02-18T00:00:00", "2011-02-19T00:00:00", "2011-02-20T00:00:00", "2011-02-21T00:00:00", "2011-02-22T00:00:00", "2011-02-23T00:00:00", "2011-02-24T00:00:00", "2011-02-25T00:00:00", "2011-02-26T00:00:00", "2011-02-27T00:00:00", "2011-02-28T00:00:00", "2011-03-01T00:00:00", "2011-03-02T00:00:00", "2011-03-03T00:00:00", "2011-03-04T00:00:00", "2011-03-05T00:00:00", "2011-03-06T00:00:00", "2011-03-07T00:00:00", "2011-03-08T00:00:00", "2011-03-09T00:00:00", "2011-03-10T00:00:00", "2011-03-11T00:00:00", "2011-03-12T00:00:00", "2011-03-13T00:00:00", "2011-03-14T00:00:00", "2011-03-15T00:00:00", "2011-03-16T00:00:00", "2011-03-17T00:00:00", "2011-03-18T00:00:00", "2011-03-19T00:00:00", "2011-03-20T00:00:00", "2011-03-21T00:00:00", "2011-03-22T00:00:00", "2011-03-23T00:00:00", "2011-03-24T00:00:00", "2011-03-25T00:00:00", "2011-03-26T00:00:00", "2011-03-27T00:00:00", "2011-03-28T00:00:00", "2011-03-29T00:00:00", "2011-03-30T00:00:00", "2011-03-31T00:00:00", "2011-04-01T00:00:00", "2011-04-02T00:00:00", "2011-04-03T00:00:00", "2011-04-04T00:00:00", "2011-04-05T00:00:00", "2011-04-06T00:00:00", "2011-04-07T00:00:00", "2011-04-08T00:00:00", "2011-04-09T00:00:00", "2011-04-10T00:00:00", "2011-04-11T00:00:00", "2011-04-12T00:00:00", "2011-04-13T00:00:00", "2011-04-14T00:00:00", "2011-04-15T00:00:00", "2011-04-16T00:00:00", "2011-04-17T00:00:00", "2011-04-18T00:00:00", "2011-04-19T00:00:00", "2011-04-20T00:00:00", "2011-04-21T00:00:00", "2011-04-22T00:00:00", "2011-04-23T00:00:00", "2011-04-24T00:00:00", "2011-04-25T00:00:00", "2011-04-26T00:00:00", "2011-04-27T00:00:00", "2011-04-28T00:00:00", "2011-04-29T00:00:00", "2011-04-30T00:00:00", "2011-05-01T00:00:00", "2011-05-02T00:00:00", "2011-05-03T00:00:00", "2011-05-04T00:00:00", "2011-05-05T00:00:00", "2011-05-06T00:00:00", "2011-05-07T00:00:00", "2011-05-08T00:00:00", "2011-05-09T00:00:00", "2011-05-10T00:00:00", "2011-05-11T00:00:00", "2011-05-12T00:00:00", "2011-05-13T00:00:00", "2011-05-14T00:00:00", "2011-05-15T00:00:00", "2011-05-16T00:00:00", "2011-05-17T00:00:00", "2011-05-18T00:00:00", "2011-05-19T00:00:00", "2011-05-20T00:00:00", "2011-05-21T00:00:00", "2011-05-22T00:00:00", "2011-05-23T00:00:00", "2011-05-24T00:00:00", "2011-05-25T00:00:00", "2011-05-26T00:00:00", "2011-05-27T00:00:00", "2011-05-28T00:00:00", "2011-05-29T00:00:00", "2011-05-30T00:00:00", "2011-05-31T00:00:00", "2011-06-01T00:00:00", "2011-06-02T00:00:00", "2011-06-03T00:00:00", "2011-06-04T00:00:00", "2011-06-05T00:00:00", "2011-06-06T00:00:00", "2011-06-07T00:00:00", "2011-06-08T00:00:00", "2011-06-09T00:00:00", "2011-06-10T00:00:00", "2011-06-11T00:00:00", "2011-06-12T00:00:00", "2011-06-13T00:00:00", "2011-06-14T00:00:00", "2011-06-15T00:00:00", "2011-06-16T00:00:00", "2011-06-17T00:00:00", "2011-06-18T00:00:00", "2011-06-19T00:00:00", "2011-06-20T00:00:00", "2011-06-21T00:00:00", "2011-06-22T00:00:00", "2011-06-23T00:00:00", "2011-06-24T00:00:00", "2011-06-25T00:00:00", "2011-06-26T00:00:00", "2011-06-27T00:00:00", "2011-06-28T00:00:00", "2011-06-29T00:00:00", "2011-06-30T00:00:00", "2011-07-01T00:00:00", "2011-07-02T00:00:00", "2011-07-03T00:00:00", "2011-07-04T00:00:00", "2011-07-05T00:00:00", "2011-07-06T00:00:00", "2011-07-07T00:00:00", "2011-07-08T00:00:00", "2011-07-09T00:00:00", "2011-07-10T00:00:00", "2011-07-11T00:00:00", "2011-07-12T00:00:00", "2011-07-13T00:00:00", "2011-07-14T00:00:00", "2011-07-15T00:00:00", "2011-07-16T00:00:00", "2011-07-17T00:00:00", "2011-07-18T00:00: ...

# %%
print('Seasonal Decompose on Daily Resampled Data')
for i in lists:
    sm.tsa.seasonal_decompose(sales_cat_daily[i]).plot()
    #fig.update_layout(title_text=i)
# Out:
# Seasonal Decompose on Daily Resampled Data

# %% [markdown]
# **ADF TEST on daily data**

# %%
# Perform ADF Test

performADFTest(sales_cat_daily,lists)
# Out:
# Results of Dickey-Fuller Test for :  FOODS
# Test Statistic                   -1.558381
# p-value                           0.504459
# #Lags Used                       26.000000
# Number of Observations Used    1914.000000
# Critical Value (1%)              -3.430000
# Critical Value (5%)              -2.860000
# Critical Value (10%)             -2.570000
# dtype: float64
# ++++++++++++++++++++++++++++++++++++++
# Results of Dickey-Fuller Test for :  HOBBIES
# Test Statistic                   -1.685561
# p-value                           0.438567
# #Lags Used                       26.000000
# Number of Observations Used    1914.000000
# Critical Value (1%)              -3.430000
# Critical Value (5%)              -2.860000
# Critical Value (10%)             -2.570000
# dtype: float64
# ++++++++++++++++++++++++++++++++++++++
# Results of Dickey-Fuller Test for :  HOUSEHOLD
# Test Statistic                   -1.486333
# p-value                           0.540261
# #Lags Used                       26.000000
# Number of Observations Used    1914.000000
# Critical Value (1%)              -3.430000
# Critical Value (5%)              -2.860000
# Critical Value (10%)             -2.570000
# dtype: float64
# ++++++++++++++++++++++++++++++++++++++

# %%
sales_cat_food = sales_cat_daily['FOODS']
sales_cat_house = sales_cat_daily['HOUSEHOLD']
sales_cat_hobbies = sales_cat_daily['HOBBIES']

# %%
sales_cat_food_diff = sales_cat_food.diff(2)
sales_cat_house_diff = sales_cat_house.diff(1)
sales_cat_hobbies_diff = sales_cat_hobbies.diff(1)
sales_cat_food_diff = sales_cat_food_diff.dropna()
sales_cat_house_diff = sales_cat_house_diff.dropna()
sales_cat_hobbies_diff = sales_cat_hobbies_diff.dropna()

# %%
lists = [sales_cat_food_diff,sales_cat_food_diff,sales_cat_hobbies_diff]
for i in lists:

  print('Results of Dickey-Fuller Test for : ',i.name)
  dftest = adfuller(i)

  dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
  for key, value in dftest[4].items():
    dfoutput['Critical Value (%s)'%key] = round(value,2)

  print(dfoutput)
  print('++++++++++++++++++++++++++++++++++++++')
  print('\n')

  fig, (ax1, ax2) = plt.subplots(nrows=2, ncols=1, figsize=(14,6), sharex=False, sharey=False)
  ax1 = plot_acf(i, lags=50, ax=ax1)
  ax2 = plot_pacf(i, lags=50, ax=ax2)
  plt.show()
# Out:
# Results of Dickey-Fuller Test for :  FOODS
# Test Statistic                  -22.458851
# p-value                           0.000000
# #Lags Used                       26.000000
# Number of Observations Used    1912.000000
# Critical Value (1%)              -3.430000
# Critical Value (5%)              -2.860000
# Critical Value (10%)             -2.570000
# dtype: float64
# ++++++++++++++++++++++++++++++++++++++
# Results of Dickey-Fuller Test for :  FOODS
# Test Statistic                  -22.458851
# p-value                           0.000000
# #Lags Used                       26.000000
# Number of Observations Used    1912.000000
# Critical Value (1%)              -3.430000
# Critical Value (5%)              -2.860000
# Critical Value (10%)             -2.570000
# dtype: float64
# ++++++++++++++++++++++++++++++++++++++
# Results of Dickey-Fuller Test for :  HOBBIES
# Test Statistic                -1.456485e+01
# p-value                        4.730040e-27
# #Lags Used                     2.600000e+01
# Number of Observations Used    1.913000e+03
# Critical Value (1%)           -3.430000e+00
# Critical Value (5%)           -2.860000e+00
# Critical Value (10%)          -2.570000e+00
# dtype: float64
# ++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# ## Train ARIMA

# %%
# Perform Train Test Splits
train = sales_cat_daily[:int(0.98*(len(sales_cat_daily)))]
test = sales_cat_daily[int(0.98*(len(sales_cat_daily))):]

# %% [markdown]
# ### FOODS

# %%
sales_cat_daily.FOODS.describe()
# Out:
# count     1941.000000
# mean     23659.158681
# std       4958.106999
# min         11.000000
# 25%      20386.000000
# 50%      23272.000000
# 75%      26782.000000
# max      41447.000000
# Name: FOODS, dtype: float64

# %%
train.FOODS.plot()
test.FOODS.plot()

# %%
transformLog_flag = True

# %%
# Train using Auto Arima
model_food = trainAutoARIMA(train.copy(),'FOODS', logTransformation = transformLog_flag)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,2,0)(0,0,0)[0] intercept   : AIC=5149.783, Time=0.36 sec
#  ARIMA(1,2,0)(0,0,0)[0] intercept   : AIC=4131.857, Time=0.23 sec
#  ARIMA(0,2,1)(0,0,0)[0] intercept   : AIC=inf, Time=2.98 sec
#  ARIMA(0,2,0)(0,0,0)[0]             : AIC=5149.783, Time=0.40 sec
#  ARIMA(2,2,0)(0,0,0)[0] intercept   : AIC=3662.713, Time=0.41 sec
#  ARIMA(3,2,0)(0,0,0)[0] intercept   : AIC=3399.206, Time=0.62 sec
#  ARIMA(4,2,0)(0,0,0)[0] intercept   : AIC=3231.207, Time=0.79 sec
#  ARIMA(5,2,0)(0,0,0)[0] intercept   : AIC=3110.768, Time=1.03 sec
#  ARIMA(5,2,1)(0,0,0)[0] intercept   : AIC=inf, Time=6.85 sec
#  ARIMA(4,2,1)(0,0,0)[0] intercept   : AIC=inf, Time=5.40 sec
#  ARIMA(5,2,0)(0,0,0)[0]             : AIC=3110.768, Time=1.05 sec
#
# Best model:  ARIMA(5,2,0)(0,0,0)[0] intercept
# Total fit time: 20.142 seconds

# %%
[rmse_foods, results_foods] = evaluate_arima_model(train.copy(), test.copy(), model_food.get_params()['order'], 
                                                   'FOODS', logTransformation = transformLog_flag)
print(rmse_foods)
# Out:
# 6136.522698532656

# %%
modelSummary(sales_cat_daily, test, 'FOODS', results_foods, showConf=False, logTransformation = transformLog_flag)
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 1940
# Model:                 ARIMA(5, 2, 0)   Log Likelihood               -1562.900
# Date:                Sat, 30 Oct 2021   AIC                           3137.801
# Time:                        18:43:32   BIC                           3171.217
# Sample:                             0   HQIC                          3150.090
#                                - 1940
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -1.2930      0.004   -353.253      0.000      -1.300      -1.286
# ar.L2         -1.2169      0.009   -131.991      0.000      -1.235      -1.199
# ar.L3         -0.9472      0.017    -56.225      0.000      -0.980      -0.914
# ar.L4         -0.5968      0.025    -23.666      0.000      -0.646      -0.547
# ar.L5         -0.2499      0.008    -31.179      0.000      -0.266      -0.234
# sigma2         0.2934      0.001    213.763      0.000       0.291       0.296
# ===================================================================================
# Ljung-Box (L1) (Q):                  12.90   Jarque-Bera (JB):            982944.25
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.69   Skew:                            -4.34
# Prob(H) (two-sided):                  0.00   Kurtosis:                       112.99
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
# Train using gridsearch

# parameters
p_values = range(0,6)
d_values = range(0, 4)
q_values = range(0, 4)
warnings.filterwarnings("ignore")

results_foods_gs = trainARIMAGridSearch(train.copy(), test.copy(), 'FOODS',p_values,d_values,
                                        q_values,logTransformation = transformLog_flag)
# Out:
# ARIMA(0, 0, 0) RMSE=7192.399
# ARIMA(0, 0, 1) RMSE=5149.635
# ARIMA(0, 0, 2) RMSE=4380.181
# ARIMA(0, 0, 3) RMSE=4338.483
# ARIMA(0, 1, 0) RMSE=4174.410
# ARIMA(0, 1, 1) RMSE=4152.514
# ARIMA(0, 1, 2) RMSE=3736.437
# ARIMA(0, 1, 3) RMSE=3534.664

# %%
modelSummary(sales_cat_weekly, test.copy(), 'FOODS', results_foods_gs, 
             showConf=False, logTransformation = transformLog_flag)

# %% [markdown]
# ### HOBBIES

# %%
sales_cat_daily.HOBBIES.describe()
# Out:
# count    1941.000000
# mean     3215.175683
# std       713.553574
# min         0.000000
# 25%      2700.000000
# 50%      3188.000000
# 75%      3648.000000
# max      5360.000000
# Name: HOBBIES, dtype: float64

# %%
train.HOBBIES.plot()
test.HOBBIES.plot()

# %%
transformLog_flag = False

# %%
model_hobbies = trainAutoARIMA(train.copy(), 'HOBBIES', logTransformation = transformLog_flag)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,2,0)(0,0,0)[0] intercept   : AIC=31100.768, Time=0.05 sec
#  ARIMA(1,2,0)(0,0,0)[0] intercept   : AIC=30702.657, Time=0.12 sec
#  ARIMA(0,2,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.91 sec
#  ARIMA(0,2,0)(0,0,0)[0]             : AIC=31100.768, Time=0.08 sec
#  ARIMA(2,2,0)(0,0,0)[0] intercept   : AIC=30436.234, Time=0.33 sec
#  ARIMA(3,2,0)(0,0,0)[0] intercept   : AIC=30317.132, Time=0.45 sec
#  ARIMA(4,2,0)(0,0,0)[0] intercept   : AIC=30261.316, Time=0.65 sec
#  ARIMA(5,2,0)(0,0,0)[0] intercept   : AIC=29980.411, Time=0.98 sec
#  ARIMA(5,2,1)(0,0,0)[0] intercept   : AIC=inf, Time=4.57 sec
#  ARIMA(4,2,1)(0,0,0)[0] intercept   : AIC=inf, Time=4.12 sec
#  ARIMA(5,2,0)(0,0,0)[0]             : AIC=29980.411, Time=0.91 sec
#
# Best model:  ARIMA(5,2,0)(0,0,0)[0]
# Total fit time: 13.198 seconds

# %%
[rmse_hobbies, results_hobbies] = evaluate_arima_model(train.copy(), test.copy(), model_hobbies.get_params()['order'], 
                                                       'HOBBIES', logTransformation = transformLog_flag)
print(rmse_hobbies)
# Out:
# 667.4952938312742

# %%
modelSummary(sales_cat_daily, test.copy(), 'HOBBIES', results_hobbies, 
             showConf=False, logTransformation = transformLog_flag)
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 1940
# Model:                 ARIMA(5, 2, 0)   Log Likelihood              -15284.745
# Date:                Sat, 30 Oct 2021   AIC                          30581.490
# Time:                        18:46:52   BIC                          30614.906
# Sample:                             0   HQIC                         30593.779
#                                - 1940
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.7892      0.017    -47.168      0.000      -0.822      -0.756
# ar.L2         -0.7350      0.028    -26.316      0.000      -0.790      -0.680
# ar.L3         -0.5879      0.029    -20.546      0.000      -0.644      -0.532
# ar.L4         -0.4418      0.023    -19.392      0.000      -0.486      -0.397
# ar.L5         -0.3749      0.015    -24.827      0.000      -0.404      -0.345
# sigma2      4.135e+05   9045.604     45.709      0.000    3.96e+05    4.31e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                 105.81   Jarque-Bera (JB):              3821.95
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.62   Skew:                             0.53
# Prob(H) (two-sided):                  0.00   Kurtosis:                         9.80
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
# Train using gridsearch

# parameters
p_values = range(0,7)
d_values = range(0, 4)
q_values = range(0, 4)
warnings.filterwarnings("ignore")

results_hobbies_gs = trainARIMAGridSearch(train.copy(), test.copy(), 'HOBBIES',p_values,d_values,q_values, logTransformation = transformLog_flag)

# %%
modelSummary(sales_cat_daily, test.copy(), 'HOBBIES', results_hobbies_gs, 
             showConf=False, logTransformation = transformLog_flag)

# %% [markdown]
# ### HOUSEHOLD

# %%
sales_cat_daily.HOUSEHOLD.describe()
# Out:
# count     1941.000000
# mean      7606.434827
# std       2209.606572
# min          0.000000
# 25%       6088.000000
# 50%       7457.000000
# 75%       8998.000000
# max      13889.000000
# Name: HOUSEHOLD, dtype: float64

# %%
train.HOUSEHOLD.plot()
test.HOUSEHOLD.plot()

# %%
transformLog_flag = False

# %%
model_household = trainAutoARIMA(train.copy(), category='HOUSEHOLD', logTransformation = transformLog_flag)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,2,0)(0,0,0)[0] intercept   : AIC=34273.418, Time=0.06 sec
#  ARIMA(1,2,0)(0,0,0)[0] intercept   : AIC=34128.148, Time=0.12 sec
#  ARIMA(0,2,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.97 sec
#  ARIMA(0,2,0)(0,0,0)[0]             : AIC=34273.418, Time=0.10 sec
#  ARIMA(2,2,0)(0,0,0)[0] intercept   : AIC=33923.781, Time=0.33 sec
#  ARIMA(3,2,0)(0,0,0)[0] intercept   : AIC=33848.141, Time=0.47 sec
#  ARIMA(4,2,0)(0,0,0)[0] intercept   : AIC=33761.146, Time=0.53 sec
#  ARIMA(5,2,0)(0,0,0)[0] intercept   : AIC=33180.432, Time=0.92 sec
#  ARIMA(5,2,1)(0,0,0)[0] intercept   : AIC=inf, Time=6.91 sec
#  ARIMA(4,2,1)(0,0,0)[0] intercept   : AIC=inf, Time=5.92 sec
#  ARIMA(5,2,0)(0,0,0)[0]             : AIC=33180.432, Time=0.95 sec
#
# Best model:  ARIMA(5,2,0)(0,0,0)[0] intercept
# Total fit time: 17.288 seconds

# %%
[rmse_household, results_household] = evaluate_arima_model(train.copy(), test.copy(), model_household.get_params()['order'],
                                                           'HOUSEHOLD', logTransformation = transformLog_flag)
print(rmse_household)
# Out:
# 1651.6587246404958

# %%
modelSummary(sales_cat_daily, test.copy(), 'HOUSEHOLD', results_household, 
             showConf=False, logTransformation = transformLog_flag)
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 1940
# Model:                 ARIMA(5, 2, 0)   Log Likelihood              -16919.128
# Date:                Sat, 30 Oct 2021   AIC                          33850.255
# Time:                        18:47:53   BIC                          33883.672
# Sample:                             0   HQIC                         33862.545
#                                - 1940
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.5779      0.014    -40.464      0.000      -0.606      -0.550
# ar.L2         -0.6244      0.023    -26.699      0.000      -0.670      -0.579
# ar.L3         -0.5382      0.024    -22.556      0.000      -0.585      -0.491
# ar.L4         -0.4543      0.019    -23.496      0.000      -0.492      -0.416
# ar.L5         -0.5173      0.013    -40.748      0.000      -0.542      -0.492
# sigma2       2.24e+06   4.09e+04     54.734      0.000    2.16e+06    2.32e+06
# ===================================================================================
# Ljung-Box (L1) (Q):                 253.48   Jarque-Bera (JB):              6620.01
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               3.25   Skew:                             0.53
# Prob(H) (two-sided):                  0.00   Kurtosis:                        11.99
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
# Train using gridsearch

# parameters
p_values = range(0,7)
d_values = range(0, 4)
q_values = range(0, 4)
warnings.filterwarnings("ignore")

results_household_gs = trainARIMAGridSearch(train.copy(), test.copy(), 'HOUSEHOLD',p_values,d_values,
                                            q_values, logTransformation = transformLog_flag)

# %%
modelSummary(sales_cat_weekly, test.copy(), 'HOUSEHOLD', results_household_gs, 
             showConf= False, logTransformation = transformLog_flag)

# %% [markdown]
# ## SARIMAX Training

# %%
train = sales_cat_daily[:int(0.98*(len(sales_cat_daily)))]
test = sales_cat_daily[int(0.98*(len(sales_cat_daily))):]

# %% [markdown]
# ### FOODS

# %%
transformLog_flag = True

# %%
sarima_model_foods = trainSeasonalAutoARIMA(train.copy(),'FOODS', logTransformation = transformLog_flag)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,2,0)(1,1,1)[12]             : AIC=7579.870, Time=57.04 sec
#  ARIMA(0,2,0)(0,1,0)[12]             : AIC=6119.697, Time=15.13 sec
#  ARIMA(1,2,0)(1,1,0)[12]             : AIC=6392.176, Time=71.61 sec
#  ARIMA(0,2,1)(0,1,1)[12]             : AIC=6174.255, Time=62.96 sec
#  ARIMA(0,2,0)(1,1,0)[12]             : AIC=7697.868, Time=50.54 sec
#  ARIMA(0,2,0)(0,1,1)[12]             : AIC=6153.702, Time=93.72 sec
#  ARIMA(1,2,0)(0,1,0)[12]             : AIC=6124.554, Time=18.59 sec
#  ARIMA(0,2,1)(0,1,0)[12]             : AIC=6943.011, Time=19.29 sec
#  ARIMA(1,2,1)(0,1,0)[12]             : AIC=18064543.047, Time=35.21 sec
#  ARIMA(0,2,0)(0,1,0)[12] intercept   : AIC=6119.697, Time=15.31 sec
#
# Best model:  ARIMA(0,2,0)(0,1,0)[12]
# Total fit time: 439.421 seconds

# %%
# Extract Model Parameters
order = sarima_model_foods.get_params()['order']
seasonal_order = sarima_model_foods.get_params()['seasonal_order']
trend = sarima_model_foods.get_params()['trend']

model_params = [order, seasonal_order, trend]
model_params
# Out:
# [(0, 2, 0), (0, 1, 0, 12), 't']

# %%
[rmse_sarima_foods, smodel_foods] = evaluate_seasonal_arima_model(train.copy(), test.copy(), model_params,
                                                                  'FOODS', logTransformation = transformLog_flag)
print(rmse_sarima_foods)
# Out:
# 28666.132316028845

# %%
modelSummary(sales_cat_daily, test.copy(), 'FOODS', smodel_foods, model="sarimax", 
             showConf=False, logTransformation = transformLog_flag)
# Out:
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                              FOODS   No. Observations:                 1902
# Model:             SARIMAX(0, 2, 0)x(0, 1, 0, 12)   Log Likelihood               -3047.849
# Date:                            Sat, 30 Oct 2021   AIC                           6119.697
# Time:                                    18:59:06   BIC                           6186.216
# Sample:                                01-29-2011   HQIC                          6144.193
#                                      - 04-13-2016
# Covariance Type:                              opg
# ==========================================================================================
#                              coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# drift                  -1.723e-06   2.54e-05     -0.068      0.946   -5.15e-05     4.8e-05
# isWeekend               4.357e+11      0.014   3.21e+13      0.000    4.36e+11    4.36e+11
# isWeekday               4.357e+11      0.014   3.21e+13      0.000    4.36e+11    4.36e+11
# inbetween25and5           -0.4612      0.042    -10.887      0.000      -0.544      -0.378
# event_on_weekend        1.761e+09      0.047   3.71e+10      0.000    1.76e+09    1.76e+09
# event_on_weekday        1.761e+09      0.044   4.03e+10      0.000    1.76e+09    1.76e+09
# event_type_1_Cultural  -1.761e+09      0.135   -1.3e+10      0.000   -1.76e+09   -1.76e+09
# event_type_1_National  -1.761e+09      0.058  -3.04e+10      0.000   -1.76e+09   -1.76e+09
# event_type_1_Religious -1.761e+09      0.049  -3.56e+10      0.000   -1.76e+09   -1.76e+09
# event_type_1_Sporting  -1.761e+09      0.155  -1.13e+10      0.000   -1.76e+09   -1.76e+09
# event_type_2_Cultural      0.1650      0.549      0.301      0.764      -0.910       1.240
# sigma2                     1.4781      0.025     58.411      0.000       1.429       1.528
# ===================================================================================
# Ljung-Box (L1) (Q):                 787.42   Jarque-Bera (JB):            309288.80
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.76   Skew:                             0.25
# Prob(H) (two-sided):                  0.00   Kurtosis:                        65.70
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 2.76e+18. Standard errors may be unstable.

# %% [markdown]
# ### HOBBIES

# %%
transformLog_flag = True

# %%
sarima_model_hobbies = trainSeasonalAutoARIMA(train.copy(),'HOBBIES',tr='c', logTransformation = transformLog_flag)

# %%
# Extract Model Parameters
order = sarima_model_hobbies.get_params()['order']
seasonal_order = sarima_model_hobbies.get_params()['seasonal_order']
trend = sarima_model_hobbies.get_params()['trend']

model_params = [order, seasonal_order, trend]
model_params

# %%
[rmse_sarima_hobbies, smodel_hobbies] = evaluate_seasonal_arima_model(train.copy(), test.copy(), model_params,
                                                                      'HOBBIES', logTransformation = transformLog_flag)
print(rmse_sarima_hobbies)

# %%
modelSummary(sales_cat_weekly, test.copy(), 'HOBBIES', smodel_hobbies, model="sarimax", 
             showConf=False, logTransformation = transformLog_flag)

# %%
# define config lists
p_params = [1, 2, 3, 4, 5]
d_params = [0, 1, 2]
q_params = [0, 1, 2, 3]
t_params = ['n','c','t']
P_params = [0, 1, 2, 3]
D_params = [0, 1]
Q_params = [0, 1, 2, 3]

# smodel_hobbies_gs = trainSeasonalARIMAGridSearch(train.copy(), test.copy(), 'HOBBIES', p_params, d_params, q_params, t_params, 
#                                                  P_params, D_params, Q_params, logTransformation = transformLog_flag)

# %%
#modelSummary(sales_cat_daily, test, 'HOBBIES', smodel_hobbies_gs, model="sarimax", logTransformation = transformLog_flag)

# %% [markdown]
# ### HOUSEHOLD

# %%
transformLog_flag = False

# %%
sarima_model_household = trainSeasonalAutoARIMA(train.copy(),'HOUSEHOLD',tr='c', logTransformation = transformLog_flag)

# %%
# Extract Model Parameters
order = sarima_model_household.get_params()['order']
seasonal_order = sarima_model_household.get_params()['seasonal_order']
trend = sarima_model_household.get_params()['trend']

model_params = [order, seasonal_order, trend]
model_params

# %%
[rmse_sarima_household, smodel_household] = evaluate_seasonal_arima_model(train.copy(), test.copy(), model_params,
                                                                          'HOUSEHOLD', logTransformation = transformLog_flag)
print(rmse_sarima_household)

# %%
modelSummary(sales_cat_daily, test.copy(), 'HOUSEHOLD', smodel_household, model="sarimax",
             showConf=False, logTransformation = transformLog_flag)

# %%
# define config lists
p_params = [1, 2, 3, 4, 5]
d_params = [0, 1, 2]
q_params = [0, 1, 2, 3]
t_params = ['n','c','t']
P_params = [0, 1, 2, 3]
D_params = [0, 1]
Q_params = [0, 1, 2, 3]

# smodel_household_gs = trainSeasonalARIMAGridSearch(train.copy(), test.copy(), 'HOUSEHOLD', p_params, d_params, q_params, t_params,
#                                                    P_params, D_params, Q_params, logTransformation = transformLog_flag)

# %%
#modelSummary(sales_cat_daily, test.copy(), 'HOUSEHOLD', smodel_household_gs, model="sarimax", logTransformation = transformLog_flag)
